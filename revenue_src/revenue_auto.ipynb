# %%
from tqdm.notebook import tqdm
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.request import Request
import urllib

# %%
url = "https://job.incruit.com/jobdb_list/searchjob.asp?kw=%C0%DA%C0%B2%C1%D6%C7%E0&rgn2=11&rgn2=18&page={page_number}"        # 자신의 찾으려는 웹사이트 입력
req = Request(url.format(page_number = urllib.parse.quote('1')))
res = urlopen(req)
soup = BeautifulSoup(res, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="text/javascript" http-equiv="Content-Script-Type"/>
#   <meta content="text/css" http-equiv="Content-Style-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    서울특별시,경기도 자율주행 :: 인크루트 채용정보
#   </title>
#   <meta content=" 서울특별시,경기도 자율주행 인크루트 채용정보(incruit.com) - 믿을 수 있는 취업정보사이트, 경력별, 지역별, 직종별 구인구직정보, 직업별 일자리정보, 실시간 채용정보, 기업별 입사비법" name="Description"/>
#   <meta content=" 서울특별시,경기도 자율주행,취업정보사이트,구인구직사이트,직업,일자리사이트,구인구직사이트,채용정보사이트,인턴,공기업채용,구인광고,구직정보,채용공고,대기업채용정보,여성일자리,기업정보,공사채용,취직,JOB,잡,인크루트,incruit" name="Keywords"/>
#   <meta content="https://job.incruit.com/jobdb_list/searchjob.asp?kw=%C0%DA%C0%B2%C1%D6%C7%E0&amp;rgn2=11&amp;rgn2=18" property="og:url"/>
#   <meta content=" 서울특별시,경기도 자율주행 :: 인크루트 채용정보" property="og:title"/>
# ...

# %% [markdown]
# ### 1차 크롤링 (회사명. 회사 링크)

# %%
company_list = []

for i in range(1,4):
    url = "https://job.incruit.com/jobdb_list/searchjob.asp?kw=%C0%DA%C0%B2%C1%D6%C7%E0&rgn2=11&rgn2=18&page={page_number}"        # 자신의 찾으려는 웹사이트 입력
    req = Request(url.format(page_number = urllib.parse.quote(str(i))))
    res = urlopen(req)
    soup = BeautifulSoup(res, "html.parser")
    
    element = soup.find_all('ul',class_='c_row')
    for each in element:
        cl_top = each.find('div',class_='cl_top')
        cell_mid = each.find('div',class_='cell_mid')

        company = []
        name = each.find('a',class_='cpname').string    # 회사이름
        link = each.find('a',class_='cpname')['href']

        company.append(name)
        company.append(link)
        company_list.append(company)

# %%
company_list
# Out:
# [['(주)에이알247', 'https://www.incruit.com/company/1682843434'],
#  ['쓰리핸즈', 'https://www.incruit.com/company/1685388129'],
#  ['매버릭컨설팅(주)', 'https://www.incruit.com/company/934472'],
#  ['현대자동차(주)', 'https://www.incruit.com/company/1682257672'],
#  ['(주)에이알247', 'https://www.incruit.com/company/1682843434'],
#  ['현대자동차(주)', 'https://www.incruit.com/company/1682257672'],
#  ['(주)에이알247', 'https://www.incruit.com/company/1682843434'],
#  ['쓰리핸즈', 'https://www.incruit.com/company/1685388129'],
#  ['현대자동차(주)', 'https://www.incruit.com/company/1682257672'],
#  ['매버릭컨설팅(주)', 'https://www.incruit.com/company/934472'],
#  ['쓰리핸즈', 'https://www.incruit.com/company/1685388129'],
#  ['쓰리핸즈', 'https://www.incruit.com/company/1685388129'],
#  ['코가로보틱스(주)', 'https://www.incruit.com/company/1684206860'],
#  ['(주)조인스에이치알코리아', 'https://www.incruit.com/company/1678710127'],
#  ['(주)조인스에이치알코리아', 'https://www.incruit.com/company/1678710127'],
#  ['(주)에바', 'https://www.incruit.com/company/1680817418'],
# ...

# %%
import pandas as pd 
autocar_df = pd.DataFrame(company_list, columns=['회사명', '링크'])

# %%
autocar_df['링크']
# Out:
#                 회사명                                          링크
# 0         (주)에이알247  https://www.incruit.com/company/1682843434
# 1              쓰리핸즈  https://www.incruit.com/company/1685388129
# 2         매버릭컨설팅(주)      https://www.incruit.com/company/934472
# 3          현대자동차(주)  https://www.incruit.com/company/1682257672
# 4         (주)에이알247  https://www.incruit.com/company/1682843434
# ..              ...                                         ...
# 118       주식회사애니랙티브  https://www.incruit.com/company/1681585926
# 119      나노융합산업연구조합      https://www.incruit.com/company/524624
# 120  (주) 실리콘스튜디오코리아     https://www.incruit.com/company/1941449
# 121        한국교통안전공단                                           #
# 122      현대엠시스템즈(주)                                           #
#
# [123 rows x 2 columns]

# %% [markdown]
# ### 2차크롤링 테스트

# %%
url = "https://www.incruit.com/company/1684206860"        # 자신의 찾으려는 웹사이트 입력
res = urlopen(url)
soup = BeautifulSoup(res, "html.parser")
# print(soup.prettify())

table =  soup.find(class_='table_li')
li1 = table.find_all('li')[1]
li2 = table.find_all('li')[4]
li3 = table.find_all('li')[6]
print(li1.get_text())
print(li2.get_text())
print(li3.get_text())
print('------------------')

rev = soup.find(class_='table_b sub_table')
tbody = rev.find('tbody')
r1 = tbody.find_all('tr')[0]
r2 = tbody.find_all('tr')[1]
r3 = tbody.find_all('tr')[2]

# print(rev.get_text())
print(r1.get_text())
print(r2.get_text())
print(r3.get_text())
print('------------------')
# Out:
# 기업규모중소기업
# 매출액 3억 7,179만원 (2022)
# 평균연봉4,578만원 자세히보기
# ------------------
# 2022 239억 8,977만원
# ↑ 3억 7,179만원
# ↓- 83억 5,304만원
# ↓
# 2021 10억 1,575만원
# ↑ 15억 6,842만원
# ↑ 6억 623만원
# ↑
# 2020 7억 7,147만원
#  7억 4,946만원
#  3억 7,414만원
#
# ------------------

# %%
autocar_df = autocar_df[autocar_df['링크'].str.contains('http')]

# %%
autocar_df
# Out:
#                 회사명                                          링크
# 0         (주)에이알247  https://www.incruit.com/company/1682843434
# 1              쓰리핸즈  https://www.incruit.com/company/1685388129
# 2         매버릭컨설팅(주)      https://www.incruit.com/company/934472
# 3          현대자동차(주)  https://www.incruit.com/company/1682257672
# 4         (주)에이알247  https://www.incruit.com/company/1682843434
# ..              ...                                         ...
# 116    오픈엣지테크놀로지(주)  https://www.incruit.com/company/1683416684
# 117       (주)두원전자통신  https://www.incruit.com/company/1660060677
# 118       주식회사애니랙티브  https://www.incruit.com/company/1681585926
# 119      나노융합산업연구조합      https://www.incruit.com/company/524624
# 120  (주) 실리콘스튜디오코리아     https://www.incruit.com/company/1941449
#
# [121 rows x 2 columns]

# %% [markdown]
# ### 2차크롤링

# %%
from tqdm import tqdm 
from user_agent import generate_user_agent

info_list = []
r1_list = []
r2_list = []
r3_list = []


for idx, row in tqdm(autocar_df.iterrows(), total=len(autocar_df.index)):
    req = Request(url=row['링크'], headers={'User-Agent':generate_user_agent()})
    page = urlopen(req)
    soup = BeautifulSoup(page, 'html.parser')

    try:
        table =  soup.find(class_='table_li')
        info_list.append(table.get_text())
    except:
        info_list.append('-')     

    try:    
        rev = soup.find(class_='table_b sub_table')
        tbody = rev.find('tbody')
        r1 = tbody.find_all('tr')[0]
        r2 = tbody.find_all('tr')[1]
        r3 = tbody.find_all('tr')[2]
    
        r1_list.append(r1.get_text())
        r2_list.append(r2.get_text())
        r3_list.append(r3.get_text())

    except:
        r1_list.append('-')
        r2_list.append('-')
        r3_list.append('-')
# Out:
# 100%|██████████| 121/121 [00:38<00:00,  3.10it/s]

# %%
info_list,r1_list,r2_list,r3_list
# Out:
# (['기업명(주)에이알247기업규모중소기업대표자최인혜설립일1996년 3월 18일 매출액-사원수 7 명 재직중평균연봉4,108만원 자세히보기자본금-업종유통',
#   '기업명쓰리핸즈기업규모소기업대표자하준우설립일2022년 4월 1일 매출액-사원수 10 명 재직중 (헤드헌터 5 명)자본금-업종용역·인력알선',
#   '기업명매버릭컨설팅(주)기업규모중소기업대표자이용구설립일2000년 7월 13일 매출액-사원수 8 명 재직중 (헤드헌터 6 명)자본금-업종용역·인력알선',
#   '기업명현대자동차(주)기업규모대기업대표자이동석,장재훈,정의선설립일1967년 12월 29일 매출액 49조 1,556억 9,300만원 (2019)사원수-평균연봉7,371만원 자세히보기자본금 1조 4,889억 9,300만원업종기계·조선·자동차·운송장비',
#   '기업명(주)에이알247기업규모중소기업대표자최인혜설립일1996년 3월 18일 매출액-사원수 7 명 재직중평균연봉4,108만원 자세히보기자본금-업종유통',
#   '기업명현대자동차(주)기업규모대기업대표자이동석,장재훈,정의선설립일1967년 12월 29일 매출액 49조 1,556억 9,300만원 (2019)사원수-평균연봉7,371만원 자세히보기자본금 1조 4,889억 9,300만원업종기계·조선·자동차·운송장비',
#   '기업명(주)에이알247기업규모중소기업대표자최인혜설립일1996년 3월 18일 매출액-사원수 7 명 재직중평균연봉4,108만원 자세히보기자본금-업종유통',
#   '기업명쓰리핸즈기업규모소기업대표자하준우설립일2022년 4월 1일 매출액-사원수 10 명 재직중 (헤드헌터 5 명)자본금-업종용역·인력알선',
#   '기업명현대자동차(주)기업규모대기업대표자이동석,장재훈,정의선설립일1967년 12월 29일 매출액 49조 1,556억 9,300만원 (2019)사원수-평균연봉7,371만원 자세히보기자본금 1조 4,889억 9,300만원업종기계·조선·자동차·운송장비',
# ...

# %%
autocar_df['info'] = info_list
autocar_df['r1'] = r1_list
autocar_df['r2'] = r2_list
autocar_df['r3'] = r3_list
# Out:
# /tmp/ipykernel_20996/592973535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autocar_df['info'] = info_list
# /tmp/ipykernel_20996/592973535.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autocar_df['r1'] = r1_list
# /tmp/ipykernel_20996/592973535.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
autocar_df['기업규모'] =  autocar_df['info'].str.split('기업규모').str[1]
autocar_df['매출액'] =  autocar_df['기업규모'].str.split('매출액').str[1]
autocar_df['평균연봉'] =  autocar_df['매출액'].str.split('평균연봉').str[1]
# Out:
# /tmp/ipykernel_20996/401625601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autocar_df['기업규모'] =  autocar_df['info'].str.split('기업규모').str[1]
# /tmp/ipykernel_20996/401625601.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autocar_df['매출액'] =  autocar_df['기업규모'].str.split('매출액').str[1]
# /tmp/ipykernel_20996/401625601.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
autocar_df['기업규모'] =  autocar_df['기업규모'].str.split('대표자').str[0]
autocar_df['매출액'] =  autocar_df['매출액'].str.split('사원수').str[0]
# Out:
# /tmp/ipykernel_20996/3435722962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autocar_df['기업규모'] =  autocar_df['기업규모'].str.split('대표자').str[0]
# /tmp/ipykernel_20996/3435722962.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autocar_df['매출액'] =  autocar_df['매출액'].str.split('사원수').str[0]

# %%
autocar_df['평균연봉'] =  autocar_df['평균연봉'].str.split('자세히보기').str[0]
# Out:
# /tmp/ipykernel_20996/3713421440.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autocar_df['평균연봉'] =  autocar_df['평균연봉'].str.split('자세히보기').str[0]

# %%
autocar_df.iloc[:,6:9]
# Out:
#      기업규모                         매출액      평균연봉
# 0    중소기업                           -  4,108만원
# 1     소기업                           -       NaN
# 2    중소기업                           -       NaN
# 3     대기업   49조 1,556억 9,300만원 (2019)  7,371만원
# 4    중소기업                           -  4,108만원
# ..    ...                         ...       ...
# 116  중소기업         100억 1,168만원 (2022)  6,473만원
# 117  중소기업         334억 3,666만원 (2022)  4,382만원
# 118  중소기업            22억 104만원 (2022)       NaN
# 119  중소기업                           -  6,165만원
# 120  중소기업          49억 1,500만원 (2020)  4,552만원
#
# [121 rows x 3 columns]

# %%
autocar_df.iloc[:,3:6]
# Out:
#                                                     r1  \
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 116  2022 340억 6,848만원\n↑ 100억 1,168만원\n↑- 247억 8,5...
# 117  2022 136억 6,881만원\n↑ 334억 3,666만원\n↓ 1억 5,420만...
# 118   2022 59억 6,381만원\n↓ 22억 104만원\n↑- 31억 6,896만원\n↓
# 119                                                  -
# 120      2016 11억 1,974만원\n↑ 11억 3,107만원\n↓ 1,611만원\n↓
#
#                                                     r2  \
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3                                                    -
# ...

# %%
autocar_df['자본총계1'] =  autocar_df['r1'].str.split('\n').str[0]
autocar_df['자본총계2'] =  autocar_df['r2'].str.split('\n').str[0]
autocar_df['자본총계3'] =  autocar_df['r3'].str.split('\n').str[0]

autocar_df['매출액1'] =  autocar_df['r1'].str.split('\n').str[1]
autocar_df['매출액2'] =  autocar_df['r2'].str.split('\n').str[1]
autocar_df['매출액3'] =  autocar_df['r3'].str.split('\n').str[1]

autocar_df['순이익1'] =  autocar_df['r1'].str.split('\n').str[2]
autocar_df['순이익2'] =  autocar_df['r2'].str.split('\n').str[2]
autocar_df['순이익3'] =  autocar_df['r3'].str.split('\n').str[2]
# Out:
# /tmp/ipykernel_20996/3403067393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autocar_df['자본총계1'] =  autocar_df['r1'].str.split('\n').str[0]
# /tmp/ipykernel_20996/3403067393.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autocar_df['자본총계2'] =  autocar_df['r2'].str.split('\n').str[0]
# /tmp/ipykernel_20996/3403067393.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
autocar_df.head(1)
autocar_df.drop(columns=['링크','info','r1','r2','r3'], inplace=True)
# Out:
# /tmp/ipykernel_20996/263736299.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autocar_df.drop(columns=['링크','info','r1','r2','r3'], inplace=True)

# %%
autocar_df.to_csv('../../data/eda_project_data/auto_rev2.csv')

# %%
autocar_df.fillna('-')
# Out:
#                 회사명  기업규모                         매출액      평균연봉  \
# 0         (주)에이알247  중소기업                           -  4,108만원
# 1              쓰리핸즈   소기업                           -         -
# 2         매버릭컨설팅(주)  중소기업                           -         -
# 3          현대자동차(주)   대기업   49조 1,556억 9,300만원 (2019)  7,371만원
# 4         (주)에이알247  중소기업                           -  4,108만원
# ..              ...   ...                         ...       ...
# 116    오픈엣지테크놀로지(주)  중소기업         100억 1,168만원 (2022)  6,473만원
# 117       (주)두원전자통신  중소기업         334억 3,666만원 (2022)  4,382만원
# 118       주식회사애니랙티브  중소기업            22억 104만원 (2022)         -
# 119      나노융합산업연구조합  중소기업                           -  6,165만원
# 120  (주) 실리콘스튜디오코리아  중소기업          49억 1,500만원 (2020)  4,552만원
#
#                  자본총계1              자본총계2               자본총계3            매출액1  \
# 0                    -                  -                   -               -
# ...

# %%
import pandas as pd 
autocar_df = pd.read_csv('../../data/eda_project_data/auto_rev2.csv')

# %%
autocar_df.drop(columns=['Unnamed: 0'],inplace=True)

# %% [markdown]
# ### 통화 변환 함수

# %%
import pandas as pd

# 예제 데이터프레임
data = {'금액': ['- 1,000억 5,000만원', '3,000억원', '500원', '10억 2,000만원', '6,848원', '1조 5,000억 3,000만원', '- 11억 578만원']}
df = pd.DataFrame(data)

def convert_currency_to_int(value):
    if isinstance(value, (float, int)):
        return int(value)

    result = 0
    is_negative = False

    # '억' 또는 '억원' 다음에 '원'이 오는 경우를 처리
    value = value.replace('억원', '억 원')

    for part in value.split():
        if '조' in part:
            result += int(part.replace('조', '').replace(',', '')) * 10**8
        elif '억' in part or '억원' in part:
            result += int(part.replace('억', '').replace('억원', '').replace(',', '')) * 10**4
        elif '만원' in part:
            result += int(part.replace('만원', '').replace(',', ''))
        elif '원' in part:
            result += 0
        elif '-' in part:
            is_negative = True

    return -result if is_negative else result

# '금액' 열에 함수 적용
df['금액'] = df['금액'].apply(convert_currency_to_int)

# 결과 표시
print(df)
# Out:
#           금액
# 0  -10005000
# 1   30000000
# 2          0
# 3     102000
# 4          0
# 5  150003000
# 6    -110578

# %%
autocar_df['평균연봉'] = pd.to_numeric(autocar_df['평균연봉'].str.replace(',', '').str.replace('만원', ''), errors='coerce').astype('Int64')

# %%
autocar_df['매출액1'] = autocar_df['매출액1'].str.replace('↑','')
autocar_df['매출액2'] = autocar_df['매출액2'].str.replace('↑','')
autocar_df['매출액3'] = autocar_df['매출액3'].str.replace('↑','')
autocar_df['순이익1'] = autocar_df['순이익1'].str.replace('↑','')
autocar_df['순이익2'] = autocar_df['순이익2'].str.replace('↑','')
autocar_df['순이익3'] = autocar_df['순이익3'].str.replace('↑','')

autocar_df['매출액1'] = autocar_df['매출액1'].str.replace('↓','')
autocar_df['매출액2'] = autocar_df['매출액2'].str.replace('↓','')
autocar_df['매출액3'] = autocar_df['매출액3'].str.replace('↓','')
autocar_df['순이익1'] = autocar_df['순이익1'].str.replace('↓','')
autocar_df['순이익2'] = autocar_df['순이익2'].str.replace('↓','')
autocar_df['순이익3'] = autocar_df['순이익3'].str.replace('↓','')

# %%
autocar_df
# Out:
#                 회사명  기업규모                         매출액  평균연봉  \
# 0         (주)에이알247  중소기업                           -  4108
# 1              쓰리핸즈   소기업                           -  <NA>
# 2         매버릭컨설팅(주)  중소기업                           -  <NA>
# 3          현대자동차(주)   대기업   49조 1,556억 9,300만원 (2019)  7371
# 4         (주)에이알247  중소기업                           -  4108
# ..              ...   ...                         ...   ...
# 116    오픈엣지테크놀로지(주)  중소기업         100억 1,168만원 (2022)  6473
# 117       (주)두원전자통신  중소기업         334억 3,666만원 (2022)  4382
# 118       주식회사애니랙티브  중소기업            22억 104만원 (2022)  <NA>
# 119      나노융합산업연구조합  중소기업                           -  6165
# 120  (주) 실리콘스튜디오코리아  중소기업          49억 1,500만원 (2020)  4552
#
#                  자본총계1              자본총계2               자본총계3           매출액1  \
# 0                    -                  -                   -            NaN
# 1                    -                  -                   -            NaN
# ...

# %%
autocar_df['매출액1'] = autocar_df['매출액1'].fillna(0).apply(convert_currency_to_int)
autocar_df['매출액2'] = autocar_df['매출액2'].fillna(0).apply(convert_currency_to_int)
autocar_df['매출액3'] = autocar_df['매출액3'].fillna(0).apply(convert_currency_to_int)


autocar_df['순이익1'] = autocar_df['순이익1'].fillna(0).apply(convert_currency_to_int)
autocar_df['순이익2'] = autocar_df['순이익2'].fillna(0).apply(convert_currency_to_int)
autocar_df['순이익3'] = autocar_df['순이익3'].fillna(0).apply(convert_currency_to_int)

# %%
autocar_df['매출액'] =  autocar_df['매출액'].str.split('(').str[0]

# %%
autocar_df.to_csv('../../data/eda_project_data/auto_rev3.csv')

# %%
autocar_df['매출액'] = autocar_df['매출액'].fillna(0).apply(convert_currency_to_int)

# %%
autocar_df.iloc[:,1:6]
# Out:
#      기업규모         매출액  평균연봉              자본총계1              자본총계2
# 0    중소기업           0  4108                  -                  -
# 1     소기업           0  <NA>                  -                  -
# 2    중소기업           0  <NA>                  -                  -
# 3     대기업  4915569300  7371                  -                  -
# 4    중소기업           0  4108                  -                  -
# ..    ...         ...   ...                ...                ...
# 116  중소기업     1001168  6473  2022 340억 6,848만원  2021 221억 3,247만원
# 117  중소기업     3343666  4382  2022 136억 6,881만원  2021 135억 6,231만원
# 118  중소기업      220104  <NA>   2022 59억 6,381만원   2021 76억 3,278만원
# 119  중소기업           0  6165                  -                  -
# 120  중소기업      491500  4552   2016 11억 1,974만원     2015 11억 541만원
#
# [121 rows x 5 columns]

# %%
autocar_df['기준년도'] = autocar_df['자본총계1'].str.extract(r'(\d{4})', expand=False)

# %%
autocar_df['자본총계1'] = autocar_df['자본총계1'].str.replace('2022', '')
autocar_df['자본총계2'] = autocar_df['자본총계2'].str.replace('2021', '')
autocar_df['자본총계3'] = autocar_df['자본총계3'].str.replace('2020', '')
autocar_df['자본총계1'] = autocar_df['자본총계1'].str.replace('2016', '')
autocar_df['자본총계2'] = autocar_df['자본총계2'].str.replace('2015', '')
autocar_df['자본총계3'] = autocar_df['자본총계3'].str.replace('2014', '')

# %%
autocar_df['자본총계1'] = autocar_df['자본총계1'].fillna(0).apply(convert_currency_to_int)
autocar_df['자본총계2'] = autocar_df['자본총계2'].fillna(0).apply(convert_currency_to_int)
autocar_df['자본총계3'] = autocar_df['자본총계3'].fillna(0).apply(convert_currency_to_int)

# %%
autocar_df['기준년도']= autocar_df['기준년도'].fillna(0).astype(int)

# %%
autocar_df.drop(columns=['기준년도1 ','기준년도 '],inplace=True)

# %%
autocar_df['평균연봉']= autocar_df['평균연봉'].fillna(0).astype(int)

# %%
autocar_df.rename(columns={'회사명':'기업이름'},inplace=True)

# %%
unique_companies = autocar_df.drop_duplicates(subset='기업이름')

# %%
unique_companies.reset_index(drop=True,inplace=True)

# %%
unique_companies.to_csv('../../data/eda_project_data/auto_rev_syt.csv')
