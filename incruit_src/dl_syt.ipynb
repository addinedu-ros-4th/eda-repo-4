# %% [markdown]
# # 딥러닝 크롤링

# %%
from tqdm.notebook import tqdm
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.request import Request
import urllib

# %% [markdown]
# ### 1차 크롤링

# %%
company_list = []

for i in range(1,3):
    url = "https://job.incruit.com/jobdb_list/searchjob.asp?kw=%B5%F6%B7%AF%B4%D7&rgn2=11&page={page_number}"        # 자신의 찾으려는 웹사이트 입력
    req = Request(url.format(page_number = urllib.parse.quote(str(i))))
    res = urlopen(req)
    soup = BeautifulSoup(res, "html.parser")
    
    element = soup.find_all('ul',class_='c_row')
    for each in element:
        cl_top = each.find('div',class_='cl_top')
        cell_mid = each.find('div',class_='cell_mid')

        company = []
        name =each.find('a',class_='cpname').string    # 회사이름
        title = cell_mid.find(class_='cl_top').get_text()   # 모집명
        link = cell_mid.find('a')['href']                  # 링크
        info = cell_mid.find(class_='cl_md').get_text()     # 경력 학력 주소 연봉
        field = cell_mid.find(class_='cl_btm').get_text()  # 분야

        company.append(name)
        company.append(title)
        company.append(link)
        company.append(info)
        company.append(field)
        company_list.append(company)

# %%
company_list
# Out:
# [['(주)커리어케어',
#   '\n머신러닝, 딥러닝 경력  채용\n스크랩\n',
#   'https://job.incruit.com/jobdb_info/jobpost.asp?job=2307120001694&src=gsw*etc',
#   '\n경력3년↑ 석사이상\n서울 강남구 정규직\n',
#   '\n빅데이터·AI(인공지능)\n'],
#  ['(주)메디픽셀',
#   '\n[메디픽셀] 딥러닝 & SW 개발 엔지니어 채용\n스크랩\n',
#   'https://job.incruit.com/jobdb_info/jobpost.asp?job=2201140004421&src=gsw*etc',
#   '\n경력5년↑ 대졸\n서울 마포구 정규직\n',
#   '\n응용프로그래머, 빅데이터·AI(인공지능)\n'],
#  ['(주)유비소시어스',
#   '\n[딥러닝개발] 전자부품 전문기업, 딥러닝 AI 알고리즘 개발 경력자 모집\n스크랩\n',
#   'https://job.incruit.com/jobdb_info/jobpost.asp?job=2301300004876&src=gsw*etc',
#   '\n경력6년↑ 대졸이상\n서울 구로구 정규직\n',
#   '\n응용프로그래머\n'],
#  ['글로빛주식회사',
#   '\n글로빛논문컨설팅 빅데이터 분석,AI(머신러닝,딥러닝)박사 모집\n스크랩\n',
#   'https://job.incruit.com/jobdb_info/jobpost.asp?job=2211090000441&src=gsw*etc',
#   '\n신입/경력(연차무관) 박사이상\n서울 (재택근무 (재택근무 가능) 계약직외 건별\n',
#   '\n대학(교)강사·교수, 교육·교재개발\n'],
#  ['(주)위드브레인',
#   '\n머신러닝/딥러닝-영상인식 / 머신비젼 / AI-SW개발자 채용\n스크랩\n',
# ...

# %%
import pandas as pd 
dl_df = pd.DataFrame(company_list, columns=['기업이름', '모집명','링크','info','담당업무'])

# %%
dl_df.head()
# Out:
#         기업이름                                                모집명  \
# 0   (주)커리어케어                          \n머신러닝, 딥러닝 경력  채용\n스크랩\n
# 1    (주)메디픽셀                \n[메디픽셀] 딥러닝 & SW 개발 엔지니어 채용\n스크랩\n
# 2  (주)유비소시어스  \n[딥러닝개발] 전자부품 전문기업, 딥러닝 AI 알고리즘 개발 경력자 모집\n스크랩\n
# 3    글로빛주식회사        \n글로빛논문컨설팅 빅데이터 분석,AI(머신러닝,딥러닝)박사 모집\n스크랩\n
# 4   (주)위드브레인        \n머신러닝/딥러닝-영상인식 / 머신비젼 / AI-SW개발자 채용\n스크랩\n
#
#                                                   링크  \
# 0  https://job.incruit.com/jobdb_info/jobpost.asp...
# 1  https://job.incruit.com/jobdb_info/jobpost.asp...
# 2  https://job.incruit.com/jobdb_info/jobpost.asp...
# 3  https://job.incruit.com/jobdb_info/jobpost.asp...
# 4  https://job.incruit.com/jobdb_info/jobpost.asp...
#
#                                                info  \
# 0                        \n경력3년↑ 석사이상\n서울 강남구 정규직\n
# 1                          \n경력5년↑ 대졸\n서울 마포구 정규직\n
# 2                        \n경력6년↑ 대졸이상\n서울 구로구 정규직\n
# ...

# %%
dl_df['고용형태'] = dl_df['info'].str.split('\n').str[1]
dl_df['연봉'] = dl_df['info'].str.split('\n').str[2]
dl_df['모집명'] = dl_df['모집명'].str.split('\n').str[1]
dl_df['담당업무'] = dl_df['담당업무'].str.replace('\n', '')
dl_df['경력'] = dl_df['고용형태'].str.split(' ').str[0]

# %%
dl_df
# Out:
#                기업이름                                             모집명  \
# 0          (주)커리어케어                                머신러닝, 딥러닝 경력  채용
# 1           (주)메디픽셀                      [메디픽셀] 딥러닝 & SW 개발 엔지니어 채용
# 2         (주)유비소시어스        [딥러닝개발] 전자부품 전문기업, 딥러닝 AI 알고리즘 개발 경력자 모집
# 3           글로빛주식회사              글로빛논문컨설팅 빅데이터 분석,AI(머신러닝,딥러닝)박사 모집
# 4          (주)위드브레인              머신러닝/딥러닝-영상인식 / 머신비젼 / AI-SW개발자 채용
# ..              ...                                             ...
# 97    주식회사 딥브레인에이아이                           [인공지능기업] 풀스택 개발자 (경력)
# 98    한국폴리텍대학 성남캠퍼스                       [전액무료] 하이테크 과정 교육생  2차 모집
# 99       나노융합산업연구조합           (재직자/무료) 소재/부품 분야 재직자 AI 역량 강화 교육생 모집
# 100  SK플래닛 Tacademy                      SK플래닛 T아카데미 ASAC 5기 교육생 모집
# 101  (주) 실리콘스튜디오코리아  2024년 상반기 실리콘스튜디오코리아 부문별 채용[가상현실 엔지니어,AI 엔지니어]
#
#                                                     링크  \
# 0    https://job.incruit.com/jobdb_info/jobpost.asp...
# ...

# %%
import re
dl_df['연봉'] = dl_df['연봉'].apply(lambda x: ''.join(re.findall(r'월급[\s\S]*[\d,~]+|[\d,~]+', x)) if re.search(r'월급|[\d,~]', x) else None)

# %%
dl_df.drop(columns=['info','고용형태'], inplace=True)

# %% [markdown]
# ### 키워드 삽입

# %%
cate_list = []
for i in range(1,103):
    cate_list.append('딥러닝')

# %%
dl_df['키워드'] = cate_list

# %% [markdown]
# ### 2차 크롤링

# %%
from tqdm import tqdm 
from user_agent import generate_user_agent

address_list = []
link2_list = []

for idx, row in tqdm(dl_df.iterrows(), total=len(dl_df.index)):
    req = Request(url=row['링크'], headers={'User-Agent':generate_user_agent()})
    page = urlopen(req)
    soup = BeautifulSoup(page, 'html.parser')

    try:
        company = soup.find(class_='jcinfo_list last')
        address = company.get_text()
        address_list.append(address)
    except (AttributeError, IndexError):
        address_list.append(None)

    try:
        link = soup.find_all('div',class_='section_view_layout')[1]
        link2 = link.find('iframe',id='ifrmJobCont')['src']
        link2_list.append(link2)
    except (AttributeError, IndexError):
        link2_list.append(None)
# Out:
# 100%|██████████| 102/102 [01:19<00:00,  1.29it/s]

# %%
address_list, link2_list
# Out:
# (['복리후생 주5일근무, 연차, 월차, 경조휴가, 반차, 육아휴직, 국민연금, 의료보험, 산재보험, 고용...  +   주5일근무, 연차, 월차, 경조휴가, 반차, 육아휴직 국민연금, 의료보험, 산재보험, 고용보험 사내동호회, 워크샵 인센티브, 우수사원포상, 퇴직금, 명절선물 듀얼모니터, 통신비 지원     주소  (06167) 서울특별시 강남구 테헤란로87길 35 5-8층 (삼성동,씨엔드에치빌딩) 커리어케어 지도보기    홈페이지  http://www.careercare.co.kr/   ',
#   '복리후생 주5일근무, 연차, 경조휴가, 반차, 포상휴가, 육아휴직, 남성출산휴가, 국민연금, 의료보...  +   주5일근무, 연차, 경조휴가, 반차, 포상휴가, 육아휴직, 남성출산휴가 국민연금, 의료보험, 산재보험, 고용보험 자기개발지원, 직무능력향상교육, 도서구입비지원, 사내외국어교육 인센티브, 우수사원포상, 장기근속자포상, 퇴직금, 명절선물, 스톡옵션, 장기근속수당, 경조사 지원 식대지원, 듀얼모니터, 간식제공, 건강검진     주소  (04037) 서울특별시 마포구 양화로 61 7층 (서교동,두암빌딩) 지도보기    홈페이지  http://www.medipixel.io   ',
#   '복리후생 주5일근무, 연차, 월차, 경조휴가, 국민연금, 의료보험, 산재보험, 고용보험, 휴양시설, ...  +   주5일근무, 연차, 월차, 경조휴가 국민연금, 의료보험, 산재보험, 고용보험 휴양시설 인센티브, 퇴직금 식대지원 전국콘도이용, 중식제공, 경조사, 생일자축하, 우수사원포창, 워크샵 등     주소  (08505) 서울특별시 금천구 가산디지털2로 123 월드메르디앙2차 1110호, 1116호 지도보기    홈페이지  http://www.ubsocius.com   ',
#   '     주소  (06627) 서울특별시 서초구 사임당로 174 (서초동,강남미래타워) 지도보기    홈페이지  http://www.globit.kr   ',
# ...

# %%
dl_df['주소'] = address_list
dl_df['링크2'] = link2_list

# %%
import re

# 주소 열에서 주소라는 단어를 발견했을 때 이후의 문자열을 추출하는 함수
def extract_address(text):
    if isinstance(text, str):  # 문자열인 경우에만 처리
        match = re.search(r'주소\s*(.*)', text)
        return match.group(1) if match else None
    else:
        return None

# 주소 열에 적용하여 새로운 열 생성
dl_df['추출된_주소'] = dl_df['주소'].apply(extract_address)

# 결과 확인
print(dl_df[['주소', '추출된_주소']])
# Out:
#                                                     주소  \
# 0    복리후생 주5일근무, 연차, 월차, 경조휴가, 반차, 육아휴직, 국민연금, 의료보험...
# 1    복리후생 주5일근무, 연차, 경조휴가, 반차, 포상휴가, 육아휴직, 남성출산휴가, ...
# 2    복리후생 주5일근무, 연차, 월차, 경조휴가, 국민연금, 의료보험, 산재보험, 고용...
# 3         주소  (06627) 서울특별시 서초구 사임당로 174 (서초동,강남미래타...
# 4    복리후생 주5일근무, 연차, 월차, 보건휴가, 경조휴가, 국민연금, 의료보험, 산재...
# ..                                                 ...
# 97   복리후생 주5일근무, 연차, 월차, 국민연금, 의료보험, 산재보험, 고용보험, 자기...
# 98        주소  (13122) 경기 성남시 수정구 수정로 398 (산성동)    홈...
# 99        주소  (137-140) 서울 서초구 우면동 66-2 세신우면종합상가 40...
# 100       주소  (463-400) 경기도 성남시 분당구 판교로 264 (삼평동,sk...
# 101  복리후생 주5일근무, 연차, 경조휴가, 창립일휴무, 국민연금, 의료보험, 산재보험,...
#
#                                                 추출된_주소
# 0    (06167) 서울특별시 강남구 테헤란로87길 35 5-8층 (삼성동,씨엔드에치빌딩...
# 1    (04037) 서울특별시 마포구 양화로 61 7층 (서교동,두암빌딩) 지도보기   ...
# 2    (08505) 서울특별시 금천구 가산디지털2로 123 월드메르디앙2차 1110호, ...
# 3    (06627) 서울특별시 서초구 사임당로 174 (서초동,강남미래타워) 지도보기  ...
# ...

# %%
dl_df.drop(columns=['주소'],inplace=True)

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
from tqdm import tqdm 
from user_agent import generate_user_agent

list3 = []

for idx, row in tqdm(dl_df.iterrows(), total=len(dl_df.index)):
    req = Request(url=row['링크2'], headers={'User-Agent':generate_user_agent()})
    page = urlopen(req)
    soup = BeautifulSoup(page, 'html.parser')

    tbody = soup.get_text()
    list3.append(tbody)
# Out:
# 100%|██████████| 102/102 [00:18<00:00,  5.59it/s]

# %%
list3
# Out:
# ['\n\n\n머신러닝, 딥러닝 경력  채용 - 인크루트 채용\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n우리 회사를 한 줄로 표현해주세요\n\n머신러닝, 딥러닝 경력  채용\n\n\n우리 회사에 대해 4줄 이내로 소개해주세요\n\n\n모집부문 및 자격요건\n\n\n\n\n\n\n\n\n\n모집부문\n담당업무\n자격요건\n인원\n\n\n\n\nMachine Learning• 신약 개발 관련 인공지능 모델 구현\n• 데이터 큐레이션 및 데이터에 맞는 최적의 학습방법 고도화\n• 인공지능 최신 논문 서치 및 세미나, 관련 내용 구현\n• 기 구축 된 인공 지능 모델 튜닝 및 제품/서비스 화• 컴퓨터 공학과 혹은 관련학과 졸업자\n• 빠르게 성장하는 스타트업에서 능동적이고 자기주도적으로 업무를 꼼꼼하게 처리 하시는 분\n• 머신러닝 / 딥러닝 관련 프로젝트를 하나 이상 end-to-end로 수행해 보신분\n• 머신러닝 / 딥러닝 관련 오픈 소스 및 관련 논문 파악에 무리가\r\n없으신 분\n• 여러 딥러닝 프레임워크 활용 및 python 코드 구현에 능숙하신\r\n분\n• 문제에 봉착했을 때 이를 끝까지 해결해내는 근성을 가지신 분(Get\r\nthings done.)우대사항• 머신러닝/딥러닝 관련 전공 (석사\r\n이상)• 머신러닝 / 딥러닝 분야 3년\r\n이상 경력• 머신러닝 / 딥러닝 프로젝트 리딩 경력• 다양한 머신러닝/딥러닝 모델 구현 경험 및 모델을 직접 튜닝하여\r\n새로운 도메인에 적용해 본 경험• 딥러닝 모델 제품/서비스화 경험• CS 탑 논문 발표 경험\r\n(NIPS, ICML, KDD, AAAI, IJCAI, ACL, NAACL, EMNLP 등)• 제약/바이오/화학/메디컬 필드 지식 소유자\n• 영어 (Written/Verbal) 능통자\n\n\n근무조건\n고용형태: 정규직급여조건: 연봉 협의 후 결정\n\n\n전형단계 및 제출서류\n전형단계: 서류전형 > 면접진행 > 최종심사 > 최종합격추가 제출서류이력서, 자기소개서
# ...

# %%
dl_df['필요역량'] = list3

# %%
dl_df.drop(columns=['링크','링크2'],inplace=True)

# %%
import re

# 주소에서 (숫자) 제거하는 함수
def remove_numbers_in_parentheses(address):
    if pd.isna(address):
        return address
    return re.sub(r'\(\d+\)', '', address)

# '주소' 열에 함수 적용
dl_df['추출된_주소'] = dl_df['추출된_주소'].apply(remove_numbers_in_parentheses)

# %%
dl_df.drop(columns=['모집명'],inplace=True)

# %%
dl_df['추출된_주소'] =  dl_df['추출된_주소'].str.split('지도보기').str[0]
dl_df['추출된_주소'] =  dl_df['추출된_주소'].str.split('홈페이지').str[0]

# %%
dl_df.rename(columns={'경력':'고용형태','추출된_주소':'기업주소'},inplace=True)
new_order = ['기업이름', '고용형태', '연봉', '기업주소', '키워드', '담당업무', '필요역량']
drone_df = dl_df[new_order]

# %%
dl_df.to_csv('../../data/eda_project_data/DL_syt.csv', sep=',', encoding='utf-8')

# %%
dl_df
# Out:
#                기업이름                                               담당업무    연봉  \
# 0          (주)커리어케어                                      빅데이터·AI(인공지능)  None
# 1           (주)메디픽셀                             응용프로그래머, 빅데이터·AI(인공지능)  None
# 2         (주)유비소시어스                                            응용프로그래머  None
# 3           글로빛주식회사                                대학(교)강사·교수, 교육·교재개발  None
# 4          (주)위드브레인                    소프트웨어·하드웨어, 응용프로그래머, 데이터베이스·DBA  None
# ..              ...                                                ...   ...
# 97    주식회사 딥브레인에이아이                     웹프로그래머, 응용프로그래머, 빅데이터·AI(인공지능)  None
# 98    한국폴리텍대학 성남캠퍼스  연구원·연구개발, 기술영업, 바이오·식품공학, 빅데이터·AI(인공지능), 응용프로그...  None
# 99       나노융합산업연구조합  빅데이터·AI(인공지능), 응용프로그래머, ERP·시스템분석·설계, 전산·IT기술지...  None
# 100  SK플래닛 Tacademy  빅데이터·AI(인공지능), ERP·시스템분석·설계, 데이터베이스·DBA, 응용프로그...  None
# 101  (주) 실리콘스튜디오코리아  응용프로그래머, 네트워크·서버·보안, 빅데이터·AI(인공지능), ERP·시스템분석·...  None
#
# ...
