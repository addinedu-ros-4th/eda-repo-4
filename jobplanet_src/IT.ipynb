# %%
from tqdm.notebook import tqdm
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.request import Request
import urllib
from user_agent import generate_user_agent

# %%
driver = webdriver.Chrome(service=Service('../../../driver/chromedriver'))
driver.get('https://www.jobplanet.co.kr/companies?industry_id=700&page=1')

# %%
import time
from tqdm.notebook import tqdm

# company_list = []

for i in tqdm(range(1,50)):
    time.sleep(1)
    elements = driver.find_elements(By.CLASS_NAME, 'company.content_ty3')
    
    for elem in elements:
        company =[]

        name = elem.find_element(By.CLASS_NAME,'us_titb_l3').text
        field = elem.find_element(By.CLASS_NAME, 'us_stxt_1').text
        point = elem.find_element(By.CLASS_NAME, 'gfvalue').text
        money = elem.find_element(By.CLASS_NAME, 'notranslate').text
        
        company.append(name)
        company.append(field)
        company.append(point)
        company.append(money)
        company_list.append(company)
        print(company)

    driver.find_element(By.CLASS_NAME, 'btn_pgnext').click()
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]
# ['(주)키친구 following', 'IT/웹/통신', '0.0', '0']
# ['(주)킨터치 following', 'IT/웹/통신', '0.0', '0']
# ['(주)타임티켓 following', 'IT/웹/통신', '0.0', '0']
# ['(주)탐코퍼레이션 following', 'IT/웹/통신', '0.0', '0']
# ['(주)태스커 following', 'IT/웹/통신', '0.0', '0']
# ['(주)테리랜드 following', 'IT/웹/통신', '0.0', '0']
# ['(주)테이아 following', 'IT/웹/통신', '0.0', '0']
# ['(주)테크에이스지엑스 following', 'IT/웹/통신', '0.0', '0']
# ['(주)테트라시그넘 following', 'IT/웹/통신', '0.0', '6,036']
# ['(주)텐 following', 'IT/웹/통신', '0.0', '0']
# ['(주)텐디 following', 'IT/웹/통신', '0.0', '4,227']
# ['(주)템스 following', 'IT/웹/통신', '0.0', '0']
# ['(주)토끼표 following', 'IT/웹/통신', '0.0', '0']
# ['(주)투비윈 following', 'IT/웹/통신', '0.0', '0']
# ['(주)투이아이앤씨 following', 'IT/웹/통신', '0.0', '0']
# ['(주)트라이위즈 following', 'IT/웹/통신', '0.0', '0']
# ['(주)트라이즘 following', 'IT/웹/통신', '0.0', '0']
# ['(주)트랄라랩 following', 'IT/웹/통신', '0.0', '0']
# ['(주)트레디팀 following', 'IT/웹/통신', '0.0', '0']
# ['(주)트리피노 following', 'IT/웹/통신', '0.0', '0']
# ['(주)트웬티온스 following', 'IT/웹/통신', '0.0', '0']
# ['(주)트웰브랩스 following', 'IT/웹/통신', '0.0', '0']
# ['(주)트윈소프트 following', 'IT/웹/통신', '0.0', '0']
# ['(주)티아코리아 following', 'IT/웹/통신', '0.0', '0']
# ['(주)티어제이 following', 'IT/웹/통신', '0.0', '0']
# ['(주)티유컨설팅 following', 'IT/웹/통신', '0.0', '0']
# ['(주)티이에스 following', 'IT/웹/통신', '0.0', '0']
# ['(주)티커 following', 'IT/웹/통신', '0.0', '0']
# ['(주)티클 following', 'IT/웹/통신', '0.0', '3,231']
# ['(주)파노믹스 following', 'IT/웹/통신', '0.0', '0']
# ['(주)파라스타 following', 'IT/웹/통신', '0.0', '0']
# ['(주)파로스인포 following', 'IT/웹/통신', '0.0', '0']
# ['(주)파모스 following', 'IT/웹/통신', '0.0', '0']
# ['(주)파이브시그마컨실리움 following', 'IT/웹/통신', '0.0', '0']
# ['(주)파이퍼블릭 following', 'IT/웹/통신', '0.0', '0']
# ['(주)파트리지시스템즈 following', 'IT/웹/통신', '0.0', '0']
# ['(주)팜존에스엔씨 following', 'IT/웹/통신', '0.0', '1,602']
# ['(주)패션을부탁해 following', 'IT/웹/통신', '0.0', '0']
# ['(주)패스트블록 following', 'IT/웹/통신', '0.0', '0']
# ['(주)퍼스트제너레이션 following', 'IT/웹/통신', '0.0', '0']
# ['(주)퍼펫 following', 'IT/웹/통신', '0.0', '0']
# ['(주)퍼폼어스 following', 'IT/웹/통신', '0.0', '0']
# ['(주)퍼풀 following', 'IT/웹/통신', '0.0', '0']
# ['(주)펑션투웰브 following', 'IT/웹/통신', '0.0', '0']
# ['(주)페스타 following', 'IT/웹/통신', '0.0', '0']
# ['(주)포자랩스 following', 'IT/웹/통신', '0.0', '0']
# ['(주)푸씽 following', 'IT/웹/통신', '0.0', '0']
# ['(주)프론티 following', 'IT/웹/통신', '0.0', '0']
# ['(주)플라네타리움랩스코리아 following', 'IT/웹/통신', '0.0', '0']
# ['(주)플래닛12 following', 'IT/웹/통신', '0.0', '0']
# ['(주)플랙스뉴럴랩스 following', 'IT/웹/통신', '0.0', '6,035']
# ['(주)플랜핏 following', 'IT/웹/통신', '0.0', '0']
# ['(주)플럭스플래닛 following', 'IT/웹/통신', '0.0', '4,172']
# ['(주)플레이엔 following', 'IT/웹/통신', '0.0', '0']
# ['(주)플레인베이글 following', 'IT/웹/통신', '0.0', '3,386']
# ['(주)플로워크연구소 following', 'IT/웹/통신', '0.0', '0']
# ['(주)플릿튠 following', 'IT/웹/통신', '0.0', '0']
# ['(주)피니트 following', 'IT/웹/통신', '0.0', '0']
# ['(주)피엠투이엔엠 following', 'IT/웹/통신', '0.0', '0']
# ['(주)피치 following', 'IT/웹/통신', '0.0', '0']
# ['(주)피플후레코드 following', 'IT/웹/통신', '0.0', '0']
# ['(주)픽셀몬스터 following', 'IT/웹/통신', '0.0', '0']
# ['(주)핀포츠 following', 'IT/웹/통신', '0.0', '0']
# ['(주)하트모아 following', 'IT/웹/통신', '0.0', '0']
# ['(주)한국디지털자산수탁 following', 'IT/웹/통신', '0.0', '0']
# ['(주)한국모바일상품권 following', 'IT/웹/통신', '0.0', '0']
# ['(주)해피해킹 following', 'IT/웹/통신', '0.0', '3,372']
# ['(주)핸들 following', 'IT/웹/통신', '0.0', '0']
# ['(주)행복마술사들 following', 'IT/웹/통신', '0.0', '0']
# ['(주)행파이브 following', 'IT/웹/통신', '0.0', '0']
# ['(주)헬로에이아이시스템즈 following', 'IT/웹/통신', '0.0', '0']
# ['(주)호들 following', 'IT/웹/통신', '0.0', '0']
# ['(주)호아이티 following', 'IT/웹/통신', '0.0', '0']
# ['(주)화담소프트 following', 'IT/웹/통신', '0.0', '0']
# ['(주)희원 following', 'IT/웹/통신', '0.0', '0']
# ['(주)히든스카우트 following', 'IT/웹/통신', '0.0', '0']
# ['(주)히츠 following', 'IT/웹/통신', '0.0', '0']
# ['42 MEDIA Corp. following', 'IT/웹/통신', '0.0', '0']
# ['ByteBridge following', 'IT/웹/통신', '0.0', '0']
# ['Chegg Inc. following', 'IT/웹/통신', '0.0', '0']
# ['Dream Communications Company following', 'IT/웹/통신', '0.0', '0']
# ['MobiClix Pte LTD following', 'IT/웹/통신', '0.0', '0']
# ['OLA PARTY PTE. LTD. following', 'IT/웹/통신', '0.0', '0']
# ['PLYNIUS SDN. BHD. following', 'IT/웹/통신', '0.0', '0']
# ['Pulit Inc. following', 'IT/웹/통신', '0.0', '0']
# ['RTB HOUSE PTE. LTD. following', 'IT/웹/통신', '0.0', '0']
# ['SUPERPROF following', 'IT/웹/통신', '0.0', '0']
# ['ZIMI TECH, INC. following', 'IT/웹/통신', '0.0', '0']
# ['강한커뮤니케이션(주) following', 'IT/웹/통신', '0.0', '3,900']
# ['게임디멘션(주) following', 'IT/웹/통신', '0.0', '1,901']
# ['그루네트웍스 following', 'IT/웹/통신', '0.0', '0']
# ['글로벌아이엔피(주) following', 'IT/웹/통신', '0.0', '0']
# ['글로벌이노베이션(주) following', 'IT/웹/통신', '0.0', '0']
# ['글로벌이펙트(주) following', 'IT/웹/통신', '0.0', '8,170']
# ['글로벌케어(주) following', 'IT/웹/통신', '0.0', '3,404']
# ['꿈네트웍스(주) following', 'IT/웹/통신', '0.0', '0']
# ['나노인터렉티브 following', 'IT/웹/통신', '0.0', '0']
# ['나무뉴스코리아 유한책임회사 following', 'IT/웹/통신', '0.0', '0']
# ['나이젤뱅크 following', 'IT/웹/통신', '0.0', '0']
# ['나인그루브(주) following', 'IT/웹/통신', '0.0', '0']
# ['네모드림(주) following', 'IT/웹/통신', '0.0', '2,806']
# ['네트원정보(주) following', 'IT/웹/통신', '0.0', '2,925']
# ['넥스트라인코드 following', 'IT/웹/통신', '0.0', '0']
# ['넥스트러너스(주) following', 'IT/웹/통신', '0.0', '0']
# ['노크앤롤(주) following', 'IT/웹/통신', '0.0', '4,095']
# ['녹원정보기술(주) following', 'IT/웹/통신', '0.0', '3,337']
# ['농업회사법인 네오팜(주) following', 'IT/웹/통신', '0.0', '0']
# ['농정사이버(주) following', 'IT/웹/통신', '0.0', '0']
# ['누스랩(주) following', 'IT/웹/통신', '0.0', '0']
# ['뉴핀(주) following', 'IT/웹/통신', '0.0', '0']
# ['다날게임즈(주) following', 'IT/웹/통신', '0.0', '2,638']
# ['대진 어패럴 following', 'IT/웹/통신', '0.0', '0']
# ['더스토리씨앤티(주) following', 'IT/웹/통신', '0.0', '1,950']
# ['더테스터 following', 'IT/웹/통신', '0.0', '0']
# ['더핸즈 following', 'IT/웹/통신', '0.0', '0']
# ['데이드림랩 following', 'IT/웹/통신', '0.0', '0']
# ['드리머스에듀케이션(주) following', 'IT/웹/통신', '0.0', '3,588']
# ['드림플러스프로덕션(주) following', 'IT/웹/통신', '0.0', '3,833']
# ['디아이오 following', 'IT/웹/통신', '0.0', '0']
# ['디와이오 following', 'IT/웹/통신', '0.0', '0']
# ['디자인스톤(주) following', 'IT/웹/통신', '0.0', '2,050']
# ['디제이홀딩스(주) following', 'IT/웹/통신', '0.0', '0']
# ['디탑툴즈(주) following', 'IT/웹/통신', '0.0', '2,633']
# ['디텍스(주) following', 'IT/웹/통신', '0.0', '0']
# ['디프트(주) following', 'IT/웹/통신', '0.0', '3,042']
# ['라스카(주) following', 'IT/웹/통신', '0.0', '2,412']
# ['라이클리(주) following', 'IT/웹/통신', '0.0', '0']
# ['라인컨설팅(주) following', 'IT/웹/통신', '0.0', '5,125']
# ['랑연soft following', 'IT/웹/통신', '0.0', '0']
# ['랩스튜디오 following', 'IT/웹/통신', '0.0', '0']
# ['러브이즈터치(주) following', 'IT/웹/통신', '0.0', '0']
# ['런시스(주) following', 'IT/웹/통신', '0.0', '0']
# ['레드붐(주) following', 'IT/웹/통신', '0.0', '1,755']
# ['레이지스튜디오 following', 'IT/웹/통신', '0.0', '0']
# ['로그(주) following', 'IT/웹/통신', '0.0', '3,399']
# ['로그컴퍼니 following', 'IT/웹/통신', '0.0', '0']
# ['로직소프트 following', 'IT/웹/통신', '0.0', '0']
# ['리딩타운 following', 'IT/웹/통신', '0.0', '0']
# ['리스펙트스몰머니(주) following', 'IT/웹/통신', '0.0', '0']
# ['마르코 following', 'IT/웹/통신', '0.0', '0']
# ['마인이스(주) following', 'IT/웹/통신', '0.0', '0']
# ['매크로임팩트(주) following', 'IT/웹/통신', '0.0', '2,790']
# ['매터스긱스(주) following', 'IT/웹/통신', '0.0', '11,700']
# ['맥스아이디씨(주) following', 'IT/웹/통신', '0.0', '4,059']
# ['메가펀게임즈(주) following', 'IT/웹/통신', '0.0', '3,075']
# ['메이톰 following', 'IT/웹/통신', '0.0', '0']
# ['명찬시스템 following', 'IT/웹/통신', '0.0', '0']
# ['모두닥(주) following', 'IT/웹/통신', '0.0', '0']
# ['모바일기술연구소(주) following', 'IT/웹/통신', '0.0', '3,315']
# ['모바일유틸리티(주) following', 'IT/웹/통신', '0.0', '2,145']
# ['모아정보(주) following', 'IT/웹/통신', '0.0', '1,845']
# ['모티플로우 following', 'IT/웹/통신', '0.0', '0']
# ['뮤레카(주) 에어모니터 following', 'IT/웹/통신', '0.0', '7,800']
# ['밑줄미디어(주) following', 'IT/웹/통신', '0.0', '0']
# ['바른즐거움(주) following', 'IT/웹/통신', '0.0', '2,460']
# ['바비디(주) following', 'IT/웹/통신', '0.0', '0']
# ['바이블랙(주) following', 'IT/웹/통신', '0.0', '3,118']
# ['발랄한아이티(주) following', 'IT/웹/통신', '0.0', '0']
# ['벨루가브루어리(주) following', 'IT/웹/통신', '0.0', '0']
# ['브릿지세븐 following', 'IT/웹/통신', '0.0', '2,821']
# ['블랙팔콘시큐리티(주) following', 'IT/웹/통신', '0.0', '0']
# ['블록버스커(주) following', 'IT/웹/통신', '0.0', '0']
# ['블루브릭 following', 'IT/웹/통신', '0.0', '0']
# ['블루솔루션(주) following', 'IT/웹/통신', '0.0', '4,452']
# ['블루웨이브 following', 'IT/웹/통신', '0.0', '0']
# ['블리스소프트(주) following', 'IT/웹/통신', '0.0', '3,075']
# ['비더에그 following', 'IT/웹/통신', '0.0', '0']
# ['비버게임즈(주) following', 'IT/웹/통신', '0.0', '0']
# ['비아이비즈앤(주) following', 'IT/웹/통신', '0.0', '3,294']
# ['비액티브랩 following', 'IT/웹/통신', '0.0', '0']
# ['비젠(주) following', 'IT/웹/통신', '0.0', '3,510']
# ['비젼웨어(주) following', 'IT/웹/통신', '0.0', '0']
# ['비트포믹스(주) following', 'IT/웹/통신', '0.0', '3,690']
# ['비하이브소프트(주) following', 'IT/웹/통신', '0.0', '0']
# ['빌리브 following', 'IT/웹/통신', '0.0', '0']
# ['빌보드코리아 following', 'IT/웹/통신', '0.0', '1,735']
# ['삼성에스디에스(주) 인도법인 following', 'IT/웹/통신', '0.0', '5,277']
# ['샤캄(주) following', 'IT/웹/통신', '0.0', '0']
# ['서치스(주) following', 'IT/웹/통신', '0.0', '0']
# ['선단테크(주) following', 'IT/웹/통신', '0.0', '1,548']
# ['성우시스템 following', 'IT/웹/통신', '0.0', '3,847']
# ['세일러 following', 'IT/웹/통신', '0.0', '0']
# ['셀레트 following', 'IT/웹/통신', '0.0', '0']
# ['셀트리온에스티(주) following', 'IT/웹/통신', '0.0', '5,975']
# ['소렘(주) following', 'IT/웹/통신', '0.0', '3,199']
# ['소프트리퍼브릭(주) following', 'IT/웹/통신', '0.0', '0']
# ['손잡다 following', 'IT/웹/통신', '0.0', '0']
# ['솔깃 following', 'IT/웹/통신', '0.0', '0']
# ['쇼비트(주) following', 'IT/웹/통신', '0.0', '0']
# ['스닙팟(주) following', 'IT/웹/통신', '0.0', '0']
# ['스마트스터디게임즈(주) following', 'IT/웹/통신', '0.0', '0']
# ['스타트업코드 following', 'IT/웹/통신', '0.0', '0']
# ['스트로베리코스메틱(유) following', 'IT/웹/통신', '0.0', '0']
# ['스페이스타임옵티마코리아(주) following', 'IT/웹/통신', '0.0', '0']
# ['시골 following', 'IT/웹/통신', '0.0', '3,174']
# ['시나잇정보통신 following', 'IT/웹/통신', '0.0', '0']
# ['시너텍(주) following', 'IT/웹/통신', '0.0', '1,575']
# ['시스템씨포(주) following', 'IT/웹/통신', '0.0', '0']
# ['시컴스 following', 'IT/웹/통신', '0.0', '0']
# ['시큐엠 following', 'IT/웹/통신', '0.0', '2,925']
# ['신아테크 following', 'IT/웹/통신', '0.0', '0']
# ['실버라이닝 following', 'IT/웹/통신', '0.0', '0']
# ['심플로지스(주) following', 'IT/웹/통신', '0.0', '0']
# ['심플리즘 following', 'IT/웹/통신', '0.0', '0']
# ['싱글톤소프트(주) following', 'IT/웹/통신', '0.0', '4,438']
# ['써니사이드웹 following', 'IT/웹/통신', '0.0', '0']
# ['씨그로(주) following', 'IT/웹/통신', '0.0', '0']
# ['씨알지테크놀러지(주) following', 'IT/웹/통신', '0.0', '6,043']
# ['씨에이커뮤니케이션즈(주) following', 'IT/웹/통신', '0.0', '3,075']
# ['씨웨이시스템즈(주) following', 'IT/웹/통신', '0.0', '3,705']
# ['씨제이엔터테인먼트(주) following', 'IT/웹/통신', '0.0', '3,510']
# ['아노테이션서울(주) following', 'IT/웹/통신', '0.0', '0']
# ['아르스비벤디 following', 'IT/웹/통신', '0.0', '0']
# ['아워스페이스(주) following', 'IT/웹/통신', '0.0', '0']
# ['아이넥스시스템 following', 'IT/웹/통신', '0.0', '0']
# ['아이노바씨앤씨(주) following', 'IT/웹/통신', '0.0', '2,925']
# ['아이렌소프트(주) following', 'IT/웹/통신', '0.0', '3,048']
# ['아이비에스(주) following', 'IT/웹/통신', '0.0', '3,809']
# ['아이비에스파트너스 following', 'IT/웹/통신', '0.0', '0']
# ['아이윅스(주) following', 'IT/웹/통신', '0.0', '4,100']
# ['아이지피(주) following', 'IT/웹/통신', '0.0', '0']
# ['아이콘랩(주) following', 'IT/웹/통신', '0.0', '2,798']
# ['아이큐브(주) following', 'IT/웹/통신', '0.0', '2,876']
# ['아이티모어(주) following', 'IT/웹/통신', '0.0', '4,204']
# ['아이티엔씨 following', 'IT/웹/통신', '0.0', '0']
# ['아케인(주) following', 'IT/웹/통신', '0.0', '0']
# ['아텍글로벌홀딩스(주) following', 'IT/웹/통신', '0.0', '0']
# ['아프로시스(주) following', 'IT/웹/통신', '0.0', '4,279']
# ['알리오 following', 'IT/웹/통신', '0.0', '3,588']
# ['알브이소프트(주) following', 'IT/웹/통신', '0.0', '2,340']
# ['알씨에스시스템즈(주) following', 'IT/웹/통신', '0.0', '2,518']
# ['애드블루 following', 'IT/웹/통신', '0.0', '0']
# ['애로우잉글리시(주) following', 'IT/웹/통신', '0.0', '2,686']
# ['어레인보우(주) following', 'IT/웹/통신', '0.0', '4,613']
# ['어필시스템(주) following', 'IT/웹/통신', '0.0', '2,170']
# ['언커먼랩(주) following', 'IT/웹/통신', '0.0', '0']
# ['에듀러시 following', 'IT/웹/통신', '0.0', '0']
# ['에바씨엔피(주) following', 'IT/웹/통신', '0.0', '0']
# ['에스앤디정보(주) following', 'IT/웹/통신', '0.0', '0']
# ['에스엘아이티(주) following', 'IT/웹/통신', '0.0', '3,474']
# ['에스케이바이오스(주) following', 'IT/웹/통신', '0.0', '0']
# ['에스케이플래닛(주) 티스토어 following', 'IT/웹/통신', '0.0', '4,575']
# ['에스프레스토(주) following', 'IT/웹/통신', '0.0', '0']
# ['에스플러스소프트(주) following', 'IT/웹/통신', '0.0', '0']
# ['에이비(주) following', 'IT/웹/통신', '0.0', '0']
# ['에이스 엔터테인먼트 LLC following', 'IT/웹/통신', '0.0', '0']
# ['에이아이솔텍(주) following', 'IT/웹/통신', '0.0', '2,050']
# ['에이임팩트(주) following', 'IT/웹/통신', '0.0', '3,186']
# ['에이치엔컴퍼니 following', 'IT/웹/통신', '0.0', '0']
# ['에이코리아(주) following', 'IT/웹/통신', '0.0', '3,900']
# ['에이팩스시스템(주) following', 'IT/웹/통신', '0.0', '4,270']
# ['엑스케어(주) following', 'IT/웹/통신', '0.0', '0']
# ['엑시스소프트웨어엔지니어링(주) following', 'IT/웹/통신', '0.0', '3,651']
# ['엔소프트(주) following', 'IT/웹/통신', '0.0', '2,828']
# ['엔씨아이에스(주) following', 'IT/웹/통신', '0.0', '5,125']
# ['엔와이티지(주) following', 'IT/웹/통신', '0.0', '4,587']
# ['엔지니어스토리(유) following', 'IT/웹/통신', '0.0', '0']
# ['엔쿤스타(주) following', 'IT/웹/통신', '0.0', '2,730']
# ['엔티에스소프트(주) following', 'IT/웹/통신', '0.0', '0']
# ['엔피날(주) following', 'IT/웹/통신', '0.0', '3,285']
# ['엘레멘트에너지코리아(주) following', 'IT/웹/통신', '0.0', '0']
# ['엘모모션콘트롤아시아(유) following', 'IT/웹/통신', '0.0', '0']
# ['엘타임게임즈(주) following', 'IT/웹/통신', '0.0', '3,793']
# ['엠버케이브(주) following', 'IT/웹/통신', '0.0', '3,218']
# ['엠앤엠솔루션(주) following', 'IT/웹/통신', '0.0', '0']
# ['엠에이치드림(주) following', 'IT/웹/통신', '0.0', '0']
# ['엠원테크(주) following', 'IT/웹/통신', '0.0', '0']
# ['엠일일사(주) following', 'IT/웹/통신', '0.0', '3,417']
# ['오비씨소프트(주) following', 'IT/웹/통신', '0.0', '3,315']
# ['오오씨(주) following', 'IT/웹/통신', '0.0', '4,388']
# ['오투오페이먼트(주) following', 'IT/웹/통신', '0.0', '0']
# ['오픈소스놀리지(주) following', 'IT/웹/통신', '0.0', '4,602']
# ['옥토칼럼 following', 'IT/웹/통신', '0.0', '0']
# ['온라인패스(주) following', 'IT/웹/통신', '0.0', '4,676']
# ['옵티머스(주) following', 'IT/웹/통신', '0.0', '5,353']
# ['와이어드랩(주) following', 'IT/웹/통신', '0.0', '0']
# ['와이즈소프트(주) following', 'IT/웹/통신', '0.0', '3,953']
# ['와이즈테크놀로지(주) following', 'IT/웹/통신', '0.0', '2,806']
# ['와이피디프로젝트(주) following', 'IT/웹/통신', '0.0', '0']
# ['와플소프트(주) following', 'IT/웹/통신', '0.0', '2,255']
# ['원글로벌커머셜 following', 'IT/웹/통신', '0.0', '0']
# ['월요일(주) following', 'IT/웹/통신', '0.0', '0']
# ['웹솔(주) following', 'IT/웹/통신', '0.0', '2,438']
# ['위로드산업(주) following', 'IT/웹/통신', '0.0', '0']
# ['위커넥티드 following', 'IT/웹/통신', '0.0', '2,535']
# ['위프로스퍼(주) following', 'IT/웹/통신', '0.0', '0']
# ['윈터치 following', 'IT/웹/통신', '0.0', '0']
# ['유니크래스(주) following', 'IT/웹/통신', '0.0', '3,383']
# ['유런테크(주) following', 'IT/웹/통신', '0.0', '4,569']
# ['유스내퍼코리아(주) following', 'IT/웹/통신', '0.0', '0']
# ['유이공 following', 'IT/웹/통신', '0.0', '0']
# ['이글이알피(주) following', 'IT/웹/통신', '0.0', '1,722']
# ['이너스정보(주) following', 'IT/웹/통신', '0.0', '0']
# ['이노반트테크놀로지스(주) following', 'IT/웹/통신', '0.0', '0']
# ['이디소프트(주) following', 'IT/웹/통신', '0.0', '2,504']
# ['이리스컨설팅(주) following', 'IT/웹/통신', '0.0', '3,642']
# ['이에스엠(주) following', 'IT/웹/통신', '0.0', '2,983']
# ['이엔커뮤니케이션(주) following', 'IT/웹/통신', '0.0', '0']
# ['이지원시스템(주) following', 'IT/웹/통신', '0.0', '0']
# ['이테스트(주) following', 'IT/웹/통신', '0.0', '3,675']
# ['이테크밸리(주) following', 'IT/웹/통신', '0.0', '2,730']
# ['인디드랩(주) following', 'IT/웹/통신', '0.0', '0']
# ['인디큐브(주) following', 'IT/웹/통신', '0.0', '0']
# ['인레인(주) following', 'IT/웹/통신', '0.0', '2,400']
# ['인터케어(주) following', 'IT/웹/통신', '0.0', '5,099']
# ['인트인(주) following', 'IT/웹/통신', '0.0', '0']
# ['자이크론(주) following', 'IT/웹/통신', '0.0', '3,400']
# ['제이니몹(주) following', 'IT/웹/통신', '0.0', '3,666']
# ['제이엠와이시스템(주) following', 'IT/웹/통신', '0.0', '1,755']
# ['제이크로 following', 'IT/웹/통신', '0.0', '5,125']
# ['젠핏엑스(주) following', 'IT/웹/통신', '0.0', '0']
# ['젬플레이(주) following', 'IT/웹/통신', '0.0', '4,348']
# ['주성시스템(주) following', 'IT/웹/통신', '0.0', '3,321']
# ['주식회사 그로잉포인트 following', 'IT/웹/통신', '0.0', '0']
# ['주식회사 울트라블루 following', 'IT/웹/통신', '0.0', '0']
# ['지락인포메이션(주) following', 'IT/웹/통신', '0.0', '2,338']
# ['지코드 following', 'IT/웹/통신', '0.0', '0']
# ['지투시스넷(주) following', 'IT/웹/통신', '0.0', '3,703']
# ['직송(주) following', 'IT/웹/통신', '0.0', '0']
# ['진앤현시스템(주) following', 'IT/웹/통신', '0.0', '0']
# ['차트모굴(유) following', 'IT/웹/통신', '0.0', '0']
# ['카몬(주) following', 'IT/웹/통신', '0.0', '0']
# ['카밤게임즈코리아 following', 'IT/웹/통신', '0.0', '3,588']
# ['카운트파트너스(주) following', 'IT/웹/통신', '0.0', '0']
# ['카카오네트웍스(주) following', 'IT/웹/통신', '0.0', '2,214']
# ['캐셜롯 following', 'IT/웹/통신', '0.0', '0']
# ['캬라멜라 following', 'IT/웹/통신', '0.0', '0']
# ['컨슈머너티(주) following', 'IT/웹/통신', '0.0', '4,100']
# ['컬처코리아(주) following', 'IT/웹/통신', '0.0', '0']
# ['컬택 following', 'IT/웹/통신', '0.0', '0']
# ['컴스퀘어(주) following', 'IT/웹/통신', '0.0', '3,523']
# ['컴팔(주) following', 'IT/웹/통신', '0.0', '0']
# ['컴퍼니 타임스 following', 'IT/웹/통신', '0.0', '0']
# ['컴포자이너스 following', 'IT/웹/통신', '0.0', '0']
# ['케이퍼스트랩(주) following', 'IT/웹/통신', '0.0', '0']
# ['코리아데이타코퍼레이션(주) following', 'IT/웹/통신', '0.0', '3,933']
# ['코리아트립(주) following', 'IT/웹/통신', '0.0', '1,075']
# ['코볼(주) following', 'IT/웹/통신', '0.0', '0']
# ['퀀텀테크엔시큐(주) following', 'IT/웹/통신', '0.0', '0']
# ['크리에이시브코리아(유) following', 'IT/웹/통신', '0.0', '0']
# ['크립토파라다이스 유한책임회사 following', 'IT/웹/통신', '0.0', '3,285']
# ['클라인스코리아(주) following', 'IT/웹/통신', '0.0', '3,510']
# ['키스코(주) 일본 following', 'IT/웹/통신', '0.0', '4,260']
# ['키키아이(주) following', 'IT/웹/통신', '0.0', '0']
# ['키핀터치(주) following', 'IT/웹/통신', '0.0', '2,870']
# ['킥오프 following', 'IT/웹/통신', '0.0', '0']
# ['텔레픽스(주) following', 'IT/웹/통신', '0.0', '4,465']
# ['토이박스게임즈(주) following', 'IT/웹/통신', '0.0', '0']
# ['투웨이앤코(주) following', 'IT/웹/통신', '0.0', '2,255']
# ['트랜스파머(주) following', 'IT/웹/통신', '0.0', '0']
# ['트루스토리 following', 'IT/웹/통신', '0.0', '0']
# ['티엔오오토모티브코리아(주) following', 'IT/웹/통신', '0.0', '14,625']
# ['파이브락스(주) following', 'IT/웹/통신', '0.0', '4,753']
# ['패스트비코리아(주) following', 'IT/웹/통신', '0.0', '0']
# ['패킷플레이(주) following', 'IT/웹/통신', '0.0', '0']
# ['팬세이션(주) following', 'IT/웹/통신', '0.0', '0']
# ['퍼플칩스 following', 'IT/웹/통신', '0.0', '0']
# ['펜타베이스코리아 following', 'IT/웹/통신', '0.0', '2,865']
# ['펫브리즈 following', 'IT/웹/통신', '0.0', '0']
# ['펫페오톡(주) following', 'IT/웹/통신', '0.0', '0']
# ['퓨처스토리(주) following', 'IT/웹/통신', '0.0', '2,563']
# ['프레버소프트(주) following', 'IT/웹/통신', '0.0', '3,042']
# ['프리온(주) following', 'IT/웹/통신', '0.0', '0']
# ['플러스아이덴티티(유) following', 'IT/웹/통신', '0.0', '0']
# ['플레이벳컴 following', 'IT/웹/통신', '0.0', '0']
# ['플레이스낭낭 following', 'IT/웹/통신', '0.0', '0']
# ['플레이스에이(주) following', 'IT/웹/통신', '0.0', '0']
# ['플링커(주) following', 'IT/웹/통신', '0.0', '0']
# ['필락시스(주) following', 'IT/웹/통신', '0.0', '0']
# ['필로토(주) following', 'IT/웹/통신', '0.0', '0']
# ['핑거플래닛(주) following', 'IT/웹/통신', '0.0', '2,870']
# ['하늘소프트(주) following', 'IT/웹/통신', '0.0', '0']
# ['하이브레인넷 following', 'IT/웹/통신', '0.0', '3,383']
# ['하이퍼시스템즈(주) following', 'IT/웹/통신', '0.0', '2,950']
# ['한국에이에이씨 following', 'IT/웹/통신', '0.0', '0']
# ['해드앤하트 following', 'IT/웹/통신', '0.0', '0']
# ['해킷 following', 'IT/웹/통신', '0.0', '0']
# ['헤르츠639 following', 'IT/웹/통신', '0.0', '0']
# ['협동조합 작은시선 following', 'IT/웹/통신', '0.0', '0']
# ['호루스인터내셔널 following', 'IT/웹/통신', '0.0', '2,925']
# ['호암아이씨티유한책임회사 following', 'IT/웹/통신', '0.0', '0']
# ['호텔파인더 following', 'IT/웹/통신', '0.0', '0']
# ['홈라이프 following', 'IT/웹/통신', '0.0', '0']
# ['효원텍(주) following', 'IT/웹/통신', '0.0', '0']
# ['휴스테이(주) following', 'IT/웹/통신', '0.0', '3,236']
# ['호암아이씨티유한책임회사 following', 'IT/웹/통신', '0.0', '0']
# ['호텔파인더 following', 'IT/웹/통신', '0.0', '0']
# ['홈라이프 following', 'IT/웹/통신', '0.0', '0']
# ['효원텍(주) following', 'IT/웹/통신', '0.0', '0']
# ['휴스테이(주) following', 'IT/웹/통신', '0.0', '3,236']
# ['호암아이씨티유한책임회사 following', 'IT/웹/통신', '0.0', '0']
# ['호텔파인더 following', 'IT/웹/통신', '0.0', '0']
# ['홈라이프 following', 'IT/웹/통신', '0.0', '0']
# ['효원텍(주) following', 'IT/웹/통신', '0.0', '0']
# ['휴스테이(주) following', 'IT/웹/통신', '0.0', '3,236']
# ['호암아이씨티유한책임회사 following', 'IT/웹/통신', '0.0', '0']
# ['호텔파인더 following', 'IT/웹/통신', '0.0', '0']
# ['홈라이프 following', 'IT/웹/통신', '0.0', '0']
# ['효원텍(주) following', 'IT/웹/통신', '0.0', '0']
# ['휴스테이(주) following', 'IT/웹/통신', '0.0', '3,236']
# ['호암아이씨티유한책임회사 following', 'IT/웹/통신', '0.0', '0']
# ['호텔파인더 following', 'IT/웹/통신', '0.0', '0']
# ['홈라이프 following', 'IT/웹/통신', '0.0', '0']
# ['효원텍(주) following', 'IT/웹/통신', '0.0', '0']
# ['휴스테이(주) following', 'IT/웹/통신', '0.0', '3,236']
# ['호암아이씨티유한책임회사 following', 'IT/웹/통신', '0.0', '0']
# ['호텔파인더 following', 'IT/웹/통신', '0.0', '0']
# ['홈라이프 following', 'IT/웹/통신', '0.0', '0']
# ['효원텍(주) following', 'IT/웹/통신', '0.0', '0']
# ['휴스테이(주) following', 'IT/웹/통신', '0.0', '3,236']
# ['호암아이씨티유한책임회사 following', 'IT/웹/통신', '0.0', '0']
# ['호텔파인더 following', 'IT/웹/통신', '0.0', '0']
# ['홈라이프 following', 'IT/웹/통신', '0.0', '0']
# ['효원텍(주) following', 'IT/웹/통신', '0.0', '0']
# ['휴스테이(주) following', 'IT/웹/통신', '0.0', '3,236']
# ['호암아이씨티유한책임회사 following', 'IT/웹/통신', '0.0', '0']
# ['호텔파인더 following', 'IT/웹/통신', '0.0', '0']
# ['홈라이프 following', 'IT/웹/통신', '0.0', '0']
# ['효원텍(주) following', 'IT/웹/통신', '0.0', '0']
# ['휴스테이(주) following', 'IT/웹/통신', '0.0', '3,236']
# ['호암아이씨티유한책임회사 following', 'IT/웹/통신', '0.0', '0']
# ['호텔파인더 following', 'IT/웹/통신', '0.0', '0']
# ['홈라이프 following', 'IT/웹/통신', '0.0', '0']
# ['효원텍(주) following', 'IT/웹/통신', '0.0', '0']
# ['휴스테이(주) following', 'IT/웹/통신', '0.0', '3,236']
# ['호암아이씨티유한책임회사 following', 'IT/웹/통신', '0.0', '0']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 13
#      10 for elem in elements:
#      11     company =[]
# ---> 13     name = elem.find_element(By.CLASS_NAME,'us_titb_l3').text
#      14     field = elem.find_element(By.CLASS_NAME, 'us_stxt_1').text
#      15     point = elem.find_element(By.CLASS_NAME, 'gfvalue').text
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:90, in WebElement.text(self)
#      87 @property
#      88 def text(self) -> str:
#      89     """The text of the element."""
# ---> 90     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     343     elif "sessionId" not in params:
#     344         params["sessionId"] = self.session_id
# --> 346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
#     348     self.error_handler.check_response(response)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:300, in RemoteConnection.execute(self, command, params)
#     298 data = utils.dump_json(params)
#     299 url = f"{self._url}{path}"
# --> 300 return self._request(command_info[0], url, body=data)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:321, in RemoteConnection._request(self, method, url, body)
#     318     body = None
#     320 if self.keep_alive:
# --> 321     response = self._conn.request(method, url, body=body, headers=headers)
#     322     statuscode = response.status
#     323 else:
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/_request_methods.py:110, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     107     urlopen_kw["body"] = body
#     109 if method in self._encode_url_methods:
# --> 110     return self.request_encode_url(
#     111         method,
#     112         url,
#     113         fields=fields,  # type: ignore[arg-type]
#     114         headers=headers,
#     115         **urlopen_kw,
#     116     )
#     117 else:
#     118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     140 if fields:
#     141     url += "?" + urlencode(fields)
# --> 143 return self.urlopen(method, url, **extra_kw)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/poolmanager.py:444, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     442     response = conn.urlopen(method, url, **kw)
#     443 else:
# --> 444     response = conn.urlopen(method, u.request_uri, **kw)
#     446 redirect_location = redirect and response.get_redirect_location()
#     447 if not redirect_location:
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import pandas as pd 
com1 = company_list
columns=['기업이름','분야','평점','연봉']
df1 = pd.DataFrame(com1, columns=columns)

# %%
df1['기업이름'] = df1['기업이름'].str.split('f').str[0]
df1['평점'] = df1['평점'].astype(float)
df1['연봉'] = df1['연봉'].replace({',': ''}, regex=True)
df1['연봉'] = df1['연봉'].astype(int)
df1['2차산업군'] = 'IT'

# %%
df1.to_csv('../../../data/eda_project_data/잡플래닛/IT.csv',index=False)

# %%
driver.quit()
