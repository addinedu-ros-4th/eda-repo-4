# %%
from tqdm.notebook import tqdm
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.request import Request
import urllib
from user_agent import generate_user_agent

# %%
driver = webdriver.Chrome(service=Service('../../../driver/chromedriver'))
driver.get('https://www.jobplanet.co.kr/companies?industry_id=204&page=1')

# %%
import time
from tqdm.notebook import tqdm

# company_list = []

for i in tqdm(range(1,50)):
    time.sleep(1)
    elements = driver.find_elements(By.CLASS_NAME, 'company.content_ty3')
    
    for elem in elements:
        company =[]

        name = elem.find_element(By.CLASS_NAME,'us_titb_l3').text
        field = elem.find_element(By.CLASS_NAME, 'us_stxt_1').text
        point = elem.find_element(By.CLASS_NAME, 'gfvalue').text
        money = elem.find_element(By.CLASS_NAME, 'notranslate').text
        
        company.append(name)
        company.append(field)
        company.append(point)
        company.append(money)
        company_list.append(company)
        print(company)

    driver.find_element(By.CLASS_NAME, 'btn_pgnext').click()
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]
# ['엘지디스플레이(주) following', '제조/화학', '3.1', '5,022']
# ['에스케이하이닉스(주) following', '제조/화학', '3.6', '5,093']
# ['앰코테크놀로지코리아(주) following', '제조/화학', '2.7', '3,825']
# ['(유)스태츠칩팩코리아 following', '제조/화학', '2.6', '3,782']
# ['삼성디스플레이(주) following', '제조/화학', '3.4', '5,250']
# ['유니셈(주) following', '제조/화학', '2.3', '3,240']
# ['에스케이실트론(주) following', '제조/화학', '3.0', '4,528']
# ['(주)네패스 following', '제조/화학', '2.9', '4,072']
# ['(주)엠씨넥스 following', '제조/화학', '2.0', '3,786']
# ['(주)원익아이피에스 following', '제조/화학', '2.7', '4,646']
# ['(주)케이씨텍 following', '제조/화학', '3.0', '4,139']
# ['온세미컨덕터코리아(주) following', '제조/화학', '2.9', '4,055']
# ['한미반도체(주) following', '제조/화학', '2.3', '3,871']
# ['세메스(주) following', '제조/화학', '3.3', '5,237']
# ['(주)휴맥스 following', '제조/화학', '2.8', '4,586']
# ['어플라이드머티어리얼즈코리아(주) following', '제조/화학', '3.6', '4,976']
# ['(주)이오테크닉스 following', '제조/화학', '1.9', '4,126']
# ['(주)디비하이텍 following', '제조/화학', '2.7', '4,275']
# ['서울반도체(주) following', '제조/화학', '2.5', '4,962']
# ['에이에스엠엘코리아(주) following', '제조/화학', '3.8', '5,410']
# ['(주)세코닉스 following', '제조/화학', '2.2', '4,051']
# ['시그네틱스(주) following', '제조/화학', '2.1', '3,681']
# ['하나마이크론(주) following', '제조/화학', '2.6', '3,944']
# ['(주)신성이엔지 following', '제조/화학', '2.5', '3,684']
# ['엠이엠씨코리아(주) following', '제조/화학', '3.6', '3,880']
# ['(주)아이씨디 following', '제조/화학', '2.4', '4,040']
# ['(주)제우스 following', '제조/화학', '3.5', '4,052']
# ['(주)에스에프에이반도체 following', '제조/화학', '2.5', '3,878']
# ['매그나칩반도체(유) following', '제조/화학', '3.0', '4,430']
# ['(주)인터로조 following', '제조/화학', '2.3', '3,995']
# ['(주)엘아이에스 following', '제조/화학', '2.3', '3,829']
# ['(주)아이아이컴바인드 following', '제조/화학', '3.1', '3,782']
# ['에이피시스템(주) following', '제조/화학', '2.7', '4,009']
# ['(주)나래나노텍 following', '제조/화학', '2.5', '3,966']
# ['(주)엘엠에스 following', '제조/화학', '2.0', '3,929']
# ['케이맥(주) following', '제조/화학', '2.3', '3,649']
# ['(주)엘엑스세미콘 following', '제조/화학', '2.7', '4,875']
# ['(주)코텍 following', '제조/화학', '2.3', '4,210']
# ['웅진에너지(주) following', '제조/화학', '2.5', '4,145']
# ['스테코(주) following', '제조/화학', '3.0', '4,099']
# ['광전자(주) following', '제조/화학', '2.3', '3,113']
# ['(주)에프에스티 following', '제조/화학', '3.2', '3,917']
# ['(주)인터엠 following', '제조/화학', '2.3', '3,066']
# ['(주)케이이씨 following', '제조/화학', '2.5', '3,949']
# ['(주)루멘스 following', '제조/화학', '2.3', '3,610']
# ['일진디스플레이(주) following', '제조/화학', '2.5', '4,063']
# ['(주)하이비젼시스템 following', '제조/화학', '2.8', '4,432']
# ['크레신(주) following', '제조/화학', '2.7', '4,635']
# ['(주)그린광학 following', '제조/화학', '2.0', '3,181']
# ['에스피반도체통신(주) following', '제조/화학', '2.1', '3,238']
# ['하나머티리얼즈(주) following', '제조/화학', '2.9', '3,929']
# ['(주)큐엠씨 following', '제조/화학', '2.2', '3,492']
# ['희성전자(주) following', '제조/화학', '2.5', '4,857']
# ['서울바이오시스(주) following', '제조/화학', '2.3', '4,854']
# ['(주)메카로 following', '제조/화학', '2.9', '3,696']
# ['윈팩(주) following', '제조/화학', '2.2', '3,605']
# ['램리서치코리아(유) following', '제조/화학', '3.8', '4,714']
# ['(주)싸이노스 following', '제조/화학', '2.6', '3,694']
# ['한국호야전자(주) following', '제조/화학', '2.6', '3,367']
# ['(주)디에이치오토웨어 following', '제조/화학', '2.3', '4,125']
# ['(주)옵트론텍 following', '제조/화학', '2.4', '3,654']
# ['(주)에이팩트 following', '제조/화학', '2.7', '3,801']
# ['(주)상보 following', '제조/화학', '2.5', '3,639']
# ['이엘케이(주) following', '제조/화학', '2.5', '3,444']
# ['재영솔루텍(주) following', '제조/화학', '2.5', '3,481']
# ['(주)테크엘 following', '제조/화학', '2.6', '3,385']
# ['케이엘에이텐코코리아(주) following', '제조/화학', '3.9', '5,456']
# ['(주)싸이맥스 following', '제조/화학', '3.1', '4,024']
# ['인켈(주) following', '제조/화학', '2.2', '3,801']
# ['인테그리스코리아(주) following', '제조/화학', '3.2', '4,669']
# ['인피니언테크놀로지스파워세미텍(주) following', '제조/화학', '3.1', '4,597']
# ['(주)선익시스템 following', '제조/화학', '2.3', '3,576']
# ['(주)뉴옵틱스 following', '제조/화학', '2.5', '4,395']
# ['엘티소재(주) following', '제조/화학', '2.5', '4,465']
# ['와이엠씨(주) following', '제조/화학', '2.3', '3,320']
# ['아바텍(주) following', '제조/화학', '2.2', '3,531']
# ['(주)케이씨이노베이션 following', '제조/화학', '2.9', '3,680']
# ['코웰전자(주) following', '제조/화학', '2.0', '5,319']
# ['(주)인지디스플레이 following', '제조/화학', '2.4', '3,887']
# ['(주)휴비츠 following', '제조/화학', '2.6', '4,491']
# ['글로텍(주) following', '제조/화학', '1.9', '3,419']
# ['(주)비에스이 following', '제조/화학', '1.9', '3,947']
# ['(주)미래보 following', '제조/화학', '2.6', '3,036']
# ['(주)나노엔텍 following', '제조/화학', '3.0', '3,667']
# ['(주)오디텍 following', '제조/화학', '2.5', '3,781']
# ['이오시스템(주) following', '제조/화학', '2.1', '4,114']
# ['엠케이에스코리아(유) following', '제조/화학', '3.4', '3,672']
# ['(주)범천정밀 following', '제조/화학', '2.4', '3,925']
# ['에이티아이(주) following', '제조/화학', '3.1', '3,915']
# ['(주)넥솔론 following', '제조/화학', '2.9', '3,430']
# ['에스텍(주) following', '제조/화학', '2.5', '3,886']
# ['엠케이전자(주) following', '제조/화학', '2.7', '3,841']
# ['(주)미코세라믹스 following', '제조/화학', '2.4', '3,972']
# ['(주)인화이엔지 following', '제조/화학', '1.8', '3,022']
# ['(주)테스 following', '제조/화학', '3.3', '4,557']
# ['대곤코퍼레이션(주) following', '제조/화학', '2.7', '4,262']
# ['방주광학(주) following', '제조/화학', '2.0', '3,566']
# ['(주)도우인시스 following', '제조/화학', '1.8', '3,774']
# ['멜콘(주) following', '제조/화학', '3.4', '3,221']
# ['에이치디현대에너지솔루션(주) following', '제조/화학', '2.2', '4,927']
# ['지스마트글로벌(주) following', '제조/화학', '1.7', '3,388']
# ['링크플로우(주) following', '제조/화학', '3.1', '3,257']
# ['엠티아이(주) following', '제조/화학', '1.9', '3,728']
# ['(주)이지엠인터내셔널 following', '제조/화학', '2.9', '3,128']
# ['덕산하이메탈(주) following', '제조/화학', '2.6', '4,435']
# ['씨게이트코리아(유) following', '제조/화학', '3.7', '6,512']
# ['휴맥스오토모티브 following', '제조/화학', '2.6', '4,676']
# ['(주)티로보틱스 following', '제조/화학', '2.5', '3,660']
# ['디엔에프(주) following', '제조/화학', '3.1', '3,936']
# ['알에프세미(주) following', '제조/화학', '2.5', '3,010']
# ['(주)에스엔텍 following', '제조/화학', '1.8', '3,584']
# ['(주)케이에스엠컴포넌트 following', '제조/화학', '2.7', '3,506']
# ['일진엘이디(주) following', '제조/화학', '2.6', '2,990']
# ['에이엠에스티(주) following', '제조/화학', '2.5', '3,340']
# ['해성옵틱스(주) following', '제조/화학', '2.5', '3,598']
# ['제너셈(주) following', '제조/화학', '2.4', '3,981']
# ['(주)앤씨앤 following', '제조/화학', '2.6', '4,407']
# ['(주)에스엘에너지 following', '제조/화학', '2.8', '3,795']
# ['(주)오로스테크놀로지 following', '제조/화학', '3.7', '4,731']
# ['코아리버(주) following', '제조/화학', '2.4', '2,813']
# ['큐알티(주) following', '제조/화학', '3.0', '5,026']
# ['(주)노블엠앤비 following', '제조/화학', '2.2', '4,008']
# ['(주)동원파츠 following', '제조/화학', '2.6', '3,380']
# ['오씨아이스페셜티(주) following', '제조/화학', '2.2', '3,936']
# ['한국호야렌즈(주) following', '제조/화학', '2.5', '3,921']
# ['(주)동운아나텍 following', '제조/화학', '2.5', '4,513']
# ['(주)와이투솔루션 following', '제조/화학', '2.2', '3,116']
# ['에스이앤에스(주) following', '제조/화학', '2.2', '3,242']
# ['웰킵스하이텍(주) following', '제조/화학', '2.5', '3,116']
# ['브릴리언츠(주) following', '제조/화학', '2.7', '3,975']
# ['어보브반도체(주) following', '제조/화학', '2.8', '4,489']
# ['(주)키파운드리 following', '제조/화학', '2.7', '4,714']
# ['지나인제약(주) following', '제조/화학', '2.3', '3,343']
# ['(주)삼양옵틱스 following', '제조/화학', '2.9', '4,251']
# ['(주)케이에스엠 following', '제조/화학', '2.8', '4,016']
# ['퓨렉스(주) following', '제조/화학', '2.4', '3,184']
# ['(주)네오비젼 following', '제조/화학', '2.0', '3,000']
# ['(주)피타소프트 following', '제조/화학', '2.5', '3,917']
# ['(주)티엘아이 following', '제조/화학', '3.0', '4,168']
# ['보부하이테크(주) following', '제조/화학', '2.5', '3,465']
# ['엠피닉스(주) following', '제조/화학', '2.8', '3,294']
# ['(주)넥스트칩 following', '제조/화학', '2.7', '4,751']
# ['디에이치(주) following', '제조/화학', '2.0', '4,029']
# ['코레노(주) following', '제조/화학', '2.8', '3,975']
# ['(주)디라직 following', '제조/화학', '2.5', '3,345']
# ['더블유티테크놀로지코리아(주) following', '제조/화학', '3.1', '4,570']
# ['산리츠코리아(주) following', '제조/화학', '3.1', '3,847']
# ['열림기술(주) following', '제조/화학', '2.8', '3,937']
# ['(주)아이컴포넌트 following', '제조/화학', '2.7', '3,529']
# ['(주)제이쓰리 following', '제조/화학', '1.5', '3,391']
# ['코스텔(주) following', '제조/화학', '1.9', '3,669']
# ['한국전광(주) following', '제조/화학', '2.7', '3,866']
# ['(주)신지모루 following', '제조/화학', '2.9', '3,002']
# ['(주)에이디테크놀로지 following', '제조/화학', '3.2', '4,533']
# ['아이티엑스시큐리티(주) following', '제조/화학', '2.3', '3,761']
# ['온투이노베이션코리아(주) following', '제조/화학', '3.4', '4,920']
# ['(주)육일씨엔에쓰 following', '제조/화학', '2.8', '3,439']
# ['디아이디(주) following', '제조/화학', '2.9', '5,981']
# ['아이모스시스템(주) following', '제조/화학', '2.5', '4,321']
# ['우리이앤엘(주) following', '제조/화학', '2.4', '4,047']
# ['헬러코리아(주) following', '제조/화학', '2.2', '2,915']
# ['(주)아이앤씨테크놀로지 following', '제조/화학', '2.4', '4,646']
# ['네오뷰코오롱(주) following', '제조/화학', '3.2', '4,244']
# ['(주)티에프이 following', '제조/화학', '3.1', '3,810']
# ['동부엘이디(주) following', '제조/화학', '2.6', '3,567']
# ['(주)원익테라세미콘 following', '제조/화학', '2.9', '4,032']
# ['아사히글라스 화인테크노코리아 following', '제조/화학', '3.2', '4,416']
# ['케이케이테크(주) following', '제조/화학', '3.0', '3,684']
# ['한국소니전자(주) following', '제조/화학', '2.7', '4,074']
# ['동아엘텍(주) following', '제조/화학', '2.9', '3,725']
# ['케빅(주) following', '제조/화학', '2.0', '2,685']
# ['(주)지씨엠 following', '제조/화학', '2.0', '3,325']
# ['사파이어테크놀로지(주) following', '제조/화학', '3.4', '3,982']
# ['(주)시스메이트 following', '제조/화학', '2.3', '3,390']
# ['(주)애니캐스팅 following', '제조/화학', '2.4', '3,649']
# ['하이디스테크놀로지(주) following', '제조/화학', '3.2', '4,030']
# ['(주)쏘닉스 following', '제조/화학', '2.4', '3,714']
# ['아덴텍코리아(주) following', '제조/화학', '2.3', '3,139']
# ['(주)에이텍솔루션 following', '제조/화학', '1.8', '3,901']
# ['(주)코아시아씨엠 following', '제조/화학', '2.1', '4,010']
# ['양우전자(주) following', '제조/화학', '2.5', '3,480']
# ['(주)이더블유비엠 following', '제조/화학', '2.4', '3,939']
# ['태산엘시디(주) following', '제조/화학', '3.2', '3,625']
# ['(주)삼진 following', '제조/화학', '3.1', '3,465']
# ['(주)인스케이프 following', '제조/화학', '2.8', '4,237']
# ['(주)판타룩스 following', '제조/화학', '1.9', '3,413']
# ['레이젠(주) following', '제조/화학', '2.3', '3,719']
# ['(주)베이스 following', '제조/화학', '2.2', '3,426']
# ['브룩스오토메이션아시아(주) following', '제조/화학', '3.1', '4,020']
# ['이미지스테크놀로지(주) following', '제조/화학', '2.6', '4,659']
# ['한국브룩스오토메이션(주) following', '제조/화학', '3.5', '4,230']
# ['(주)디지트론 following', '제조/화학', '2.6', '3,584']
# ['브이테크놀로지코리아(주) following', '제조/화학', '2.6', '3,377']
# ['(주)비젼사이언스 following', '제조/화학', '2.2', '2,847']
# ['(주)알티자동화 following', '제조/화학', '3.0', '3,437']
# ['레이저앤피직스(주) following', '제조/화학', '2.3', '3,728']
# ['유니코스(주) following', '제조/화학', '2.0', '2,608']
# ['코아로직(주) following', '제조/화학', '2.8', '4,445']
# ['한국오지케이(주) following', '제조/화학', '3.0', '3,227']
# ['(주)나인벨 following', '제조/화학', '2.4', '3,636']
# ['(주)오성미디컴 following', '제조/화학', '1.9', '3,176']
# ['(주)태진기술 following', '제조/화학', '1.5', '4,568']
# ['르네사스디자인코리아(주) following', '제조/화학', '3.0', '6,672']
# ['(주)베이직테크 following', '제조/화학', '2.5', '3,013']
# ['(주)코아시아넥셀 following', '제조/화학', '2.8', '4,137']
# ['빛샘전자(주) following', '제조/화학', '2.3', '2,920']
# ['에이피티씨(주) following', '제조/화학', '3.6', '3,928']
# ['엠텍비젼(주) following', '제조/화학', '2.5', '4,289']
# ['(주)비콘아이앤씨 following', '제조/화학', '2.3', '3,538']
# ['(주)피델릭스 following', '제조/화학', '2.7', '3,845']
# ['대명소재(주) following', '제조/화학', '2.9', '3,435']
# ['대원전광(주) following', '제조/화학', '1.7', '3,363']
# ['디스코하이테크코리아(주) following', '제조/화학', '1.8', '3,741']
# ['(주)디에이아이오 following', '제조/화학', '2.0', '4,889']
# ['(주)마르시스 following', '제조/화학', '2.8', '3,580']
# ['(주)이에스티 following', '제조/화학', '2.9', '3,274']
# ['(주)라닉스 following', '제조/화학', '2.6', '5,568']
# ['아나패스(주) following', '제조/화학', '3.3', '4,669']
# ['(주)케이알엠 following', '제조/화학', '3.1', '4,668']
# ['오토스광학(주) following', '제조/화학', '2.3', '1,942']
# ['한양디지텍(주) following', '제조/화학', '3.4', '3,718']
# ['(주)참신 following', '제조/화학', '2.5', '2,774']
# ['나우테크(주) following', '제조/화학', '2.2', '3,016']
# ['르네사스일렉트로닉스한국(주) following', '제조/화학', '3.9', '4,821']
# ['(주)아이비젼웍스 following', '제조/화학', '3.9', '3,828']
# ['디스플레이테크(주) following', '제조/화학', '2.4', '3,444']
# ['온테스트(주) following', '제조/화학', '3.0', '3,321']
# ['(주)파이버프로 following', '제조/화학', '3.2', '4,344']
# ['피코앤테라(주) following', '제조/화학', '2.8', '3,667']
# ['(주)칩스앤미디어 following', '제조/화학', '3.3', '6,577']
# ['실리콘화일(주) following', '제조/화학', '2.2', '3,523']
# ['(주)레오테크 following', '제조/화학', '2.9', '3,339']
# ['(주)아이엠피 following', '제조/화학', '2.1', '2,873']
# ['(주)크레셈 following', '제조/화학', '2.5', '3,997']
# ['뉴바이오(주) following', '제조/화학', '1.5', '2,913']
# ['세미크론(주) following', '제조/화학', '3.8', '3,901']
# ['지에스티코리아(주) following', '제조/화학', '1.5', '3,077']
# ['(주)가온칩스 following', '제조/화학', '3.5', '4,083']
# ['보임기술(주) following', '제조/화학', '2.4', '4,602']
# ['사운드그래프(주) following', '제조/화학', '1.4', '3,589']
# ['(유)아이티더브류특수필름 following', '제조/화학', '2.4', '3,510']
# ['(주)라모스테크놀러지 following', '제조/화학', '2.9', '4,859']
# ['(주)코아시아 following', '제조/화학', '2.3', '4,629']
# ['(주)토모큐브 following', '제조/화학', '4.5', '0']
# ['나노윈(주) following', '제조/화학', '2.3', '3,300']
# ['애니모션텍(주) following', '제조/화학', '2.1', '4,613']
# ['(주)에이비엠 following', '제조/화학', '1.9', '3,156']
# ['(주)퀄리타스반도체 following', '제조/화학', '4.2', '4,032']
# ['(주)클라우드에어 following', '제조/화학', '3.2', '4,545']
# ['(주)피티앤케이 following', '제조/화학', '2.8', '2,577']
# ['(주)브이픽스메디칼 following', '제조/화학', '3.4', '3,324']
# ['(주)앰플리튜드코리아 following', '제조/화학', '2.6', '3,114']
# ['(주)에이치피에스피 following', '제조/화학', '4.1', '4,208']
# ['에스-탑 following', '제조/화학', '1.9', '2,814']
# ['케이티지(주) following', '제조/화학', '2.6', '2,969']
# ['(주)벡트 following', '제조/화학', '2.7', '2,950']
# ['(주)유남옵틱스 following', '제조/화학', '3.3', '3,164']
# ['(주)유비스 following', '제조/화학', '1.6', '2,376']
# ['(주)지니틱스 following', '제조/화학', '3.0', '3,736']
# ['덕산홀딩스(주) following', '제조/화학', '4.1', '5,047']
# ['창성시트(주) following', '제조/화학', '3.5', '3,636']
# ['한미스위스광학(주) following', '제조/화학', '1.3', '2,021']
# ['(주)금영 following', '제조/화학', '2.9', '3,328']
# ['(주)포스텔 following', '제조/화학', '2.5', '2,648']
# ['(주)현성정밀기계 following', '제조/화학', '2.3', '2,950']
# ['글로닉스(주) following', '제조/화학', '3.1', '2,700']
# ['렉터슨(주) following', '제조/화학', '1.8', '3,488']
# ['한국후지필름일렉트로닉머티리얼즈(주) following', '제조/화학', '2.4', '4,026']
# ['(주)씨엘라이트 following', '제조/화학', '3.3', '3,387']
# ['(주)에이티유 following', '제조/화학', '2.1', '3,194']
# ['(주)에프엔에스 following', '제조/화학', '1.8', '3,383']
# ['(주)제이앤엠디스플레이 following', '제조/화학', '1.8', '3,122']
# ['(주)현대포멕스 following', '제조/화학', '3.9', '3,219']
# ['(주)볼트크리에이션 following', '제조/화학', '3.1', '2,759']
# ['(주)윤씨네 following', '제조/화학', '2.0', '2,940']
# ['(주)일레븐전자 following', '제조/화학', '2.0', '3,307']
# ['비에프테크(주) following', '제조/화학', '3.0', '3,918']
# ['제주반도체(주) following', '제조/화학', '3.5', '3,661']
# ['(주)하이브시스템 following', '제조/화학', '2.2', '3,052']
# ['디에스이테크(주) following', '제조/화학', '2.2', '2,733']
# ['한국신광마이크로애랙트로닉스(주) following', '제조/화학', '3.0', '3,508']
# ['(주)지엠 following', '제조/화학', '2.5', '3,415']
# ['티모스(주) following', '제조/화학', '2.6', '2,780']
# ['한라정밀엔지니어링(주) following', '제조/화학', '3.2', '3,090']
# ['(주)레이시스 following', '제조/화학', '2.8', '2,559']
# ['(주)에스알씨 following', '제조/화학', '1.8', '3,390']
# ['리스광시스템(주) following', '제조/화학', '3.6', '3,343']
# ['에코엘이디(주) following', '제조/화학', '2.1', '2,708']
# ['위더맥스(주) following', '제조/화학', '3.6', '4,050']
# ['투스템(주) following', '제조/화학', '2.1', '3,617']
# ['파인트론(주) following', '제조/화학', '2.8', '4,192']
# ['(주)에이치앤아비즈 following', '제조/화학', '2.0', '3,038']
# ['(주)옵토네스트 following', '제조/화학', '2.6', '0']
# ['(주)유에스티 following', '제조/화학', '3.3', '4,641']
# ['(주)인셈 following', '제조/화학', '2.9', '4,012']
# ['(주)지비티코리아 following', '제조/화학', '3.1', '4,187']
# ['(주)케이비엘러먼트 following', '제조/화학', '1.9', '3,480']
# ['디콘전자(주) following', '제조/화학', '1.8', '2,360']
# ['부원광학(주) following', '제조/화학', '2.5', '2,960']
# ['비전넥스트(주) following', '제조/화학', '3.5', '0']
# ['씨엠아이텍(주) following', '제조/화학', '2.9', '4,869']
# ['옵토니카(주) following', '제조/화학', '1.6', '2,835']
# ['(주)엠엔텍 following', '제조/화학', '2.6', '3,391']
# ['(주)파이칩스 following', '제조/화학', '3.3', '3,816']
# ['광우(주) following', '제조/화학', '2.1', '3,578']
# ['다솜테크(주) following', '제조/화학', '3.4', '3,205']
# ['다이아소닉테크놀로지(주) following', '제조/화학', '3.3', '3,226']
# ['델타전자(주) following', '제조/화학', '2.1', '2,961']
# ['디브이에스코리아(주) following', '제조/화학', '2.6', '4,646']
# ['메이플세미컨덕터(주) following', '제조/화학', '1.6', '2,831']
# ['발렉스코리아(주) following', '제조/화학', '2.7', '4,825']
# ['보다테크(주) following', '제조/화학', '2.3', '3,895']
# ['성주음향(주) following', '제조/화학', '2.3', '3,142']
# ['에이치아이디솔루션(주) following', '제조/화학', '1.3', '3,324']
# ['엔터기술(주) following', '제조/화학', '2.4', '4,006']
# ['엘피전자(주) following', '제조/화학', '2.6', '3,246']
# ['인티맥스(주) following', '제조/화학', '2.7', '5,472']
# ['(주)노비텍 following', '제조/화학', '2.2', '3,586']
# ['(주)반도기전 following', '제조/화학', '2.3', '3,257']
# ['(주)씨엠테크 following', '제조/화학', '3.5', '3,775']
# ['(주)옵토전자 following', '제조/화학', '3.2', '3,478']
# ['(주)요크 following', '제조/화학', '2.3', '2,837']
# ['대명엔터프라이즈(주) following', '제조/화학', '3.7', '3,467']
# ['레이디오펄스(주) following', '제조/화학', '3.2', '4,516']
# ['에스티엑스솔라(주) following', '제조/화학', '2.3', '4,075']
# ['유비머트리얼즈(주) following', '제조/화학', '1.8', '3,872']
# ['유창옵티칼(주) following', '제조/화학', '2.7', '4,474']
# ['이비덴코리아(주) following', '제조/화학', '2.8', '5,067']
# ['인토(주) following', '제조/화학', '2.0', '3,363']
# ['코아옵틱스(주) following', '제조/화학', '1.8', '2,603']
# ['한종엔지니어링(주) following', '제조/화학', '3.5', '7,035']
# ['(주)글로벌테크놀로지 following', '제조/화학', '2.8', '3,984']
# ['(주)루벤틱스에이디엠 following', '제조/화학', '1.2', '4,271']
# ['(주)엠시스 following', '제조/화학', '3.4', '8,958']
# ['(주)자람테크놀로지 following', '제조/화학', '3.6', '3,610']
# ['(주)테크노힐 following', '제조/화학', '3.0', '3,014']
# ['대우디스플레이(주) following', '제조/화학', '2.2', '4,543']
# ['목산전자(주) following', '제조/화학', '2.2', '2,897']
# ['에이디반도체(주) following', '제조/화학', '3.0', '4,539']
# ['옵틱라인즈(주) following', '제조/화학', '3.2', '3,381']
# ['이노웍스(주) following', '제조/화학', '2.0', '3,446']
# ['제타(주) following', '제조/화학', '2.0', '2,735']
# ['케이에스티(주) following', '제조/화학', '3.2', '3,370']
# ['한국킹유전자(주) following', '제조/화학', '2.2', '2,520']
# ['(주)알티솔루션 following', '제조/화학', '3.5', '3,726']
# ['(주)엠씨에스로직 following', '제조/화학', '2.8', '4,405']
# ['글라소울(주) following', '제조/화학', '2.5', '2,298']
# ['다윈텍(주) following', '제조/화학', '2.3', '2,799']
# ['디케이티(주) following', '제조/화학', '2.5', '3,338']
# ['베렉스(주) following', '제조/화학', '3.0', '3,318']
# ['아이디에스 following', '제조/화학', '1.5', '4,463']
# ['큐리어스(주) following', '제조/화학', '2.5', '2,525']
# ['크루셜칩스(주) following', '제조/화학', '2.3', '2,417']
# ['프리머스(주) following', '제조/화학', '2.3', '3,153']
# ['(주)아이렌 following', '제조/화학', '4.0', '0']
# ['(주)퓨엠 following', '제조/화학', '2.0', '2,969']
# ['넥스템(주) following', '제조/화학', '3.0', '1,680']
# ['다모아전자(주) following', '제조/화학', '1.3', '2,374']
# ['디에스(주) following', '제조/화학', '1.7', '3,534']
# ['리지스(주) following', '제조/화학', '1.7', '2,925']
# ['메가텍미디어(주) following', '제조/화학', '2.0', '3,984']
# ['소담미디어(주) following', '제조/화학', '3.0', '2,650']
# ['아이텍테크널러지(주) following', '제조/화학', '1.7', '3,280']
# ['에스디티시스템즈 following', '제조/화학', '3.0', '3,240']
# ['에스아이포유(주) following', '제조/화학', '3.0', '3,536']
# ['옵티컴(주) following', '제조/화학', '2.7', '3,219']
# ['위즈덤세미컨덕터(주) following', '제조/화학', '1.7', '4,390']
# ['유플러스(주) following', '제조/화학', '2.3', '6,459']
# ['타이스일렉(주) following', '제조/화학', '3.3', '2,665']
# ['하이캔버스(주) following', '제조/화학', '2.3', '2,467']
# ['(주)나노엑스코리아 following', '제조/화학', '4.5', '5,371']
# ['(주)마스카 following', '제조/화학', '2.0', '2,456']
# ['(주)세진프리시젼 following', '제조/화학', '1.0', '3,425']
# ['(주)신희 following', '제조/화학', '3.5', '0']
# ['(주)우빈 following', '제조/화학', '2.5', '0']
# ['(주)제이엠씨글라스 following', '제조/화학', '2.0', '2,973']
# ['(주)제이엠케이네트웍스 following', '제조/화학', '4.5', '4,982']
# ['(주)젠텍 following', '제조/화학', '3.5', '4,534']
# ['도서출판두리미디어 following', '제조/화학', '2.5', '3,785']
# ['디제이코리아 following', '제조/화학', '2.0', '3,581']
# ['루미스탈(주) following', '제조/화학', '4.0', '2,767']
# ['삼성패션(주) following', '제조/화학', '3.0', '4,704']
# ['이셀전자(주) following', '제조/화학', '4.0', '2,440']
# ['펄서스테크놀러지(주) following', '제조/화학', '2.0', '4,708']
# ['(주)동영테크 following', '제조/화학', '5.0', '0']
# ['(주)랩터 following', '제조/화학', '1.0', '0']
# ['(주)비티솔루션 following', '제조/화학', '3.0', '5,960']
# ['(주)엘제이캠 following', '제조/화학', '5.0', '0']
# ['(주)원세미콘 following', '제조/화학', '2.0', '0']
# ['(주)유니버셜스탠다드테크놀러지 following', '제조/화학', '3.0', '0']
# ['(주)이솔 following', '제조/화학', '2.0', '0']
# ['(주)커널로그 following', '제조/화학', '3.0', '2,379']
# ['(주)파인에바 following', '제조/화학', '1.0', '4,084']
# ['나래플러스(주) following', '제조/화학', '2.0', '2,438']
# ['남양테크윈(주) following', '제조/화학', '4.0', '2,846']
# ['동부솔라(주) following', '제조/화학', '5.0', '2,992']
# ['아시스토코리아(주) following', '제조/화학', '3.0', '0']
# ['에스디이엔지(주) following', '제조/화학', '4.0', '2,450']
# ['에스에이치(주) following', '제조/화학', '3.0', '4,875']
# ['에이디에스테크놀로지(주) following', '제조/화학', '2.0', '2,564']
# ['엑스와이시스템(주) following', '제조/화학', '2.0', '1,658']
# ['엔지알코리아(주) following', '제조/화학', '3.0', '6,189']
# ['웨이브닉스이에스피(주) following', '제조/화학', '2.0', '4,068']
# ['유비스타(주) following', '제조/화학', '2.0', '2,153']
# ['이스트후(주) following', '제조/화학', '5.0', '0']
# ['제이디아이 following', '제조/화학', '3.0', '0']
# ['중앙디스플레이(주) following', '제조/화학', '5.0', '2,211']
# ['티더블유티(주) following', '제조/화학', '3.0', '3,726']
# ['티엠에스솔루션(주) following', '제조/화학', '4.0', '0']
# ['피코기술나노재료(주) following', '제조/화학', '4.0', '7,084']
# ['현대오토콤 following', '제조/화학', '3.0', '3,690']
# ['황보정밀(주) following', '제조/화학', '1.0', '2,520']
# ['(주)내셔널칩스 following', '제조/화학', '0.0', '4,215']
# ['(주)네오테크 following', '제조/화학', '0.0', '0']
# ['(주)더블유지에스 following', '제조/화학', '0.0', '0']
# ['(주)디폰 following', '제조/화학', '0.0', '0']
# ['(주)미광전자 following', '제조/화학', '0.0', '0']
# ['(주)비티와이플러스 following', '제조/화학', '0.0', '0']
# ['(주)사피엔반도체 following', '제조/화학', '0.0', '0']
# ['(주)싸이닉솔루션 following', '제조/화학', '0.0', '7,047']
# ['(주)에스그래핀 following', '제조/화학', '0.0', '0']
# ['(주)엘립소테크놀러지 following', '제조/화학', '0.0', '0']
# ['(주)이지 following', '제조/화학', '0.0', '0']
# ['(주)큐버모티브 following', '제조/화학', '0.0', '0']
# ['거성 following', '제조/화학', '0.0', '2,158']
# ['글래틱(주) following', '제조/화학', '0.0', '0']
# ['다이프로(주) following', '제조/화학', '0.0', '2,298']
# ['라이트컨버젼코리아(주) following', '제조/화학', '0.0', '0']
# ['루이웍스(주) following', '제조/화학', '0.0', '3,690']
# ['서우(주) following', '제조/화학', '0.0', '5,119']
# ['서원전자(주) following', '제조/화학', '0.0', '3,315']
# ['승일테크 following', '제조/화학', '0.0', '3,777']
# ['신성택(주) following', '제조/화학', '0.0', '1,613']
# ['실리콘기어(주) following', '제조/화학', '0.0', '3,383']
# ['아이테크코리아(주) following', '제조/화학', '0.0', '3,597']
# ['오벨(주) following', '제조/화학', '0.0', '2,136']
# ['인펙스(주) following', '제조/화학', '0.0', '2,846']
# ['정원전자 following', '제조/화학', '0.0', '6,581']
# ['케이모션(Korea Motion) following', '제조/화학', '0.0', '0']
# ['포우 following', '제조/화학', '0.0', '0']
# ['서원전자(주) following', '제조/화학', '0.0', '3,315']
# ['승일테크 following', '제조/화학', '0.0', '3,777']
# ['신성택(주) following', '제조/화학', '0.0', '1,613']
# ['실리콘기어(주) following', '제조/화학', '0.0', '3,383']
# ['아이테크코리아(주) following', '제조/화학', '0.0', '3,597']
# ['오벨(주) following', '제조/화학', '0.0', '2,136']
# ['인펙스(주) following', '제조/화학', '0.0', '2,846']
# ['정원전자 following', '제조/화학', '0.0', '6,581']
# ['케이모션(Korea Motion) following', '제조/화학', '0.0', '0']
# ['포우 following', '제조/화학', '0.0', '0']
# ['서원전자(주) following', '제조/화학', '0.0', '3,315']
# ['승일테크 following', '제조/화학', '0.0', '3,777']
# ['신성택(주) following', '제조/화학', '0.0', '1,613']
# ['실리콘기어(주) following', '제조/화학', '0.0', '3,383']
# ['아이테크코리아(주) following', '제조/화학', '0.0', '3,597']
# ['오벨(주) following', '제조/화학', '0.0', '2,136']
# ['인펙스(주) following', '제조/화학', '0.0', '2,846']
# ['정원전자 following', '제조/화학', '0.0', '6,581']
# ['케이모션(Korea Motion) following', '제조/화학', '0.0', '0']
# ['포우 following', '제조/화학', '0.0', '0']
# ['서원전자(주) following', '제조/화학', '0.0', '3,315']
# ['승일테크 following', '제조/화학', '0.0', '3,777']
# ['신성택(주) following', '제조/화학', '0.0', '1,613']
# ['실리콘기어(주) following', '제조/화학', '0.0', '3,383']
# ['아이테크코리아(주) following', '제조/화학', '0.0', '3,597']
# ['오벨(주) following', '제조/화학', '0.0', '2,136']
# ['인펙스(주) following', '제조/화학', '0.0', '2,846']
# ['정원전자 following', '제조/화학', '0.0', '6,581']
# ['케이모션(Korea Motion) following', '제조/화학', '0.0', '0']
# ['포우 following', '제조/화학', '0.0', '0']
# ['서원전자(주) following', '제조/화학', '0.0', '3,315']
# ['승일테크 following', '제조/화학', '0.0', '3,777']
# ['신성택(주) following', '제조/화학', '0.0', '1,613']
# ['실리콘기어(주) following', '제조/화학', '0.0', '3,383']
# ['아이테크코리아(주) following', '제조/화학', '0.0', '3,597']
# ['오벨(주) following', '제조/화학', '0.0', '2,136']
# ['인펙스(주) following', '제조/화학', '0.0', '2,846']
# ['정원전자 following', '제조/화학', '0.0', '6,581']
# ['케이모션(Korea Motion) following', '제조/화학', '0.0', '0']
# ['포우 following', '제조/화학', '0.0', '0']
# ['서원전자(주) following', '제조/화학', '0.0', '3,315']
# ['승일테크 following', '제조/화학', '0.0', '3,777']
# ['신성택(주) following', '제조/화학', '0.0', '1,613']
# ['실리콘기어(주) following', '제조/화학', '0.0', '3,383']
# ['아이테크코리아(주) following', '제조/화학', '0.0', '3,597']
# ['오벨(주) following', '제조/화학', '0.0', '2,136']
# ['인펙스(주) following', '제조/화학', '0.0', '2,846']
# ['정원전자 following', '제조/화학', '0.0', '6,581']
# ['케이모션(Korea Motion) following', '제조/화학', '0.0', '0']
# ['포우 following', '제조/화학', '0.0', '0']

# %%
import pandas as pd 
com1 = company_list
columns=['기업이름','분야','평점','연봉']
df1 = pd.DataFrame(com1, columns=columns)

# %%
df1['기업이름'] = df1['기업이름'].str.split('f').str[0]
df1['평점'] = df1['평점'].astype(float)
df1['연봉'] = df1['연봉'].replace({',': ''}, regex=True)
df1['연봉'] = df1['연봉'].astype(int)
df1['2차산업군'] = '반도체/디스플레이'

# %%
df1.to_csv('../../../data/eda_project_data/잡플래닛/반도체디스플레이.csv',index=False)

# %%
driver.quit()
