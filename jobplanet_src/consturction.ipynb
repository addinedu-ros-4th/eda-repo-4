# %%
from tqdm.notebook import tqdm
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.request import Request
import urllib
from user_agent import generate_user_agent

# %%
driver = webdriver.Chrome(service=Service('../../../driver/chromedriver'))
driver.get('https://www.jobplanet.co.kr/companies?industry_id=600&page=1')

# %%
import time
from tqdm.notebook import tqdm

# company_list = []

for i in tqdm(range(1,100)):
    time.sleep(1)
    elements = driver.find_elements(By.CLASS_NAME, 'company.content_ty3')
    
    for elem in elements:
        company =[]

        name = elem.find_element(By.CLASS_NAME,'us_titb_l3').text
        field = elem.find_element(By.CLASS_NAME, 'us_stxt_1').text
        point = elem.find_element(By.CLASS_NAME, 'gfvalue').text
        money = elem.find_element(By.CLASS_NAME, 'notranslate').text
        
        company.append(name)
        company.append(field)
        company.append(point)
        company.append(money)
        company_list.append(company)
        print(company)

    driver.find_element(By.CLASS_NAME, 'btn_pgnext').click()
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]
# ['조인시스템(주) following', '건설업', '3.0', '3,688']
# ['준원도시경관연구센타(주) following', '건설업', '2.0', '2,340']
# ['중부매일 following', '건설업', '2.5', '2,340']
# ['진명이엔지(주) following', '건설업', '4.5', '4,785']
# ['진응종합건설(주) following', '건설업', '2.0', '3,447']
# ['창운(주) following', '건설업', '3.0', '3,383']
# ['천지개발(주) following', '건설업', '2.0', '3,403']
# ['케이에이치(주) following', '건설업', '4.0', '0']
# ['케이원 following', '건설업', '2.5', '1,743']
# ['코오롱엔지니어링(주) following', '건설업', '1.5', '0']
# ['조인시스템(주) following', '건설업', '3.0', '3,688']
# ['준원도시경관연구센타(주) following', '건설업', '2.0', '2,340']
# ['중부매일 following', '건설업', '2.5', '2,340']
# ['진명이엔지(주) following', '건설업', '4.5', '4,785']
# ['진응종합건설(주) following', '건설업', '2.0', '3,447']
# ['창운(주) following', '건설업', '3.0', '3,383']
# ['천지개발(주) following', '건설업', '2.0', '3,403']
# ['케이에이치(주) following', '건설업', '4.0', '0']
# ['케이원 following', '건설업', '2.5', '1,743']
# ['코오롱엔지니어링(주) following', '건설업', '1.5', '0']
# ['큐에셋 following', '건설업', '3.5', '2,417']
# ['터존(주) following', '건설업', '3.0', '4,331']
# ['토파스 following', '건설업', '3.0', '3,900']
# ['트랑고(주) following', '건설업', '2.5', '3,668']
# ['티오피 following', '건설업', '3.5', '2,050']
# ['프라임건설 following', '건설업', '4.0', '2,568']
# ['하우투비즈(주) following', '건설업', '3.5', '2,005']
# ['한가람엔지니어링(주) following', '건설업', '3.0', '2,145']
# ['한국조경개발(주) following', '건설업', '4.0', '0']
# ['한국케이블티브이방송협회(사) following', '건설업', '3.5', '4,195']
# ['한국콘도관리 following', '건설업', '2.5', '2,925']
# ['한용아이디씨(주) following', '건설업', '4.0', '1,755']
# ['한우리(주) following', '건설업', '2.5', '2,013']
# ['한일에스티엠(주) following', '건설업', '2.0', '3,116']
# ['한중엔지니어링(주) following', '건설업', '2.5', '0']
# ['현대공조(주) following', '건설업', '3.0', '2,440']
# ['현대엘리베이터설치(주) following', '건설업', '1.5', '3,296']
# ['희망교육 following', '건설업', '4.5', '1,845']
# ['(주)뉴트랜드 following', '건설업', '3.0', '0']
# ['(주)대영기계소방 following', '건설업', '1.0', '4,011']
# ['(주)대윤정보통신 following', '건설업', '1.0', '3,804']
# ['(주)더몽 following', '건설업', '2.0', '0']
# ['(주)도시다움 following', '건설업', '4.0', '0']
# ['(주)디아이엔지니어링 following', '건설업', '5.0', '2,825']
# ['(주)디엠씨엠 following', '건설업', '4.0', '5,418']
# ['(주)라보토리 following', '건설업', '1.0', '3,089']
# ['(주)루안디자인 following', '건설업', '2.0', '0']
# ['(주)브솔종합건축사사무소 following', '건설업', '3.0', '0']
# ['(주)빛세움 following', '건설업', '4.0', '4,392']
# ['(주)서해디앤씨 following', '건설업', '5.0', '0']
# ['(주)세종디자인 following', '건설업', '4.0', '0']
# ['(주)센추리21코리아 following', '건설업', '5.0', '4,963']
# ['(주)수주건설 following', '건설업', '2.0', '0']
# ['(주)아이오테크 following', '건설업', '4.0', '2,946']
# ['(주)양지트윈클 following', '건설업', '2.0', '0']
# ['(주)에이앤아이 following', '건설업', '3.0', '3,873']
# ['(주)예림종합건축사사무소 following', '건설업', '2.0', '3,541']
# ['(주)예성냉동산업 following', '건설업', '2.0', '2,734']
# ['(주)오케이디엔씨 following', '건설업', '4.0', '2,768']
# ['(주)이널리 following', '건설업', '1.0', '3,810']
# ['(주)이씨티 following', '건설업', '2.0', '2,361']
# ['(주)인케이디자인 following', '건설업', '2.0', '0']
# ['(주)재성환경 following', '건설업', '1.0', '3,177']
# ['(주)정감디자인 following', '건설업', '4.0', '2,711']
# ['(주)주택안전기술원 following', '건설업', '2.0', '0']
# ['(주)지아이에스21 following', '건설업', '2.0', '0']
# ['(주)청풍공조산업 following', '건설업', '2.0', '0']
# ['(주)청해엔지니어링 following', '건설업', '3.0', '3,087']
# ['(주)퀸즈홈즈 following', '건설업', '4.0', '5,125']
# ['(주)태한건설 following', '건설업', '2.0', '3,206']
# ['(주)트리플비전 following', '건설업', '2.0', '0']
# ['(주)팬웨스트에스앤티 following', '건설업', '5.0', '3,819']
# ['(주)피에이치파트너스그룹 following', '건설업', '5.0', '0']
# ['(주)피티에이공조 following', '건설업', '5.0', '0']
# ['(주)한고연 following', '건설업', '4.0', '0']
# ['(주)한국환경안전연구원 following', '건설업', '2.0', '2,777']
# ['(주)현대이엔씨 following', '건설업', '1.0', '0']
# ['갑진개발(주) following', '건설업', '4.0', '0']
# ['강남건설(주) following', '건설업', '4.0', '4,132']
# ['강림 following', '건설업', '4.0', '2,740']
# ['거산종합건설(주) following', '건설업', '3.0', '0']
# ['건축사사무소엘지 following', '건설업', '1.0', '0']
# ['건축사사무소이석디앤씨(주) following', '건설업', '2.0', '2,925']
# ['경기개발(주) following', '건설업', '3.0', '1,845']
# ['고황건설(주) following', '건설업', '3.0', '0']
# ['골드만삭스투자자문(주) following', '건설업', '3.0', '0']
# ['공정건설(주) following', '건설업', '4.0', '0']
# ['광림종합건설(주) following', '건설업', '3.0', '1,755']
# ['광천종합건설(주) following', '건설업', '3.0', '2,668']
# ['굿모닝리쿠르트 following', '건설업', '3.0', '2,729']
# ['그리마건설(주) following', '건설업', '3.0', '3,793']
# ['그린스페이스(주) following', '건설업', '3.0', '1,950']
# ['금동건축적산사무소(주) following', '건설업', '3.0', '4,100']
# ['나사(주) following', '건설업', '2.0', '2,870']
# ['나이스글로벌(주) following', '건설업', '3.0', '0']
# ['남해전기공사(주) following', '건설업', '4.0', '0']
# ['노무라코리아(주) following', '건설업', '4.0', '2,895']
# ['놀텍코리아(주) following', '건설업', '1.0', '3,941']
# ['늘봄(주) following', '건설업', '1.0', '1,575']
# ['대륭엔지니어링 following', '건설업', '3.0', '2,257']
# ['대맥건설산업(주) following', '건설업', '4.0', '1,755']
# ['대세전력(주) following', '건설업', '4.0', '0']
# ['대한 following', '건설업', '3.0', '3,842']
# ['더모아 following', '건설업', '3.0', '0']
# ['도원아이앤씨(주) following', '건설업', '1.0', '1,925']
# ['동양미래산업(주) following', '건설업', '4.0', '3,075']
# ['동열산업(주) following', '건설업', '3.0', '1,845']
# ['동일(주) following', '건설업', '1.0', '4,183']
# ['동화주택(주) following', '건설업', '3.0', '3,301']
# ['디비아이(주) following', '건설업', '4.0', '5,540']
# ['디자인그룹(주) following', '건설업', '2.0', '1,543']
# ['디자인노브(주) following', '건설업', '4.0', '4,100']
# ['디자인플랜트건축사사무소 following', '건설업', '4.0', '0']
# ['라움엔지니어링종합건축사사무소(주) following', '건설업', '3.0', '3,254']
# ['라이브스케이프(주) following', '건설업', '3.0', '0']
# ['라인테크놀로지(주) following', '건설업', '3.0', '1,950']
# ['리얼피엠(주) following', '건설업', '3.0', '0']
# ['마루와코리아(주) following', '건설업', '3.0', '3,383']
# ['메르씨엘 following', '건설업', '3.0', '2,298']
# ['미림도시개발(주) following', '건설업', '4.0', '6,765']
# ['밥디자인 following', '건설업', '2.0', '0']
# ['부산통신(주) following', '건설업', '3.0', '2,925']
# ['비손푸른엔지니어링(주) following', '건설업', '3.0', '2,864']
# ['비엠테크(주) following', '건설업', '3.0', '2,466']
# ['비토디자인(주) following', '건설업', '2.0', '0']
# ['사라다(주) following', '건설업', '5.0', '3,586']
# ['산들종합조경 following', '건설업', '2.0', '1,845']
# ['삼동환경(주) following', '건설업', '2.0', '2,133']
# ['삼보개발(주) following', '건설업', '2.0', '2,665']
# ['삼산기공(주) following', '건설업', '4.0', '3,244']
# ['삼상이엔지(주) following', '건설업', '2.0', '2,308']
# ['삼성설비 following', '건설업', '3.0', '4,100']
# ['삼영 following', '건설업', '1.0', '3,075']
# ['삼웅건설 following', '건설업', '3.0', '2,925']
# ['삼원이엔씨(주) following', '건설업', '4.0', '1,950']
# ['삼일건설(주) following', '건설업', '3.0', '2,925']
# ['삼호도시건설(주) following', '건설업', '3.0', '3,075']
# ['삼화건설 following', '건설업', '3.0', '3,688']
# ['상갑건설 following', '건설업', '4.0', '1,845']
# ['상경토건(주) following', '건설업', '2.0', '4,875']
# ['상아 following', '건설업', '3.0', '2,730']
# ['서우건설 following', '건설업', '3.0', '3,200']
# ['석우산업(주) following', '건설업', '2.0', '2,460']
# ['선에디슨코리아(주) following', '건설업', '4.0', '5,125']
# ['선진전력(주) following', '건설업', '1.0', '1,290']
# ['성남(주) following', '건설업', '5.0', '0']
# ['성완종합건설(주) following', '건설업', '4.0', '0']
# ['세계씨앤아이(주) following', '건설업', '3.0', '3,510']
# ['세우건설(주) following', '건설업', '2.0', '0']
# ['세원인테리어 following', '건설업', '3.0', '1,755']
# ['세이브(주) following', '건설업', '3.0', '2,340']
# ['세주티앤씨(주) following', '건설업', '3.0', '3,510']
# ['세진미디어통신 following', '건설업', '2.0', '2,219']
# ['수양(주) following', '건설업', '1.0', '1,755']
# ['수지인테리어 following', '건설업', '1.0', '0']
# ['수현엔지니어링(주) following', '건설업', '3.0', '3,075']
# ['스마트레일(주) following', '건설업', '3.0', '6,376']
# ['시엔플레이스(주) following', '건설업', '3.0', '2,255']
# ['신광산업(주) following', '건설업', '3.0', '3,900']
# ['신동아전기 following', '건설업', '3.0', '5,287']
# ['신한토건(주) following', '건설업', '3.0', '0']
# ['신화 following', '건설업', '4.0', '5,107']
# ['신화하이테크(주) following', '건설업', '4.0', '0']
# ['신흥(주) following', '건설업', '1.0', '4,202']
# ['쎄븐스타(주) following', '건설업', '2.0', '0']
# ['씨비리차드엘리스코리아(주) following', '건설업', '3.0', '3,413']
# ['아산이엔씨 following', '건설업', '2.0', '0']
# ['아이디스트(주) following', '건설업', '3.0', '2,765']
# ['아이에스컨설팅(주) following', '건설업', '4.0', '2,925']
# ['알파 following', '건설업', '1.0', '2,613']
# ['에스에스(주) following', '건설업', '3.0', '3,510']
# ['에이아이디(주) following', '건설업', '3.0', '3,726']
# ['에이텍종합건축사사무소(주) following', '건설업', '3.0', '2,848']
# ['에프앤씨건설(주) following', '건설업', '5.0', '0']
# ['엘에스디자인(주) following', '건설업', '1.0', '0']
# ['엠에스에듀케이션(주) following', '건설업', '5.0', '0']
# ['엠파워(주) following', '건설업', '3.0', '3,336']
# ['오릭스저축은행(주) following', '건설업', '4.0', '3,875']
# ['와이지건축사사무소(주) following', '건설업', '3.0', '2,925']
# ['우리티앤씨(주) following', '건설업', '3.0', '2,563']
# ['우방건설(주) following', '건설업', '3.0', '2,900']
# ['우익(주) following', '건설업', '3.0', '2,145']
# ['원테크 following', '건설업', '1.0', '0']
# ['위대한디자인 following', '건설업', '3.0', '0']
# ['유니시티(주) following', '건설업', '4.0', '6,058']
# ['인스타(주) following', '건설업', '2.0', '1,950']
# ['인정건설(주) following', '건설업', '3.0', '4,000']
# ['인천광역시경제통상진흥원(재) following', '건설업', '4.0', '0']
# ['일본산소코리아(주) following', '건설업', '1.0', '3,801']
# ['일신기업(주) following', '건설업', '1.0', '0']
# ['정우이앤씨(주) following', '건설업', '3.0', '0']
# ['제이에스이엔지(주) following', '건설업', '1.0', '3,900']
# ['죽암건설(주) following', '건설업', '1.0', '3,089']
# ['중앙종합관리(주) following', '건설업', '2.0', '1,755']
# ['지앤티네트웍스(주) following', '건설업', '3.0', '2,373']
# ['지우감정평가법인 following', '건설업', '4.0', '3,905']
# ['진방 following', '건설업', '3.0', '1,755']
# ['진영엔지니어링 following', '건설업', '5.0', '2,340']
# ['창건축사사무소(주) following', '건설업', '1.0', '2,730']
# ['창인전력(주) following', '건설업', '4.0', '3,900']
# ['카이치랜드(주) following', '건설업', '5.0', '5,850']
# ['케이와이씨(주) following', '건설업', '4.0', '2,662']
# ['케이피엑스개발(주) following', '건설업', '3.0', '3,537']
# ['켐피아(주) following', '건설업', '4.0', '3,902']
# ['타임건설(주) following', '건설업', '1.0', '3,075']
# ['탑엔이엠이(주) following', '건설업', '2.0', '4,465']
# ['태양건설(주) following', '건설업', '3.0', '2,267']
# ['태양토건(주) following', '건설업', '3.0', '0']
# ['텔레카(주) following', '건설업', '2.0', '6,453']
# ['토마토디자인(주) following', '건설업', '4.0', '2,050']
# ['토문컨설탄트건축사사무소(주) following', '건설업', '4.0', '2,828']
# ['토우컨설턴트(주) following', '건설업', '2.0', '2,460']
# ['톤엔터테인먼트(주) following', '건설업', '2.0', '0']
# ['티엘인베스트 following', '건설업', '3.0', '2,925']
# ['페이지(주) following', '건설업', '4.0', '0']
# ['평택엔지니어링(주) following', '건설업', '2.0', '1,164']
# ['푸른지붕 following', '건설업', '3.0', '3,075']
# ['풍산개발(주) following', '건설업', '3.0', '1,487']
# ['프라브코리아(주) following', '건설업', '5.0', '2,298']
# ['하우시스(주) following', '건설업', '4.0', '2,925']
# ['한강오엠에스(주) following', '건설업', '3.0', '0']
# ['한경인터내셔널(주) following', '건설업', '2.0', '0']
# ['한국건축구조기술사회 following', '건설업', '3.0', '0']
# ['한국지적토목측량공사(주) following', '건설업', '3.0', '2,670']
# ['한국투아치(주) following', '건설업', '3.0', '1,989']
# ['한길종합건축사사무소(주) following', '건설업', '4.0', '2,119']
# ['한미리 following', '건설업', '3.0', '1,800']
# ['한백엔지니어링(주) following', '건설업', '2.0', '2,365']
# ['한솔PNC following', '건설업', '3.0', '4,340']
# ['한유건설(주) following', '건설업', '2.0', '0']
# ['한주전설(주) following', '건설업', '4.0', '4,583']
# ['한투(주) following', '건설업', '4.0', '5,381']
# ['해남개발 following', '건설업', '4.0', '2,925']
# ['현중 following', '건설업', '2.0', '5,269']
# ['혜우이엔씨(주) following', '건설업', '1.0', '0']
# ['호남 following', '건설업', '3.0', '5,381']
# ['홍(주) following', '건설업', '1.0', '0']
# ['홍건개발(주) following', '건설업', '2.0', '0']
# ['화영일렉콤(주) following', '건설업', '5.0', '3,901']
# ['효진산업(주) following', '건설업', '3.0', '5,125']
# ['휴먼텍에이엔씨종합건축사사무소 following', '건설업', '4.0', '0']
# ['(유)복정대토개발 following', '건설업', '0.0', '0']
# ['(유)장강 following', '건설업', '0.0', '2,953']
# ['(주)거화건영 following', '건설업', '0.0', '0']
# ['(주)건영티에스씨 following', '건설업', '0.0', '0']
# ['(주)건축사사무소플리드 following', '건설업', '0.0', '0']
# ['(주)골드인베스트 following', '건설업', '0.0', '0']
# ['(주)공간온 following', '건설업', '0.0', '0']
# ['(주)공감나눔 following', '건설업', '0.0', '0']
# ['(주)나우씨앤엠 following', '건설업', '0.0', '0']
# ['(주)남경엔지니어링 following', '건설업', '0.0', '0']
# ['(주)넥스테라 following', '건설업', '0.0', '0']
# ['(주)농업회사법인 식물감각 following', '건설업', '0.0', '0']
# ['(주)다원안전 following', '건설업', '0.0', '0']
# ['(주)대건종합건설 following', '건설업', '0.0', '0']
# ['(주)대동엔지니어링 following', '건설업', '0.0', '0']
# ['(주)더피버인테리어디자인 following', '건설업', '0.0', '0']
# ['(주)도로시 following', '건설업', '0.0', '0']
# ['(주)디맥스 following', '건설업', '0.0', '0']
# ['(주)디자인에이드 following', '건설업', '0.0', '0']
# ['(주)디자인이스트 following', '건설업', '0.0', '0']
# ['(주)라움건축사사무소 following', '건설업', '0.0', '0']
# ['(주)모든사람들 following', '건설업', '0.0', '0']
# ['(주)무늬디자인 following', '건설업', '0.0', '0']
# ['(주)바로부동산중개법인 following', '건설업', '0.0', '0']
# ['(주)반더펠트에스 following', '건설업', '0.0', '0']
# ['(주)범한더블유에이치산업 following', '건설업', '0.0', '3,690']
# ['(주)보람기술 following', '건설업', '0.0', '0']
# ['(주)블렌즈 following', '건설업', '0.0', '0']
# ['(주)비디엔에프 following', '건설업', '0.0', '0']
# ['(주)선우엔지니어링 following', '건설업', '0.0', '0']
# ['(주)센텀 following', '건설업', '0.0', '0']
# ['(주)소나무구조안전건축사사무소 following', '건설업', '0.0', '0']
# ['(주)송원엔지니어링건축사사무소 following', '건설업', '0.0', '3,627']
# ['(주)스퀘어원 following', '건설업', '0.0', '0']
# ['(주)승보이엔씨건축사사무소 following', '건설업', '0.0', '4,543']
# ['(주)승지디앤엠 following', '건설업', '0.0', '0']
# ['(주)신세대테크 following', '건설업', '0.0', '2,999']
# ['(주)신화소방엔지니어링 following', '건설업', '0.0', '0']
# ['(주)아람기술 following', '건설업', '0.0', '0']
# ['(주)아키션 following', '건설업', '0.0', '0']
# ['(주)알이파트너 following', '건설업', '0.0', '0']
# ['(주)애플프라임인베스트 following', '건설업', '0.0', '0']
# ['(주)어스에코 following', '건설업', '0.0', '0']
# ['(주)에스디이엔지 following', '건설업', '0.0', '0']
# ['(주)에이앤트디자인 following', '건설업', '0.0', '0']
# ['(주)에이치앤티 following', '건설업', '0.0', '1,845']
# ['(주)엘엔케이어소시에이츠 following', '건설업', '0.0', '2,370']
# ['(주)엠케이시스템 following', '건설업', '0.0', '0']
# ['(주)연컨설턴트 following', '건설업', '0.0', '3,186']
# ['(주)영빈알앤디 following', '건설업', '0.0', '2,716']
# ['(주)와이들 following', '건설업', '0.0', '0']
# ['(주)우리에이치알컴퍼니 following', '건설업', '0.0', '0']
# ['(주)위고엔지니어링 following', '건설업', '0.0', '0']
# ['(주)위어스파트너스 following', '건설업', '0.0', '0']
# ['(주)유디자인연구소 following', '건설업', '0.0', '2,432']
# ['(주)윤택한조경 following', '건설업', '0.0', '0']
# ['(주)이든파트너스 following', '건설업', '0.0', '0']
# ['(주)이로이 following', '건설업', '0.0', '0']
# ['(주)이안구조엔지니어링 following', '건설업', '0.0', '5,011']
# ['(주)이현디자인 following', '건설업', '0.0', '0']
# ['(주)일성건설 following', '건설업', '0.0', '5,399']
# ['(주)일신개발 following', '건설업', '0.0', '0']
# ['(주)잘그린건축연구소 following', '건설업', '0.0', '0']
# ['(주)제이아이텍이엔지 following', '건설업', '0.0', '0']
# ['(주)제이앤디건축사사무소 following', '건설업', '0.0', '0']
# ['(주)제이엔지인베스트 following', '건설업', '0.0', '0']
# ['(주)조아 following', '건설업', '0.0', '0']
# ['(주)종우앤종우소방기술단 following', '건설업', '0.0', '2,551']
# ['(주)중앙이엠씨 following', '건설업', '0.0', '3,058']
# ['(주)지문도시건축 following', '건설업', '0.0', '0']
# ['(주)진원산업개발 following', '건설업', '0.0', '0']
# ['(주)케이씨엠씨 following', '건설업', '0.0', '3,638']
# ['(주)케이엔에스 following', '건설업', '0.0', '2,815']
# ['(주)콤파스이앤씨 following', '건설업', '0.0', '0']
# ['(주)텐나인 following', '건설업', '0.0', '0']
# ['(주)토브씨앤지 following', '건설업', '0.0', '0']
# ['(주)트러스트에이엔씨 following', '건설업', '0.0', '0']
# ['(주)티에이디코퍼레이션 following', '건설업', '0.0', '0']
# ['(주)티지어소시에이션 following', '건설업', '0.0', '2,804']
# ['(주)푸름에코컨설팅 following', '건설업', '0.0', '0']
# ['(주)퓨어웍스 following', '건설업', '0.0', '0']
# ['(주)하나종합건축사사무소 following', '건설업', '0.0', '0']
# ['(주)한신코아건설 following', '건설업', '0.0', '3,396']
# ['(주)한양 following', '건설업', '0.0', '4,717']
# ['(주)효림컴퍼니 following', '건설업', '0.0', '0']
# ['C.N.E. (건축과 환경) following', '건설업', '0.0', '0']
# ['HE지하안전연구원 following', '건설업', '0.0', '0']
# ['Yoon ID following', '건설업', '0.0', '0']
# ['가람스페이스(주) following', '건설업', '0.0', '2,563']
# ['가화감정평가법인(주) following', '건설업', '0.0', '2,602']
# ['건일전기(유) following', '건설업', '0.0', '1,050']
# ['건축사사무소바이페이퍼스케이프(주) following', '건설업', '0.0', '2,972']
# ['건환(주) following', '건설업', '0.0', '2,050']
# ['경성엔터프라이즈(주) following', '건설업', '0.0', '0']
# ['공감디자인(주) following', '건설업', '0.0', '2,598']
# ['그레이트폼웍(주) following', '건설업', '0.0', '0']
# ['김영준도시건축연구소(주) following', '건설업', '0.0', '3,363']
# ['나이트프랭크코리아(주) following', '건설업', '0.0', '3,101']
# ['나인(주) following', '건설업', '0.0', '3,300']
# ['남일기술단(주) following', '건설업', '0.0', '1,950']
# ['느티(주) following', '건설업', '0.0', '1,755']
# ['대륭건설(주) following', '건설업', '0.0', '0']
# ['대방설비(주) following', '건설업', '0.0', '2,340']
# ['대영엠이씨(주) following', '건설업', '0.0', '0']
# ['대우산기(주) following', '건설업', '0.0', '0']
# ['대원전화통신공사 following', '건설업', '0.0', '0']
# ['동성종합건설(주) following', '건설업', '0.0', '0']
# ['동양기전엘리베이터(주) following', '건설업', '0.0', '3,156']
# ['동양피엔에이(주) following', '건설업', '0.0', '0']
# ['동일디앤씨(주) following', '건설업', '0.0', '1,755']
# ['동진건설(주) following', '건설업', '0.0', '4,613']
# ['디에스텔레콤(주) following', '건설업', '0.0', '1,950']
# ['디자인샐러드(주) following', '건설업', '0.0', '1,575']
# ['디케이디자인코퍼레이션(주) following', '건설업', '0.0', '0']
# ['뚝딱김반장 following', '건설업', '0.0', '0']
# ['라이프앤웍스 following', '건설업', '0.0', '2,298']
# ['로컬드라이브건축사사무소(주) following', '건설업', '0.0', '0']
# ['리빌딩 부동산중개 following', '건설업', '0.0', '0']
# ['맥구조안전(주) following', '건설업', '0.0', '0']
# ['맹호종합건설(주) following', '건설업', '0.0', '2,091']
# ['명성기업 following', '건설업', '0.0', '3,900']
# ['명원건설(주) following', '건설업', '0.0', '2,527']
# ['모스 following', '건설업', '0.0', '0']
# ['문(주) following', '건설업', '0.0', '2,566']
# ['미관건설(주) following', '건설업', '0.0', '5,119']
# ['미래산업전기(주) following', '건설업', '0.0', '3,690']
# ['미래인터내셔날 following', '건설업', '0.0', '9,019']
# ['바른소방(주) following', '건설업', '0.0', '0']
# ['반종합건축사사무소의전동인(주) following', '건설업', '0.0', '3,895']
# ['백석토건(주) following', '건설업', '0.0', '3,568']
# ['백송 following', '건설업', '0.0', '0']
# ['범일전기 following', '건설업', '0.0', '2,340']
# ['보람(주) following', '건설업', '0.0', '4,092']
# ['보선건설(주) following', '건설업', '0.0', '0']
# ['보성엔지니어링(주) following', '건설업', '0.0', '5,080']
# ['부엉이공인중개사사무소 following', '건설업', '0.0', '0']
# ['비에이치아이건설(주) following', '건설업', '0.0', '5,330']
# ['비엔코리아(주) following', '건설업', '0.0', '0']
# ['비투비랩(주) following', '건설업', '0.0', '0']
# ['빌딩숲부동산중개(주) following', '건설업', '0.0', '0']
# ['삼주환경산업(주) following', '건설업', '0.0', '2,671']
# ['삼후종합건설(주) following', '건설업', '0.0', '0']
# ['샤프(주) following', '건설업', '0.0', '3,184']
# ['서남해안레저(주) following', '건설업', '0.0', '0']
# ['서울문산고속도로(주) following', '건설업', '0.0', '0']
# ['서진정보산업(주) following', '건설업', '0.0', '3,120']
# ['성일바이오(주) following', '건설업', '0.0', '3,900']
# ['성진건설산업(주) following', '건설업', '0.0', '0']
# ['성현기업(주) following', '건설업', '0.0', '0']
# ['수완 following', '건설업', '0.0', '3,539']
# ['승화프리텍(주) following', '건설업', '0.0', '4,305']
# ['시큐어트리(주) following', '건설업', '0.0', '0']
# ['신도건설(주) following', '건설업', '0.0', '0']
# ['신성정보통신(주) following', '건설업', '0.0', '0']
# ['신우이앤지(주) following', '건설업', '0.0', '2,276']
# ['씨디엔지니어링(주) following', '건설업', '0.0', '2,075']
# ['아름이엔씨(주) following', '건설업', '0.0', '2,535']
# ['알투엔지니어링 following', '건설업', '0.0', '3,075']
# ['알티(주) following', '건설업', '0.0', '3,383']
# ['알피종합건축사사무소(주) following', '건설업', '0.0', '4,680']
# ['에듀온(주) following', '건설업', '0.0', '1,916']
# ['에듀챌린지(주) following', '건설업', '0.0', '0']
# ['에스비건설(주) following', '건설업', '0.0', '4,193']
# ['에스에이치알앤디 following', '건설업', '0.0', '0']
# ['에스이워크 following', '건설업', '0.0', '0']
# ['에이앤디(주) following', '건설업', '0.0', '0']
# ['에이앤유씨엠건축사사무소(주) following', '건설업', '0.0', '0']
# ['에이치와이건설(주) following', '건설업', '0.0', '0']
# ['에이치와이씨 following', '건설업', '0.0', '0']
# ['엔에스창조(주) following', '건설업', '0.0', '3,094']
# ['엔피티아(주) following', '건설업', '0.0', '3,120']
# ['엘시티(주) following', '건설업', '0.0', '0']
# ['연성(주) following', '건설업', '0.0', '3,730']
# ['영성에레베이터 following', '건설업', '0.0', '3,075']
# ['영주건설(주) following', '건설업', '0.0', '3,413']
# ['영플랜건축사사무소(주) following', '건설업', '0.0', '3,608']
# ['예광 following', '건설업', '0.0', '0']
# ['예람(주) following', '건설업', '0.0', '2,958']
# ['예시건건축사사무소(주) following', '건설업', '0.0', '2,340']
# ['예인엔지니어링(주) following', '건설업', '0.0', '3,793']
# ['오다엔지니어링(주) following', '건설업', '0.0', '0']
# ['오디 following', '건설업', '0.0', '2,103']
# ['오즈씨앤디(주) following', '건설업', '0.0', '0']
# ['오지케이(주) following', '건설업', '0.0', '2,768']
# ['온재건축사사무소 following', '건설업', '0.0', '0']
# ['와이비이엔씨(주) following', '건설업', '0.0', '3,402']
# ['우림에프앤티 following', '건설업', '0.0', '0']
# ['울산개발(주) following', '건설업', '0.0', '3,588']
# ['웅남스틸(주) following', '건설업', '0.0', '3,120']
# ['원영전력(주) following', '건설업', '0.0', '0']
# ['웰시스템(주) following', '건설업', '0.0', '5,166']
# ['유명건설 following', '건설업', '0.0', '2,050']
# ['유앤피(주) following', '건설업', '0.0', '2,730']
# ['유화(주) following', '건설업', '0.0', '4,216']
# ['이데아 following', '건설업', '0.0', '0']
# ['이산공조시스템 following', '건설업', '0.0', '0']
# ['이엔디 following', '건설업', '0.0', '2,925']
# ['이프(주) following', '건설업', '0.0', '3,168']
# ['인성건설산업(주) following', '건설업', '0.0', '0']
# ['인엔디자인웍스(주) following', '건설업', '0.0', '3,342']
# ['인플러스(주) following', '건설업', '0.0', '1,755']
# ['전력용지보상(주) following', '건설업', '0.0', '2,516']
# ['정상종합건설(주) following', '건설업', '0.0', '3,771']
# ['정정보통신(주) following', '건설업', '0.0', '2,438']
# ['제영종합건설 following', '건설업', '0.0', '1,845']
# ['제이에스이엔씨(주) following', '건설업', '0.0', '0']
# ['제이웰(주) following', '건설업', '0.0', '5,850']
# ['종근당산업(주) following', '건설업', '0.0', '5,411']
# ['주식회사 916건축디자인 following', '건설업', '0.0', '0']
# ['중앙건설(주) following', '건설업', '0.0', '3,768']
# ['중앙건설(주) following', '건설업', '0.0', '3,120']
# ['지앤지코퍼레이션(주) following', '건설업', '0.0', '1,950']
# ['지오에스엠(주) following', '건설업', '0.0', '4,124']
# ['창희파워(주) following', '건설업', '0.0', '0']
# ['청계원(유)농업회사법인(유) following', '건설업', '0.0', '0']
# ['컬리넌종합건설(주) following', '건설업', '0.0', '2,340']
# ['케놀건설(주) following', '건설업', '0.0', '4,875']
# ['케이개발(주) following', '건설업', '0.0', '2,911']
# ['케이렘(주) following', '건설업', '0.0', '4,100']
# ['케이씨이(주) following', '건설업', '0.0', '1,755']
# ['케이에프에프(주) following', '건설업', '0.0', '3,413']
# ['코원건설(주) following', '건설업', '0.0', '0']
# ['콜드웰뱅커코리아(주) following', '건설업', '0.0', '2,050']
# ['크레던스매니지먼트(주) following', '건설업', '0.0', '0']
# ['크리엔커퍼레이션(주) following', '건설업', '0.0', '2,535']
# ['태경하우디자인(주) following', '건설업', '0.0', '1,845']
# ['태화강재산업(주) following', '건설업', '0.0', '4,934']
# ['토성공영(주) following', '건설업', '0.0', '2,438']
# ['투에이플랜건축사사무소 following', '건설업', '0.0', '0']
# ['티아이 구조기술사사무소 following', '건설업', '0.0', '0']
# ['티에이치베스트먼트 following', '건설업', '0.0', '0']
# ['티엔케이(주) following', '건설업', '0.0', '3,402']
# ['파스텔씨엠(주) following', '건설업', '0.0', '9,786']
# ['파트너스자산관리(주) following', '건설업', '0.0', '0']
# ['프렌즈(주) following', '건설업', '0.0', '1,845']
# ['프렌즈부동산공인중개사사무소 following', '건설업', '0.0', '0']
# ['한국전기 following', '건설업', '0.0', '1,725']
# ['한서기획(주) following', '건설업', '0.0', '2,145']
# ['한웰(주) following', '건설업', '0.0', '8,459']
# ['해경 following', '건설업', '0.0', '0']
# ['핸즈커뮤니케이션(주) following', '건설업', '0.0', '12,300']
# ['현대공인중개사사무소 following', '건설업', '0.0', '0']
# ['홍익산업개발(주) following', '건설업', '0.0', '0']
# ['화신(주) following', '건설업', '0.0', '3,218']
# ['해경 following', '건설업', '0.0', '0']
# ['핸즈커뮤니케이션(주) following', '건설업', '0.0', '12,300']
# ['현대공인중개사사무소 following', '건설업', '0.0', '0']
# ['홍익산업개발(주) following', '건설업', '0.0', '0']
# ['화신(주) following', '건설업', '0.0', '3,218']
# ['해경 following', '건설업', '0.0', '0']
# ['핸즈커뮤니케이션(주) following', '건설업', '0.0', '12,300']
# ['현대공인중개사사무소 following', '건설업', '0.0', '0']
# ['홍익산업개발(주) following', '건설업', '0.0', '0']
# ['화신(주) following', '건설업', '0.0', '3,218']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 25
#      22     company_list.append(company)
#      23     print(company)
# ---> 25 driver.find_element(By.CLASS_NAME, 'btn_pgnext').click()
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:742, in WebDriver.find_element(self, by, value)
#     739     by = By.CSS_SELECTOR
#     740     value = f'[name="{value}"]'
# --> 742 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     343     elif "sessionId" not in params:
#     344         params["sessionId"] = self.session_id
# --> 346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
#     348     self.error_handler.check_response(response)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:300, in RemoteConnection.execute(self, command, params)
#     298 data = utils.dump_json(params)
#     299 url = f"{self._url}{path}"
# --> 300 return self._request(command_info[0], url, body=data)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:321, in RemoteConnection._request(self, method, url, body)
#     318     body = None
#     320 if self.keep_alive:
# --> 321     response = self._conn.request(method, url, body=body, headers=headers)
#     322     statuscode = response.status
#     323 else:
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/_request_methods.py:118, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     110     return self.request_encode_url(
#     111         method,
#     112         url,
#    (...)
#     115         **urlopen_kw,
#     116     )
#     117 else:
# --> 118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/_request_methods.py:217, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     213     extra_kw["headers"].setdefault("Content-Type", content_type)
#     215 extra_kw.update(urlopen_kw)
# --> 217 return self.urlopen(method, url, **extra_kw)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/poolmanager.py:444, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     442     response = conn.urlopen(method, url, **kw)
#     443 else:
# --> 444     response = conn.urlopen(method, u.request_uri, **kw)
#     446 redirect_location = redirect and response.get_redirect_location()
#     447 if not redirect_location:
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:337, in HTTPResponse.begin(self)
#     334 else:
#     335     raise UnknownProtocol(version)
# --> 337 self.headers = self.msg = parse_headers(self.fp)
#     339 if self.debuglevel > 0:
#     340     for hdr, val in self.headers.items():
#
# File /usr/lib/python3.10/http/client.py:236, in parse_headers(fp, _class)
#     234 headers = _read_headers(fp)
#     235 hstring = b''.join(headers).decode('iso-8859-1')
# --> 236 return email.parser.Parser(_class=_class).parsestr(hstring)
#
# File /usr/lib/python3.10/email/parser.py:67, in Parser.parsestr(self, text, headersonly)
#      59 def parsestr(self, text, headersonly=False):
#      60     """Create a message structure from a string.
#      61
#      62     Returns the root of the message structure.  Optional headersonly is a
#    (...)
#      65     the file.
#      66     """
# ---> 67     return self.parse(StringIO(text), headersonly=headersonly)
#
# File /usr/lib/python3.10/email/parser.py:56, in Parser.parse(self, fp, headersonly)
#      54     if not data:
#      55         break
# ---> 56     feedparser.feed(data)
#      57 return feedparser.close()
#
# File /usr/lib/python3.10/email/feedparser.py:176, in FeedParser.feed(self, data)
#     174 """Push more data into the parser."""
#     175 self._input.push(data)
# --> 176 self._call_parse()
#
# File /usr/lib/python3.10/email/feedparser.py:180, in FeedParser._call_parse(self)
#     178 def _call_parse(self):
#     179     try:
# --> 180         self._parse()
#     181     except StopIteration:
#     182         pass
#
# File /usr/lib/python3.10/email/feedparser.py:224, in FeedParser._parsegen(self)
#     221 headers = []
#     222 # Collect the headers, searching for a line that doesn't match the RFC
#     223 # 2822 header or continuation pattern (including an empty line).
# --> 224 for line in self._input:
#     225     if line is NeedMoreData:
#     226         yield NeedMoreData
#
# File /usr/lib/python3.10/email/feedparser.py:129, in BufferedSubFile.__next__(self)
#     128 def __next__(self):
# --> 129     line = self.readline()
#     130     if line == '':
#     131         raise StopIteration
#
# File /usr/lib/python3.10/email/feedparser.py:85, in BufferedSubFile.readline(self)
#      82     return NeedMoreData
#      83 # Pop the line off the stack and see if it matches the current
#      84 # false-EOF predicate.
# ---> 85 line = self._lines.popleft()
#      86 # RFC 2046, section 5.1.2 requires us to recognize outer level
#      87 # boundaries at any level of inner nesting.  Do this, but be sure it's
#      88 # in the order of most to least nested.
#      89 for ateof in reversed(self._eofstack):
#
# KeyboardInterrupt:

# %%
import pandas as pd 
com1 = company_list
columns=['기업이름','분야','평점','연봉']
df1 = pd.DataFrame(com1, columns=columns)

# %%
df1['기업이름'] = df1['기업이름'].str.split('f').str[0]
df1['평점'] = df1['평점'].astype(float)
df1['연봉'] = df1['연봉'].replace({',': ''}, regex=True)
df1['연봉'] = df1['연봉'].astype(int)
df1['2차산업군'] = '건설업'

# %%
df1.to_csv('../../../data/eda_project_data/잡플래닛/건설업.csv',index=False)

# %%
driver.quit()
