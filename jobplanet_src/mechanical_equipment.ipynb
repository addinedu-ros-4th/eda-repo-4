# %%
from tqdm.notebook import tqdm
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.request import Request
import urllib
from user_agent import generate_user_agent

# %%
driver = webdriver.Chrome(service=Service('../../../driver/chromedriver'))
driver.get('https://www.jobplanet.co.kr/companies?industry_id=208&page=1')

# %%
import time
from tqdm.notebook import tqdm

# company_list = []

for i in tqdm(range(1,140)):
    time.sleep(1)
    elements = driver.find_elements(By.CLASS_NAME, 'company.content_ty3')
    
    for elem in elements:
        company =[]

        name = elem.find_element(By.CLASS_NAME,'us_titb_l3').text
        field = elem.find_element(By.CLASS_NAME, 'us_stxt_1').text
        point = elem.find_element(By.CLASS_NAME, 'gfvalue').text
        money = elem.find_element(By.CLASS_NAME, 'notranslate').text
        
        company.append(name)
        company.append(field)
        company.append(point)
        company.append(money)
        company_list.append(company)
        print(company)

    driver.find_element(By.CLASS_NAME, 'btn_pgnext').click()
# Out:
#   0%|          | 0/139 [00:00<?, ?it/s]
# ['진영산업(주) following', '제조/화학', '2.0', '3,473']
# ['태양기계(주) following', '제조/화학', '2.3', '3,446']
# ['(주)레이 following', '제조/화학', '2.9', '4,623']
# ['(주)세아엔지니어링 following', '제조/화학', '2.3', '3,523']
# ['대유에이텍(주) following', '제조/화학', '2.6', '4,427']
# ['세동(주) following', '제조/화학', '2.5', '4,049']
# ['제닉스(주) following', '제조/화학', '2.7', '3,411']
# ['(주)바텍이우홀딩스 following', '제조/화학', '2.4', '5,070']
# ['오션브릿지(주) following', '제조/화학', '2.6', '3,305']
# ['우림피티에스(주) following', '제조/화학', '2.2', '3,770']
# ['유네코(주) following', '제조/화학', '2.4', '3,654']
# ['(주)성신알에스티 following', '제조/화학', '1.4', '3,483']
# ['대모엔지니어링(주) following', '제조/화학', '2.4', '3,610']
# ['모델솔루션(주) following', '제조/화학', '2.3', '3,712']
# ['발레오오토모티브코리아(주) following', '제조/화학', '2.5', '5,563']
# ['타타대우상용차(주) following', '제조/화학', '3.6', '5,897']
# ['(주)얼라인드제네틱스 following', '제조/화학', '3.3', '4,488']
# ['(주)에스엠코어 following', '제조/화학', '2.2', '4,073']
# ['(주)지에스메디칼 following', '제조/화학', '2.2', '3,417']
# ['건화트렐러보그(주) following', '제조/화학', '2.6', '4,048']
# ['대동하이렉스(주) following', '제조/화학', '2.7', '4,355']
# ['(주)이파워기술단 following', '제조/화학', '2.4', '3,117']
# ['리텍(주) following', '제조/화학', '2.6', '3,881']
# ['(주)엠아이텍 following', '제조/화학', '2.7', '3,419']
# ['(주)제이에스테크 following', '제조/화학', '1.6', '3,156']
# ['(주)한일진공 following', '제조/화학', '2.3', '3,172']
# ['성안기계(주) following', '제조/화학', '2.4', '3,252']
# ['(주)비엠코리아 following', '제조/화학', '1.6', '2,929']
# ['(주)청호ICT following', '제조/화학', '2.2', '3,231']
# ['동인중공업(주) following', '제조/화학', '3.1', '3,468']
# ['인터콘시스템스(주) following', '제조/화학', '2.2', '3,372']
# ['하드램(주) following', '제조/화학', '2.3', '3,145']
# ['(주)코디마 following', '제조/화학', '1.8', '3,998']
# ['아마다웰드테크코리아(주) following', '제조/화학', '2.2', '4,098']
# ['에이시디(주) following', '제조/화학', '1.8', '3,556']
# ['주광정밀(주) following', '제조/화학', '2.3', '3,340']
# ['한국알파라발(주) following', '제조/화학', '3.0', '4,238']
# ['한국쯔바키모토오토모티브(주) following', '제조/화학', '3.1', '3,622']
# ['(주)일진앤드 following', '제조/화학', '2.2', '3,218']
# ['대한칼소닉(주) following', '제조/화학', '2.1', '3,957']
# ['캄텍(주) following', '제조/화학', '3.4', '5,404']
# ['티아이티이엔지(주) following', '제조/화학', '2.5', '4,164']
# ['(주)와이엠케이 following', '제조/화학', '2.6', '3,542']
# ['대동기어(주) following', '제조/화학', '2.5', '4,526']
# ['에스피시스템스(주) following', '제조/화학', '2.1', '2,850']
# ['오스템(주) following', '제조/화학', '2.8', '4,173']
# ['(주)광진윈텍 following', '제조/화학', '2.0', '3,333']
# ['(주)스페이스솔루션 following', '제조/화학', '2.6', '3,474']
# ['대창에이치알에스지(주) following', '제조/화학', '2.5', '3,719']
# ['유라테크(주) following', '제조/화학', '2.9', '4,504']
# ['일신밸브(주) following', '제조/화학', '2.0', '3,240']
# ['(주)다이아덴트 following', '제조/화학', '2.4', '3,169']
# ['(주)대성마리프 following', '제조/화학', '1.9', '3,443']
# ['(주)수산씨에스엠 following', '제조/화학', '2.8', '3,649']
# ['(주)썸텍 following', '제조/화학', '2.4', '2,925']
# ['와브코코리아(유) following', '제조/화학', '2.4', '4,744']
# ['한국에스케이에프씰(주) following', '제조/화학', '2.8', '4,670']
# ['(주)네오아이씨피 following', '제조/화학', '2.6', '3,407']
# ['(주)원태 following', '제조/화학', '2.3', '3,674']
# ['대림자동차공업(주) following', '제조/화학', '2.0', '3,712']
# ['디에스케이(주) following', '제조/화학', '2.4', '3,323']
# ['아임삭(주) following', '제조/화학', '2.4', '2,816']
# ['정아정밀(주) following', '제조/화학', '1.9', '3,157']
# ['한국무브넥스(주) following', '제조/화학', '3.4', '4,875']
# ['(주)영광 following', '제조/화학', '2.4', '3,650']
# ['서영정밀(주) following', '제조/화학', '1.9', '2,974']
# ['신신기계(주) following', '제조/화학', '2.6', '4,338']
# ['청우하이드로(주) following', '제조/화학', '2.6', '3,521']
# ['하츠(주) following', '제조/화학', '3.4', '3,620']
# ['신비앤텍(주) following', '제조/화학', '2.9', '3,293']
# ['케이에이치이(주) following', '제조/화학', '2.2', '3,675']
# ['한터기술(주) following', '제조/화학', '2.2', '3,256']
# ['흥일기업(주) following', '제조/화학', '2.0', '3,573']
# ['대주기계(주) following', '제조/화학', '2.7', '3,825']
# ['아스플로(주) following', '제조/화학', '2.5', '3,677']
# ['에스앤더블류(주) following', '제조/화학', '2.4', '3,149']
# ['비스토스(주) following', '제조/화학', '2.8', '3,068']
# ['포스뱅크(주) following', '제조/화학', '2.4', '3,837']
# ['한국뉴매틱(주) following', '제조/화학', '2.1', '2,550']
# ['(주)네오셈 following', '제조/화학', '2.2', '3,691']
# ['(주)에스제이엠 following', '제조/화학', '2.8', '5,242']
# ['(주)에이치에스하이테크 following', '제조/화학', '2.6', '3,827']
# ['(주)엠프로텍 following', '제조/화학', '2.0', '3,262']
# ['스카니아코리아(주) following', '제조/화학', '2.3', '4,347']
# ['케이씨코트렐(주) following', '제조/화학', '3.3', '4,964']
# ['(주)엘에치이 following', '제조/화학', '3.1', '4,407']
# ['대영초음파(주) following', '제조/화학', '1.5', '3,021']
# ['대지오토모티브(주) following', '제조/화학', '2.4', '3,998']
# ['보그워너모빌리티코리아유한책임회사 following', '제조/화학', '3.0', '5,119']
# ['(주)대금지오웰 following', '제조/화학', '2.7', '3,338']
# ['(주)시스콘 following', '제조/화학', '2.8', '4,000']
# ['(주)나우테크 following', '제조/화학', '2.0', '3,577']
# ['(주)엠피에스 following', '제조/화학', '2.1', '3,559']
# ['세화(주) following', '제조/화학', '2.3', '3,241']
# ['아센텍(주) following', '제조/화학', '2.3', '3,399']
# ['일광산기(주) following', '제조/화학', '1.6', '2,748']
# ['크로버(주) following', '제조/화학', '2.4', '3,067']
# ['태평양금속(주) following', '제조/화학', '2.6', '3,858']
# ['(주)미창케이블 following', '제조/화학', '2.4', '3,507']
# ['(주)원에스티 following', '제조/화학', '1.8', '3,420']
# ['그린테크(주) following', '제조/화학', '2.1', '2,805']
# ['삼영엠티(주) following', '제조/화학', '2.5', '3,583']
# ['젬스메디컬(주) following', '제조/화학', '2.5', '3,499']
# ['(주)멕아이씨에스 following', '제조/화학', '2.7', '3,330']
# ['에스앤티다이내믹스(주) following', '제조/화학', '2.3', '4,030']
# ['정도산업(주) following', '제조/화학', '2.2', '2,782']
# ['포레시아배기컨트롤시스템코리아(유) following', '제조/화학', '2.1', '4,418']
# ['(주)나라코퍼레이션 following', '제조/화학', '1.9', '2,753']
# ['(주)맥스로텍 following', '제조/화학', '2.9', '3,370']
# ['(주)브이원텍 following', '제조/화학', '2.8', '3,751']
# ['(주)에이치와이티씨 following', '제조/화학', '2.1', '3,146']
# ['삼건세기(주) following', '제조/화학', '3.3', '3,538']
# ['이화글로텍(주) following', '제조/화학', '2.4', '3,027']
# ['화신테크(주) following', '제조/화학', '2.5', '3,781']
# ['훌루테크(주) following', '제조/화학', '2.7', '3,658']
# ['(주)미코바이오메드 following', '제조/화학', '2.2', '3,502']
# ['(주)우정테크 following', '제조/화학', '1.6', '3,176']
# ['(주)푸른기술 following', '제조/화학', '2.7', '3,927']
# ['(주)마이크로디지탈 following', '제조/화학', '2.8', '3,305']
# ['(주)씨앤아이테크놀로지 following', '제조/화학', '2.2', '3,979']
# ['(주)젬백스&카엘 following', '제조/화학', '2.3', '4,309']
# ['(주)테키스트 following', '제조/화학', '3.0', '3,353']
# ['케이시시정공(주) following', '제조/화학', '2.2', '3,144']
# ['한국공작기계(주) following', '제조/화학', '2.0', '3,169']
# ['흥아기연(주) following', '제조/화학', '3.4', '4,014']
# ['(주)장원테크 following', '제조/화학', '2.4', '3,270']
# ['신라엔지니어링(주) following', '제조/화학', '2.8', '3,513']
# ['엘링크링거코리아(주) following', '제조/화학', '2.0', '3,482']
# ['엘켐텍(주) following', '제조/화학', '1.6', '3,543']
# ['(주)디팜스테크 following', '제조/화학', '2.0', '3,767']
# ['(주)스트롱홀드테크놀로지 following', '제조/화학', '2.5', '3,239']
# ['(주)윈텍오토메이션 following', '제조/화학', '2.5', '3,625']
# ['덕지산업(주) following', '제조/화학', '2.2', '2,877']
# ['코스모이엔지(주) following', '제조/화학', '2.2', '2,822']
# ['티아이씨(주) following', '제조/화학', '2.5', '3,595']
# ['녹스코리아(주) following', '제조/화학', '1.5', '3,428']
# ['델파이코리아(유) following', '제조/화학', '3.1', '5,456']
# ['아이씨엠씨(주) following', '제조/화학', '2.3', '3,350']
# ['누가의료기(주) following', '제조/화학', '2.1', '4,077']
# ['대유신소재(주) following', '제조/화학', '2.4', '3,847']
# ['세안정기(주) following', '제조/화학', '2.6', '3,393']
# ['연우(주) following', '제조/화학', '2.6', '3,558']
# ['(주)구츠 following', '제조/화학', '1.9', '2,869']
# ['(주)동해기계항공 following', '제조/화학', '2.1', '3,465']
# ['(주)비엠씨 following', '제조/화학', '2.5', '4,017']
# ['(주)세정 following', '제조/화학', '3.2', '3,844']
# ['(주)현대공업 following', '제조/화학', '2.9', '4,735']
# ['모베이스오토테크(주) following', '제조/화학', '2.3', '4,064']
# ['브로제코리아(주) following', '제조/화학', '3.2', '5,207']
# ['삼진정공(주) following', '제조/화학', '3.6', '4,007']
# ['신광정공(주) following', '제조/화학', '2.2', '2,931']
# ['일진에이테크(주) following', '제조/화학', '2.4', '3,007']
# ['컨트롤웍스(주) following', '제조/화학', '3.0', '3,935']
# ['프라이맥스(주) following', '제조/화학', '2.2', '3,512']
# ['(주)단해 following', '제조/화학', '1.8', '3,555']
# ['대보마그네틱(주) following', '제조/화학', '2.1', '3,435']
# ['디케이산업(주) following', '제조/화학', '2.5', '3,034']
# ['메르센코리아(주) following', '제조/화학', '2.9', '4,014']
# ['삼영엠텍(주) following', '제조/화학', '2.1', '3,670']
# ['세보테크(주) following', '제조/화학', '2.3', '3,319']
# ['케이에이씨(주) following', '제조/화학', '2.0', '3,069']
# ['더블유에스오디올로지코리아(유) following', '제조/화학', '3.1', '3,324']
# ['서원풍력기계(주) following', '제조/화학', '2.3', '3,821']
# ['솔고바이오메디칼(주) following', '제조/화학', '2.8', '3,237']
# ['티에스엠텍(주) following', '제조/화학', '2.9', '3,974']
# ['(주)네오티스 following', '제조/화학', '2.5', '2,904']
# ['(주)청우메디칼 following', '제조/화학', '2.4', '3,374']
# ['레미코리아(유) following', '제조/화학', '2.6', '3,992']
# ['몰텍스(주) following', '제조/화학', '2.3', '4,206']
# ['우영산업(주) following', '제조/화학', '1.4', '2,998']
# ['유진에스엠알시오토모티브테크노(주) following', '제조/화학', '2.4', '4,806']
# ['한국와이퍼(주) following', '제조/화학', '2.6', '4,316']
# ['(주)비올 following', '제조/화학', '2.9', '3,602']
# ['(주)에이아이티 following', '제조/화학', '2.6', '3,200']
# ['(주)엠엔 following', '제조/화학', '2.1', '2,995']
# ['(주)코만 following', '제조/화학', '1.7', '3,237']
# ['디와이피엔에프(주) following', '제조/화학', '1.9', '3,861']
# ['우진시스템(주) following', '제조/화학', '3.2', '3,673']
# ['피티씨(주) following', '제조/화학', '2.5', '3,351']
# ['(주)에이다스원 following', '제조/화학', '1.8', '3,880']
# ['(주)퓨처로봇 following', '제조/화학', '2.3', '3,207']
# ['씨비아이(주) following', '제조/화학', '2.2', '3,383']
# ['아시아(주) following', '제조/화학', '2.5', '5,107']
# ['에스엠화진(주) following', '제조/화학', '2.8', '3,883']
# ['피에이치에이에차(유) following', '제조/화학', '3.1', '4,569']
# ['한국지케이엔(주) following', '제조/화학', '3.8', '4,596']
# ['한국플로우서브(유) following', '제조/화학', '2.4', '5,781']
# ['현대커민스엔진 following', '제조/화학', '2.5', '3,709']
# ['자이글(주) following', '제조/화학', '2.1', '2,543']
# ['한라캐스트(주) following', '제조/화학', '2.4', '3,074']
# ['핫시스(주) following', '제조/화학', '1.8', '2,645']
# ['(주)서번 following', '제조/화학', '2.4', '3,825']
# ['동신산업(주) following', '제조/화학', '2.1', '3,548']
# ['디앤에이모터스(주) following', '제조/화학', '2.1', '3,853']
# ['베바스토동희(주) following', '제조/화학', '2.7', '4,248']
# ['영신기전공업(주) following', '제조/화학', '2.7', '3,311']
# ['잘만정공(주) following', '제조/화학', '1.7', '3,036']
# ['(주)엔젤로보틱스 following', '제조/화학', '2.5', '4,282']
# ['삼명기계공업(주) following', '제조/화학', '1.5', '2,673']
# ['신독엔지니어링(주) following', '제조/화학', '2.4', '2,666']
# ['웰코스(주) following', '제조/화학', '2.4', '3,672']
# ['캐터필라정밀씰(주) following', '제조/화학', '3.1', '5,487']
# ['플루오르테크(주) following', '제조/화학', '2.9', '3,509']
# ['(주)신성이엔지 following', '제조/화학', '2.7', '3,947']
# ['(주)올리브헬스케어 following', '제조/화학', '2.9', '4,747']
# ['반석정밀공업(주) following', '제조/화학', '2.1', '3,257']
# ['시퍼스파이프라인(주) following', '제조/화학', '1.8', '3,404']
# ['씨와이오토텍(주) following', '제조/화학', '2.5', '3,583']
# ['아르네코리아(주) following', '제조/화학', '2.7', '3,463']
# ['에스에스피(주) following', '제조/화학', '2.4', '4,568']
# ['위지트(주) following', '제조/화학', '3.1', '3,646']
# ['유성기업(주) following', '제조/화학', '2.2', '3,774']
# ['카스윈(주) following', '제조/화학', '1.9', '3,304']
# ['하이드로텍(주) following', '제조/화학', '3.1', '3,298']
# ['(주)글로벌엔지니어링 following', '제조/화학', '2.3', '3,048']
# ['(주)아름덴티스트리 following', '제조/화학', '2.9', '3,236']
# ['(주)케이디에이 following', '제조/화학', '1.9', '3,415']
# ['대창단조(주) following', '제조/화학', '2.5', '4,312']
# ['콘티테크플루이드코리아(주) following', '제조/화학', '2.1', '3,713']
# ['플라토(주) following', '제조/화학', '2.0', '3,232']
# ['(주)글로벌로보틱스 following', '제조/화학', '2.4', '3,135']
# ['(주)코엠에스 following', '제조/화학', '2.4', '3,629']
# ['스탕코리아(주) following', '제조/화학', '1.5', '3,715']
# ['신영하이테크(주) following', '제조/화학', '2.1', '3,131']
# ['에이엠티(주) following', '제조/화학', '2.3', '3,110']
# ['엠지전자(주) following', '제조/화학', '1.5', '3,596']
# ['하이레벤(주) following', '제조/화학', '2.1', '2,782']
# ['(주)엠피에스코리아 following', '제조/화학', '2.0', '2,765']
# ['(주)제4기한국 following', '제조/화학', '2.9', '3,973']
# ['고원금속(주) following', '제조/화학', '2.1', '3,344']
# ['대국아이엔티(주) following', '제조/화학', '1.9', '3,448']
# ['메디엔인터내셔날(주) following', '제조/화학', '2.2', '2,430']
# ['제이엔케이히터(주) following', '제조/화학', '3.5', '5,180']
# ['키밸브기술(주) following', '제조/화학', '2.7', '3,455']
# ['프로세이브(주) following', '제조/화학', '2.2', '3,603']
# ['한국유니콤밸브(주) following', '제조/화학', '2.3', '3,191']
# ['(주)동은밸브 following', '제조/화학', '1.8', '2,707']
# ['(주)라이브셀인스트루먼트 following', '제조/화학', '2.1', '3,144']
# ['(주)알피에스 following', '제조/화학', '2.1', '2,958']
# ['아이엠티(주) following', '제조/화학', '2.0', '3,229']
# ['하이드로텍(주) following', '제조/화학', '3.5', '3,368']
# ['(주)비엠씨 following', '제조/화학', '2.1', '3,173']
# ['넥센테크(주) following', '제조/화학', '2.4', '3,907']
# ['신라파이어(주) following', '제조/화학', '2.4', '3,340']
# ['유라하네스(주) following', '제조/화학', '3.0', '4,439']
# ['이후시스(주) following', '제조/화학', '2.3', '4,650']
# ['테네코코리아(유) following', '제조/화학', '3.0', '4,338']
# ['팬직(주) following', '제조/화학', '2.1', '3,377']
# ['(주)엔클로니 following', '제조/화학', '3.5', '3,984']
# ['(주)피아이이 following', '제조/화학', '2.9', '3,973']
# ['HL위코(주) following', '제조/화학', '1.7', '3,615']
# ['극동기계(주) following', '제조/화학', '2.0', '2,298']
# ['대명엘리베이터(주) following', '제조/화학', '2.8', '3,107']
# ['메디스(주) following', '제조/화학', '1.4', '2,927']
# ['엔젤(주) following', '제조/화학', '2.1', '2,737']
# ['우진큐피디 following', '제조/화학', '1.9', '3,018']
# ['일신실업(주) following', '제조/화학', '2.0', '2,749']
# ['플러스이엔지(주) following', '제조/화학', '2.6', '4,090']
# ['한국정밀기계(주) following', '제조/화학', '2.8', '3,329']
# ['(주)대덕기계 following', '제조/화학', '1.6', '3,751']
# ['(주)신룡 following', '제조/화학', '3.0', '4,484']
# ['(주)에스제이이노테크 following', '제조/화학', '2.3', '3,595']
# ['(주)케이에스씨파츠 following', '제조/화학', '1.8', '2,921']
# ['(주)토인 following', '제조/화학', '3.0', '3,762']
# ['마이크로인스펙션(주) following', '제조/화학', '2.7', '4,165']
# ['모카몰드(주) following', '제조/화학', '1.9', '3,338']
# ['비스티온일렉트로닉스코리아(유) following', '제조/화학', '2.6', '5,823']
# ['송재산업(주) following', '제조/화학', '2.0', '3,066']
# ['아이젠(주) following', '제조/화학', '2.6', '3,061']
# ['우성오토콘(주) following', '제조/화학', '2.2', '3,065']
# ['인곡산업(주) following', '제조/화학', '1.9', '2,591']
# ['(주)다산뉴텍 following', '제조/화학', '1.9', '3,152']
# ['(주)에스티아이 following', '제조/화학', '2.3', '3,236']
# ['(주)케이.피.씨 following', '제조/화학', '2.8', '3,592']
# ['광신기계공업(주) following', '제조/화학', '2.8', '4,463']
# ['동양매직(주) following', '제조/화학', '3.0', '2,879']
# ['디와이이노베이트(주) following', '제조/화학', '3.3', '4,279']
# ['씨티에스(주) following', '제조/화학', '2.1', '3,840']
# ['아이젤크리에이티브(주) following', '제조/화학', '1.9', '3,096']
# ['코리아프로트(주) following', '제조/화학', '1.9', '2,778']
# ['(주)빅텍스 following', '제조/화학', '1.5', '3,849']
# ['(주)신명유압 following', '제조/화학', '1.7', '2,819']
# ['(주)아이백코리아 following', '제조/화학', '2.0', '2,503']
# ['(주)엔에스브이 following', '제조/화학', '1.8', '3,424']
# ['(주)이티에스 following', '제조/화학', '2.3', '3,494']
# ['(주)프로텍스 following', '제조/화학', '2.4', '2,847']
# ['(주)한우물 following', '제조/화학', '3.0', '2,803']
# ['신한발브공업(주) following', '제조/화학', '2.9', '3,666']
# ['실력산업(주) following', '제조/화학', '2.0', '2,673']
# ['에스엘미러텍(주) following', '제조/화학', '3.1', '5,246']
# ['장한기술(주) following', '제조/화학', '3.3', '3,592']
# ['제일피엠씨(주) following', '제조/화학', '1.5', '2,524']
# ['한림인텍(주) following', '제조/화학', '2.7', '3,435']
# ['(주)동아기업 following', '제조/화학', '1.6', '3,084']
# ['(주)성무이엔지 following', '제조/화학', '2.5', '3,387']
# ['(주)아이팩토리 following', '제조/화학', '2.4', '2,783']
# ['(주)에코니티 following', '제조/화학', '2.5', '3,844']
# ['(주)와이에스피 following', '제조/화학', '2.5', '3,140']
# ['(주)크로시스 following', '제조/화학', '1.9', '3,343']
# ['(주)필에너지 following', '제조/화학', '2.2', '4,251']
# ['안국바이오진단(주) following', '제조/화학', '2.0', '3,149']
# ['한일정공(주) following', '제조/화학', '2.6', '2,838']
# ['(주)긴트 following', '제조/화학', '2.9', '3,906']
# ['(주)센트론 following', '제조/화학', '2.1', '2,682']
# ['(주)지에스씨 following', '제조/화학', '2.2', '3,506']
# ['(주)터보맥스 following', '제조/화학', '3.1', '3,655']
# ['(주)한양공업 following', '제조/화학', '2.0', '2,670']
# ['대의테크(주) following', '제조/화학', '2.0', '3,509']
# ['두원전자(주) following', '제조/화학', '2.3', '3,799']
# ['일진에너지(주) following', '제조/화학', '2.0', '4,191']
# ['진양코퍼레이션(주) following', '제조/화학', '1.5', '3,065']
# ['화성써모(주) following', '제조/화학', '1.7', '2,491']
# ['휴롬엘에스(주) following', '제조/화학', '3.2', '4,298']
# ['(주)이큐글로벌 following', '제조/화학', '2.3', '3,255']
# ['(주)인스텍 following', '제조/화학', '2.5', '2,990']
# ['(주)제이에스케이 following', '제조/화학', '2.7', '3,612']
# ['광영이엔씨(주) following', '제조/화학', '2.6', '4,004']
# ['마르포스(주) following', '제조/화학', '2.3', '3,186']
# ['밸콘케이피에스(주) following', '제조/화학', '2.0', '3,556']
# ['보그워너충주(주) following', '제조/화학', '3.4', '4,311']
# ['세진전자(주) following', '제조/화학', '2.5', '2,675']
# ['오토산업(주) following', '제조/화학', '1.9', '2,799']
# ['제이에프씨(주) following', '제조/화학', '2.3', '4,649']
# ['제이엔에스(주) following', '제조/화학', '1.9', '3,124']
# ['(주)원드롭 following', '제조/화학', '2.2', '3,191']
# ['(주)테스크 following', '제조/화학', '1.5', '2,774']
# ['(주)화인텍 following', '제조/화학', '4.2', '4,668']
# ['대기이에스티(주) following', '제조/화학', '1.9', '3,067']
# ['스페코(주) following', '제조/화학', '2.5', '3,223']
# ['신한정공(주) following', '제조/화학', '2.8', '3,407']
# ['에이포웰 following', '제조/화학', '2.7', '3,242']
# ['전진엔텍(주) following', '제조/화학', '2.7', '3,314']
# ['카이스(주) following', '제조/화학', '3.5', '4,061']
# ['한국크노르브레이크(주) following', '제조/화학', '3.1', '5,133']
# ['(주)대영파워펌프 following', '제조/화학', '2.7', '3,983']
# ['(주)로보케어 following', '제조/화학', '2.2', '3,958']
# ['(주)에이아이코리아 following', '제조/화학', '2.3', '4,051']
# ['(주)에코셋 following', '제조/화학', '2.5', '3,466']
# ['(주)원준 following', '제조/화학', '2.3', '4,071']
# ['(주)킴 following', '제조/화학', '2.4', '3,792']
# ['대영정공(주) following', '제조/화학', '2.4', '4,327']
# ['디오(주) following', '제조/화학', '1.7', '3,390']
# ['디케이시(주) following', '제조/화학', '1.8', '2,974']
# ['마그넥스(주) following', '제조/화학', '1.9', '2,684']
# ['삼세산업(주) following', '제조/화학', '2.6', '3,354']
# ['서우테크놀로지(주) following', '제조/화학', '3.3', '3,528']
# ['에이디엠이십일(주) following', '제조/화학', '3.1', '2,422']
# ['에이스기계(주) following', '제조/화학', '2.7', '3,384']
# ['엔티리서치(주) following', '제조/화학', '1.0', '2,424']
# ['코링텍(주) following', '제조/화학', '1.6', '3,217']
# ['피스템코(주) following', '제조/화학', '2.3', '3,480']
# ['한국야스나가(주) following', '제조/화학', '2.7', '2,607']
# ['한국코소(주) following', '제조/화학', '2.8', '3,029']
# ['한국타프로기(주) following', '제조/화학', '2.4', '3,097']
# ['(주)네오피엠씨 following', '제조/화학', '2.0', '3,348']
# ['(주)삼원강재 following', '제조/화학', '2.9', '4,024']
# ['(주)성재 following', '제조/화학', '1.8', '2,371']
# ['(주)소네트 following', '제조/화학', '2.3', '6,900']
# ['(주)칼라일플루이드테크놀로지스코리아 following', '제조/화학', '2.9', '5,253']
# ['(주)컴씨스 following', '제조/화학', '1.6', '3,243']
# ['(주)큐블락 following', '제조/화학', '2.2', '4,255']
# ['대오정공(주) following', '제조/화학', '2.6', '3,061']
# ['대일공업 following', '제조/화학', '2.4', '3,065']
# ['대호정기(주) following', '제조/화학', '1.8', '3,215']
# ['아이피티씨(주) following', '제조/화학', '3.1', '3,801']
# ['엔젯(주) following', '제조/화학', '3.2', '3,552']
# ['진행워터웨이(주) following', '제조/화학', '2.7', '3,188']
# ['한미에이디엠(주) following', '제조/화학', '2.2', '3,057']
# ['현대산기(주) following', '제조/화학', '2.0', '2,772']
# ['(주)노바프로 following', '제조/화학', '2.3', '2,613']
# ['글로애져(주) following', '제조/화학', '2.6', '2,748']
# ['백산오피씨(주) following', '제조/화학', '2.5', '4,113']
# ['베스텍(주) following', '제조/화학', '2.2', '4,002']
# ['보원산업(주) following', '제조/화학', '1.8', '3,547']
# ['세미텍(주) following', '제조/화학', '2.6', '3,549']
# ['연합정밀 following', '제조/화학', '2.9', '3,344']
# ['유림공업(주) following', '제조/화학', '2.8', '2,641']
# ['제일베어링공업(주) following', '제조/화학', '2.7', '2,909']
# ['지덕산업(주) following', '제조/화학', '2.3', '3,644']
# ['칸에스티엔(주) following', '제조/화학', '2.7', '4,215']
# ['케이제이메디텍(주) following', '제조/화학', '2.2', '3,013']
# ['(주)광림 following', '제조/화학', '2.3', '3,288']
# ['(주)보고통상 following', '제조/화학', '1.9', '3,106']
# ['(주)선우하이테크 following', '제조/화학', '3.3', '3,442']
# ['(주)세우엔지니어링 following', '제조/화학', '2.9', '3,006']
# ['(주)에스엔에프 following', '제조/화학', '3.2', '3,613']
# ['(주)에스지엔지 following', '제조/화학', '2.0', '3,635']
# ['(주)포레스트힐스랩코리아 following', '제조/화학', '3.2', '2,613']
# ['보임테크놀러지(주) following', '제조/화학', '2.5', '3,430']
# ['부국정공(주) following', '제조/화학', '2.3', '3,345']
# ['세광테크(주) following', '제조/화학', '2.2', '3,411']
# ['신세기산업(주) following', '제조/화학', '2.0', '2,988']
# ['에스틸(주) following', '제조/화학', '2.1', '3,378']
# ['에어비타(주) following', '제조/화학', '1.9', '3,160']
# ['에이클로버(주) following', '제조/화학', '1.6', '3,418']
# ['존슨매티카탈리스트코리아(주) following', '제조/화학', '3.5', '3,227']
# ['진영공업(주) following', '제조/화학', '2.2', '4,525']
# ['케이씨이피중공업(주) following', '제조/화학', '3.3', '3,736']
# ['케이투레이저시스템(주) following', '제조/화학', '2.1', '3,995']
# ['탑런몰드텍(주) following', '제조/화학', '2.5', '3,405']
# ['티피씨(주) following', '제조/화학', '1.8', '3,162']
# ['퓨얼셀파워(주) following', '제조/화학', '2.7', '4,087']
# ['(주)네오디에스 following', '제조/화학', '2.4', '3,458']
# ['(주)디케이씨 following', '제조/화학', '3.2', '4,241']
# ['(주)로우템 following', '제조/화학', '2.8', '3,266']
# ['(주)리트젠 following', '제조/화학', '2.1', '4,012']
# ['(주)스타코 following', '제조/화학', '2.8', '3,065']
# ['(주)제이에프파트너스 following', '제조/화학', '2.4', '2,901']
# ['(주)지피아이 following', '제조/화학', '2.5', '3,386']
# ['(주)휴레이저 following', '제조/화학', '2.9', '2,438']
# ['대린테크(주) following', '제조/화학', '2.1', '2,979']
# ['동해산업(주) following', '제조/화학', '3.1', '2,872']
# ['삼우오토메이션 following', '제조/화학', '2.0', '2,772']
# ['삼정오토모티브(주) following', '제조/화학', '2.0', '2,654']
# ['신영제어기(주) following', '제조/화학', '2.9', '3,197']
# ['신한엘리베이타(주) following', '제조/화학', '2.7', '2,912']
# ['쓰리젯(주) following', '제조/화학', '1.8', '3,774']
# ['아이엠텍(주) following', '제조/화학', '2.2', '2,546']
# ['조인트유창써멀시스템(주) following', '제조/화학', '1.9', '3,050']
# ['케디엠(주) following', '제조/화학', '2.1', '5,048']
# ['파나케이아(주) following', '제조/화학', '2.4', '3,540']
# ['한국다이소(주) following', '제조/화학', '3.2', '2,800']
# ['현대파텍스(주) following', '제조/화학', '3.1', '4,834']
# ['(주)솔텍 following', '제조/화학', '2.9', '2,465']
# ['(주)인텍오토메이션 following', '제조/화학', '1.6', '3,029']
# ['(주)태정기공 following', '제조/화학', '2.4', '2,995']
# ['(주)한국마쓰이 following', '제조/화학', '2.5', '2,865']
# ['대명공업(주) following', '제조/화학', '2.0', '2,870']
# ['동남정밀 following', '제조/화학', '1.9', '3,686']
# ['디에이치이(주) following', '제조/화학', '2.9', '3,340']
# ['디와이씨(주) following', '제조/화학', '3.5', '3,630']
# ['미래엔비텍(주) following', '제조/화학', '2.7', '3,158']
# ['부강테크(주) following', '제조/화학', '3.2', '4,447']
# ['사이메딕스(주) following', '제조/화학', '1.4', '4,315']
# ['성우플라텍(주) following', '제조/화학', '1.5', '3,490']
# ['아하엠텍(주) following', '제조/화학', '3.0', '3,143']
# ['에스에이씨(주) following', '제조/화학', '3.2', '3,119']
# ['영동전자 following', '제조/화학', '2.4', '3,345']
# ['이노텍 following', '제조/화학', '3.5', '3,656']
# ['이원솔루텍(주) following', '제조/화학', '2.0', '3,591']
# ['티와이밸브(주) following', '제조/화학', '2.6', '2,863']
# ['한국모비스텍(주) following', '제조/화학', '2.4', '2,812']
# ['한양인더스트리(주) following', '제조/화학', '2.6', '3,535']
# ['(주)디에스이엔티 following', '제조/화학', '2.0', '3,649']
# ['(주)비티엑스 following', '제조/화학', '2.7', '3,989']
# ['(주)생명과기술 following', '제조/화학', '2.3', '3,240']
# ['(주)셈페르엠 following', '제조/화학', '2.8', '2,781']
# ['(주)씨제이케이 following', '제조/화학', '3.6', '4,207']
# ['(주)오성기공 following', '제조/화학', '2.3', '3,810']
# ['(주)이노디스 following', '제조/화학', '2.3', '3,433']
# ['(주)휘일 following', '제조/화학', '2.4', '3,620']
# ['루보(주) following', '제조/화학', '3.3', '3,500']
# ['삼우중공업(주) following', '제조/화학', '3.3', '3,253']
# ['세호로보트(주) following', '제조/화학', '2.7', '3,482']
# ['세화하이테크 following', '제조/화학', '1.6', '3,159']
# ['에스비엠(주) following', '제조/화학', '2.3', '4,488']
# ['에스아이티(주) following', '제조/화학', '2.8', '3,320']
# ['에이에스티(주) following', '제조/화학', '1.8', '4,287']
# ['우경MIT following', '제조/화학', '2.8', '3,698']
# ['웰코리아(주) following', '제조/화학', '2.0', '2,796']
# ['태창공업(주) following', '제조/화학', '1.6', '3,441']
# ['한도(주) following', '제조/화학', '2.9', '3,324']
# ['한진엘리베이터(주) following', '제조/화학', '1.6', '2,350']
# ['한텍 following', '제조/화학', '3.0', '4,197']
# ['(주)동우정공 following', '제조/화학', '1.2', '2,750']
# ['(주)마스터 following', '제조/화학', '3.7', '3,092']
# ['(주)부민더블유엔피 following', '제조/화학', '2.9', '2,846']
# ['(주)새해성 following', '제조/화학', '2.5', '3,395']
# ['(주)수도프리미엄엔지니어링 following', '제조/화학', '3.5', '3,760']
# ['(주)신영유니크 following', '제조/화학', '3.1', '3,122']
# ['(주)아띠베뷰티 following', '제조/화학', '2.5', '3,538']
# ['(주)엠에이케이 following', '제조/화학', '2.5', '3,815']
# ['(주)전성 following', '제조/화학', '2.5', '2,878']
# ['(주)케이에스브이 following', '제조/화학', '2.4', '2,830']
# ['(주)탑아이엔디 following', '제조/화학', '2.9', '3,169']
# ['서울기계공업(주) following', '제조/화학', '2.5', '3,645']
# ['서한엔티엔베어링(주) following', '제조/화학', '2.7', '4,630']
# ['에이치엠이(주) following', '제조/화학', '2.0', '3,075']
# ['엠에이치기술개발(주) following', '제조/화학', '2.5', '3,119']
# ['우일정밀공업(주) following', '제조/화학', '2.2', '3,282']
# ['중앙플랜트(주) following', '제조/화학', '2.1', '3,302']
# ['첨단정공(주) following', '제조/화학', '2.2', '3,107']
# ['탑금속(주) following', '제조/화학', '2.6', '3,069']
# ['태화인더스트리(주) following', '제조/화학', '3.3', '4,049']
# ['트로이(주) following', '제조/화학', '3.0', '2,501']
# ['팬코리아중공업(주) following', '제조/화학', '3.1', '3,136']
# ['한국쓰리엠보건안전(유) following', '제조/화학', '3.5', '7,865']
# ['헤스본(주) following', '제조/화학', '2.7', '3,269']
# ['(주)거승 following', '제조/화학', '3.2', '3,667']
# ['(주)선영시스텍 following', '제조/화학', '1.8', '3,524']
# ['(주)에코크레이션 following', '제조/화학', '2.1', '3,979']
# ['(주)엠에스제이 following', '제조/화학', '2.2', '3,766']
# ['(주)윈테크 following', '제조/화학', '2.9', '3,655']
# ['(주)인피니트랜스알파 following', '제조/화학', '2.3', '3,787']
# ['(주)일루미네이드 following', '제조/화학', '3.4', '3,875']
# ['(주)한승테크노 following', '제조/화학', '3.1', '0']
# ['(주)현준에프에이 following', '제조/화학', '1.4', '2,821']
# ['건강한사람들(주) following', '제조/화학', '2.8', '3,493']
# ['국제종합기계 following', '제조/화학', '2.8', '4,300']
# ['대명이엔지(주) following', '제조/화학', '2.7', '3,665']
# ['대양롤랜트(주) following', '제조/화학', '2.8', '2,658']
# ['신형에프에이(주) following', '제조/화학', '3.2', '3,205']
# ['씨스코(주) following', '제조/화학', '2.4', '4,960']
# ['엔디케이테크(주) following', '제조/화학', '2.4', '2,823']
# ['엔브이에이치오버헤드시스템(주) following', '제조/화학', '2.1', '4,443']
# ['엔엘테크(주) following', '제조/화학', '1.8', '3,117']
# ['엠케이아이(주) following', '제조/화학', '3.5', '2,387']
# ['참테크 following', '제조/화학', '2.4', '3,133']
# ['창성정밀(주) following', '제조/화학', '2.2', '3,000']
# ['케이아이씨(주) following', '제조/화학', '2.9', '3,109']
# ['크린피아(주) following', '제조/화학', '2.0', '3,074']
# ['토마린(주) following', '제조/화학', '1.5', '2,369']
# ['하나기술 following', '제조/화학', '2.1', '3,255']
# ['한국케이지(주) following', '제조/화학', '2.4', '2,970']
# ['현대와코텍(주) following', '제조/화학', '1.9', '2,953']
# ['흥진정공(주) following', '제조/화학', '1.7', '3,760']
# ['(주)디에스아이 following', '제조/화학', '2.0', '3,527']
# ['(주)디오에프연구소 following', '제조/화학', '4.1', '5,442']
# ['(주)메드닉스 following', '제조/화학', '2.7', '3,590']
# ['(주)애드테크 following', '제조/화학', '2.4', '2,998']
# ['(주)에스제이 following', '제조/화학', '2.7', '3,123']
# ['(주)영진엘리베이터 following', '제조/화학', '1.1', '0']
# ['(주)오토크로바 following', '제조/화학', '2.2', '3,015']
# ['광일기공(주) following', '제조/화학', '2.9', '3,150']
# ['동하기업(주) following', '제조/화학', '1.8', '2,604']
# ['레드원테크놀러지(주) following', '제조/화학', '2.0', '2,392']
# ['밸크리텍(주) following', '제조/화학', '2.3', '2,298']
# ['밸프(주) following', '제조/화학', '1.4', '3,159']
# ['센시리온오토모티브솔루션즈코리아(주) following', '제조/화학', '2.3', '5,008']
# ['신대림정밀공업(주) following', '제조/화학', '2.3', '3,102']
# ['알이디티(주) following', '제조/화학', '3.9', '2,584']
# ['에스엠중공업(주) 제조부문 following', '제조/화학', '1.0', '0']
# ['에이티에스엔지니어링(주) following', '제조/화학', '1.4', '3,469']
# ['이레엔지니어링 following', '제조/화학', '4.2', '4,339']
# ['조아스전자(주) following', '제조/화학', '2.4', '2,165']
# ['지오엠씨(주) following', '제조/화학', '1.6', '3,473']
# ['파랑(주) following', '제조/화학', '2.9', '2,720']
# ['프라임(주) following', '제조/화학', '2.0', '2,394']
# ['훼브레트랜스포트코리아(유) following', '제조/화학', '2.4', '5,340']
# ['(주)다림써지넷 following', '제조/화학', '2.9', '3,333']
# ['(주)로봇밸리 following', '제조/화학', '1.6', '2,791']
# ['(주)에임스 following', '제조/화학', '3.5', '4,812']
# ['(주)엔아이티코리아 following', '제조/화학', '4.0', '2,685']
# ['(주)제이콥아이앤시 following', '제조/화학', '2.4', '3,107']
# ['(주)청송산업기계 following', '제조/화학', '2.1', '2,742']
# ['(주)코썸사이언스 following', '제조/화학', '1.5', '2,705']
# ['(주)킴스인더스트리 following', '제조/화학', '2.9', '2,994']
# ['(주)타셋 following', '제조/화학', '4.1', '3,434']
# ['(주)프로센 following', '제조/화학', '1.6', '3,636']
# ['광성정밀(주) following', '제조/화학', '1.1', '2,648']
# ['다이이치코리아(주) following', '제조/화학', '2.9', '3,121']
# ['대동전장(주) following', '제조/화학', '2.5', '2,999']
# ['동우밸브콘트롤(주) following', '제조/화학', '2.3', '3,409']
# ['두산디에스티(주) following', '제조/화학', '3.4', '5,307']
# ['리한도어(주) following', '제조/화학', '2.8', '4,980']
# ['삼송캐스터(주) following', '제조/화학', '2.9', '3,253']
# ['세환엠에스(주) following', '제조/화학', '2.4', '2,271']
# ['시스템디엔디(주) following', '제조/화학', '2.0', '2,298']
# ['신광피엔텍(주) following', '제조/화학', '2.5', '2,758']
# ['신성테크닉스(주) following', '제조/화학', '2.3', '3,011']
# ['엑시언(주) following', '제조/화학', '2.4', '2,780']
# ['예일산업(주) following', '제조/화학', '2.5', '3,039']
# ['우리시스템 following', '제조/화학', '1.8', '2,298']
# ['유한정밀(주) following', '제조/화학', '2.3', '4,139']
# ['일림나노텍(주) following', '제조/화학', '2.1', '2,900']
# ['케이알텍 following', '제조/화학', '2.3', '2,543']
# ['코스메디슨 following', '제조/화학', '3.0', '2,592']
# ['쿠키혼(주) following', '제조/화학', '3.4', '4,836']
# ['프러스상사(주) following', '제조/화학', '3.1', '2,978']
# ['한국보쉬디젤(유) following', '제조/화학', '3.9', '5,000']
# ['한국에어로(주) following', '제조/화학', '2.6', '3,587']
# ['(주)디엔텍 following', '제조/화학', '2.4', '3,195']
# ['(주)사운드캠코리아 following', '제조/화학', '3.1', '4,688']
# ['(주)성주 엠.아이 following', '제조/화학', '2.4', '2,595']
# ['(주)신우프론티어 following', '제조/화학', '3.9', '2,492']
# ['(주)안마이크론시스템 following', '제조/화학', '3.3', '3,202']
# ['(주)알지티 following', '제조/화학', '2.6', '4,064']
# ['(주)앤트 following', '제조/화학', '1.0', '2,858']
# ['(주)오앤케이테크 following', '제조/화학', '2.0', '3,734']
# ['(주)이노스 following', '제조/화학', '2.4', '2,761']
# ['(주)티엔디 following', '제조/화학', '2.9', '4,668']
# ['(주)화인트로 following', '제조/화학', '2.4', '3,860']
# ['광성지엠(주) following', '제조/화학', '2.7', '2,919']
# ['다봉산업(주) following', '제조/화학', '2.1', '2,564']
# ['디메드 following', '제조/화학', '1.1', '3,266']
# ['머신나노텍(주) following', '제조/화학', '1.4', '2,358']
# ['메디퓨처(주) following', '제조/화학', '2.7', '2,825']
# ['시너스(주) following', '제조/화학', '3.6', '5,041']
# ['신일인텍(주) following', '제조/화학', '3.3', '4,586']
# ['신일정밀 following', '제조/화학', '2.6', '3,029']
# ['아크로워터테크(주) following', '제조/화학', '3.6', '2,801']
# ['유니스타(주) following', '제조/화학', '2.9', '2,298']
# ['지에스(주) following', '제조/화학', '3.4', '9,667']
# ['케이디에스(주) following', '제조/화학', '1.6', '2,624']
# ['케이피엘밸브공업(주) following', '제조/화학', '2.3', '2,854']
# ['포톤(주) following', '제조/화학', '1.7', '4,852']
# ['하이퍼테크(주) following', '제조/화학', '2.4', '3,123']
# ['한돌펌프(주) following', '제조/화학', '3.7', '2,808']
# ['(주)그린테크놀로지 following', '제조/화학', '2.3', '0']
# ['(주)두성특장차 following', '제조/화학', '2.3', '4,432']
# ['(주)베스텍 following', '제조/화학', '2.0', '3,173']
# ['(주)삼영티엠 following', '제조/화학', '1.8', '3,339']
# ['(주)삼원기연 following', '제조/화학', '2.7', '2,446']
# ['(주)에이알티플러스 following', '제조/화학', '3.7', '0']
# ['(주)케이엔텍 following', '제조/화학', '2.3', '4,113']
# ['(주)테크니컬코리아 following', '제조/화학', '3.0', '3,364']
# ['(주)화인인터코리아 following', '제조/화학', '2.0', '2,447']
# ['가람환경기술(주) following', '제조/화학', '2.5', '2,631']
# ['광동하이텍(주) following', '제조/화학', '2.7', '3,058']
# ['금강씨엔텍(주) following', '제조/화학', '1.5', '2,298']
# ['대정고분자산업(주) following', '제조/화학', '2.2', '4,508']
# ['돈흥실업(주) following', '제조/화학', '3.2', '4,804']
# ['라인호(주) following', '제조/화학', '2.5', '4,378']
# ['비앤이테크(주) following', '제조/화학', '3.2', '2,982']
# ['송화엔지니어링(주) following', '제조/화학', '2.7', '4,218']
# ['슐저코리아(주) following', '제조/화학', '2.2', '4,720']
# ['스마트사운드(주) following', '제조/화학', '3.2', '4,905']
# ['쓰리디플러스(주) following', '제조/화학', '2.7', '3,560']
# ['영화목금형씨스템(주) following', '제조/화학', '2.8', '2,899']
# ['유티스(주) following', '제조/화학', '2.8', '1,976']
# ['이티엠 following', '제조/화학', '3.0', '2,885']
# ['창의메디칼(주) following', '제조/화학', '2.2', '3,491']
# ['티에프텍(주) following', '제조/화학', '2.2', '2,472']
# ['티지오(주) following', '제조/화학', '2.2', '3,028']
# ['피에스아이 following', '제조/화학', '2.2', '2,447']
# ['하베코리아(주) following', '제조/화학', '3.5', '3,278']
# ['한국정밀 following', '제조/화학', '2.7', '3,300']
# ['(주)도울이엔지 following', '제조/화학', '1.8', '3,058']
# ['(주)람트 following', '제조/화학', '3.0', '2,589']
# ['(주)에이텍오토 following', '제조/화학', '3.4', '0']
# ['(주)용진터보 following', '제조/화학', '3.4', '5,077']
# ['(주)이엠코 following', '제조/화학', '3.4', '3,458']
# ['(주)코모텍 following', '제조/화학', '2.8', '3,241']
# ['(주)퓨리움 following', '제조/화학', '1.4', '3,466']
# ['다이나모테크(주) following', '제조/화학', '1.4', '3,215']
# ['대일정공(주) following', '제조/화학', '1.6', '3,856']
# ['동성이엔지(주) following', '제조/화학', '3.2', '2,485']
# ['민스타(주) following', '제조/화학', '2.0', '2,919']
# ['바이텔(주) following', '제조/화학', '1.2', '5,176']
# ['새한테크 following', '제조/화학', '3.6', '3,891']
# ['석화디자인(주) following', '제조/화학', '3.0', '3,046']
# ['스미토모에스에치아이싸이크로드라이브코리아(주) following', '제조/화학', '2.0', '2,757']
# ['에스엔씨(주) following', '제조/화학', '2.2', '2,707']
# ['엠티코리아(주) following', '제조/화학', '3.0', '3,043']
# ['이씨아이(주) following', '제조/화학', '2.2', '0']
# ['한미산업(주) following', '제조/화학', '2.4', '2,853']
# ['한화테크엠(주) following', '제조/화학', '2.8', '4,523']
# ['현대에스엔에스(주) following', '제조/화학', '2.4', '2,422']
# ['(주)건축과환경 following', '제조/화학', '2.0', '0']
# ['(주)디파이 following', '제조/화학', '5.0', '0']
# ['(주)마이브 following', '제조/화학', '2.3', '0']
# ['(주)삼원진공 following', '제조/화학', '1.3', '4,157']
# ['(주)삼원팩 following', '제조/화학', '2.3', '2,829']
# ['(주)세원하이텍 following', '제조/화학', '2.0', '2,908']
# ['(주)센도리 following', '제조/화학', '3.5', '3,062']
# ['(주)신원씨케이모터스 following', '제조/화학', '2.3', '2,645']
# ['(주)아진산업 following', '제조/화학', '2.3', '4,835']
# ['(주)에스텍 following', '제조/화학', '2.5', '4,037']
# ['(주)에프원텍 following', '제조/화학', '3.3', '3,018']
# ['(주)원재엔지니어링 following', '제조/화학', '1.0', '2,843']
# ['(주)주원이앤에스 following', '제조/화학', '3.0', '6,825']
# ['(주)한밭중공업 following', '제조/화학', '2.8', '0']
# ['가스파워(주) following', '제조/화학', '4.3', '4,250']
# ['고려정밀공업(주) following', '제조/화학', '3.3', '4,160']
# ['공성(주) following', '제조/화학', '4.3', '2,730']
# ['금하기계 following', '제조/화학', '3.5', '2,925']
# ['단디메카 following', '제조/화학', '4.8', '3,870']
# ['대경전자기업(주) following', '제조/화학', '2.0', '2,333']
# ['대성정기(주) following', '제조/화학', '2.8', '3,688']
# ['덴소풍성(주) following', '제조/화학', '2.8', '3,473']
# ['도어텍(주) following', '제조/화학', '1.5', '3,738']
# ['동부(주) following', '제조/화학', '3.3', '2,581']
# ['동산밸브 following', '제조/화학', '1.8', '3,043']
# ['디엔에스(주) following', '제조/화학', '1.8', '2,494']
# ['맥산(주) following', '제조/화학', '3.0', '3,308']
# ['모든넷(주) following', '제조/화학', '1.8', '1,667']
# ['뱅크정밀 following', '제조/화학', '3.3', '1,845']
# ['산웅엔지니어링(주) following', '제조/화학', '2.5', '3,588']
# ['상오정밀(주) following', '제조/화학', '1.8', '2,779']
# ['상진정밀(주) following', '제조/화학', '3.0', '3,426']
# ['서천산업(주) following', '제조/화학', '2.5', '2,587']
# ['세대산전(주) following', '제조/화학', '1.5', '3,318']
# ['씨에이엔지니어링(주) following', '제조/화학', '3.5', '4,480']
# ['씨케이피풍공학연구소(주) following', '제조/화학', '1.8', '0']
# ['아강테크(주) following', '제조/화학', '1.5', '2,953']
# ['안켐(주) following', '제조/화학', '3.8', '3,129']
# ['에스에이치비(주) following', '제조/화학', '2.5', '5,851']
# ['에스엠지(주) following', '제조/화학', '2.5', '0']
# ['에이스(주) following', '제조/화학', '3.0', '3,940']
# ['엠씨엠(주) following', '제조/화학', '2.0', '3,879']
# ['엠티씨 following', '제조/화학', '2.0', '1,845']
# ['영다이케스팅(주) following', '제조/화학', '2.0', '3,012']
# ['월성(주) following', '제조/화학', '1.5', '3,044']
# ['유도실업(주) following', '제조/화학', '3.5', '3,553']
# ['유텍시스템(주) following', '제조/화학', '1.5', '2,962']
# ['이원엠(주) following', '제조/화학', '3.5', '3,376']
# ['인터메드(주) following', '제조/화학', '3.8', '3,075']
# ['제논(주) following', '제조/화학', '2.0', '3,020']
# ['캔두무역 following', '제조/화학', '1.3', '3,804']
# ['클리어뷰헬스케어(주) following', '제조/화학', '3.5', '3,082']
# ['팔핑거드레겐코리아 following', '제조/화학', '2.8', '3,970']
# ['피앤에스미캐닉스(주) following', '제조/화학', '3.8', '4,314']
# ['한양개발(주) following', '제조/화학', '1.8', '4,888']
# ['한일내장(주) following', '제조/화학', '2.5', '3,581']
# ['현일테크 following', '제조/화학', '2.3', '2,628']
# ['(주)가린시스템 following', '제조/화학', '4.7', '0']
# ['(주)고송이엔지 following', '제조/화학', '3.0', '0']
# ['(주)동서기공 following', '제조/화학', '3.3', '3,533']
# ['(주)디와이비 following', '제조/화학', '2.3', '0']
# ['(주)매크로머신 following', '제조/화학', '2.7', '4,228']
# ['(주)삼양에이치티 following', '제조/화학', '1.0', '2,432']
# ['(주)삼원기계 following', '제조/화학', '2.0', '3,567']
# ['(주)선진인더스트리 following', '제조/화학', '1.7', '2,768']
# ['(주)신성 following', '제조/화학', '2.7', '3,293']
# ['(주)에이스터보 following', '제조/화학', '3.3', '2,942']
# ['(주)엠넥스 following', '제조/화학', '2.0', '4,296']
# ['(주)유니온공조이엔지 following', '제조/화학', '1.3', '1,845']
# ['(주)지메디언스 following', '제조/화학', '3.3', '2,571']
# ['(주)지엠에스 following', '제조/화학', '2.3', '4,391']
# ['(주)케이산업 following', '제조/화학', '2.7', '3,380']
# ['(주)코레드 following', '제조/화학', '3.0', '3,045']
# ['(주)픽셀 following', '제조/화학', '3.7', '0']
# ['(주)한야 following', '제조/화학', '3.3', '3,663']
# ['(주)현우산업 following', '제조/화학', '2.7', '3,453']
# ['Hyundai Motor Deutschland GmbH following', '제조/화학', '3.7', '5,288']
# ['거남(주) following', '제조/화학', '2.0', '2,428']
# ['구일공조(주) following', '제조/화학', '2.7', '2,883']
# ['내쇼날시스템(주) following', '제조/화학', '4.7', '3,566']
# ['대신기공 following', '제조/화학', '2.7', '2,256']
# ['더웨일(주) following', '제조/화학', '2.7', '2,815']
# ['덕산공조기계(주) following', '제조/화학', '3.0', '4,117']
# ['동화정공(주) following', '제조/화학', '2.3', '2,240']
# ['로보테크(주) following', '제조/화학', '3.0', '3,545']
# ['명진테크 following', '제조/화학', '3.0', '2,865']
# ['보그워너베루시스템즈코리아(주) following', '제조/화학', '3.7', '4,100']
# ['비디코리아(주) following', '제조/화학', '3.7', '2,842']
# ['삼우tcs(주) following', '제조/화학', '3.7', '4,196']
# ['상우테크(주) following', '제조/화학', '3.3', '3,575']
# ['세광공업(주) following', '제조/화학', '2.7', '3,107']
# ['시뮬라인(주) following', '제조/화학', '3.3', '4,366']
# ['신우전기제조(주) following', '제조/화학', '1.3', '3,733']
# ['씨앤아이 following', '제조/화학', '3.7', '2,108']
# ['아트리아(주) following', '제조/화학', '3.3', '3,824']
# ['에스케이컨티넨탈이모션코리아(주) following', '제조/화학', '1.7', '6,600']
# ['에이치엔티 following', '제조/화학', '3.3', '4,673']
# ['에이티엠코리아(주) following', '제조/화학', '3.7', '2,591']
# ['에이피엠테크놀러지스(주) following', '제조/화학', '2.0', '4,589']
# ['엠브라운이너트가스시스템즈코리아(유) following', '제조/화학', '4.0', '3,744']
# ['오리엔트(주) following', '제조/화학', '2.3', '2,589']
# ['오알에스코리아(유) following', '제조/화학', '3.0', '3,463']
# ['웰이앤씨(주) following', '제조/화학', '2.0', '2,772']
# ['제이앤비 following', '제조/화학', '2.7', '1,845']
# ['케이씨생명과학(주) following', '제조/화학', '1.7', '3,141']
# ['케이티아이엔씨(주) following', '제조/화학', '3.0', '3,332']
# ['코어벨(주) following', '제조/화학', '2.3', '2,799']
# ['퓨처시스템(주) following', '제조/화학', '3.7', '2,738']
# ['플로우콘트롤(주) following', '제조/화학', '3.0', '0']
# ['피케이이앤씨(주) following', '제조/화학', '4.0', '3,090']
# ['화천기계공업(주) following', '제조/화학', '3.3', '5,428']
# ['(주)로아스 following', '제조/화학', '3.0', '0']
# ['(주)세운아이엔티 following', '제조/화학', '2.5', '3,958']
# ['(주)심팩 following', '제조/화학', '1.0', '0']
# ['(주)씨엔에스디지텍 following', '제조/화학', '4.5', '3,217']
# ['(주)아디포랩스 following', '제조/화학', '2.5', '2,801']
# ['(주)우리이엠아이 following', '제조/화학', '2.5', '4,062']
# ['(주)우영실업 following', '제조/화학', '1.0', '0']
# ['(주)유니테크쓰리디피 following', '제조/화학', '4.0', '0']
# ['(주)정테크 following', '제조/화학', '4.0', '2,555']
# ['(주)지지엠 following', '제조/화학', '1.0', '3,494']
# ['(주)청우 following', '제조/화학', '3.5', '4,228']
# ['(주)플렉시고 following', '제조/화학', '3.5', '4,356']
# ['경인기술(주) following', '제조/화학', '1.0', '3,651']
# ['고려디지웍스(주) following', '제조/화학', '2.0', '3,418']
# ['그린이엔지(주) following', '제조/화학', '3.0', '3,075']
# ['누마스타세척기(주) following', '제조/화학', '1.5', '2,298']
# ['뉴파워(주) following', '제조/화학', '3.0', '3,380']
# ['더블류에프에이(주) following', '제조/화학', '4.5', '2,438']
# ['두손산업(주) following', '제조/화학', '3.5', '3,542']
# ['드리미(주) following', '제조/화학', '3.0', '1,575']
# ['릴테크(주) following', '제조/화학', '2.5', '2,628']
# ['매직라이프코리아(주) following', '제조/화학', '3.0', '2,921']
# ['메탈쓰리디(주) following', '제조/화학', '2.0', '0']
# ['명진정밀 following', '제조/화학', '2.5', '1,755']
# ['모트레인(주) following', '제조/화학', '3.0', '4,288']
# ['미시간기술(주) following', '제조/화학', '3.0', '0']
# ['범양냉방산업(주) following', '제조/화학', '2.0', '2,730']
# ['보다엔시스(주) following', '제조/화학', '2.5', '4,680']
# ['비전드라이브(주) following', '제조/화학', '3.0', '4,038']
# ['비투와이(주) following', '제조/화학', '2.5', '2,303']
# ['사회복지법인무궁화동산 following', '제조/화학', '2.0', '0']
# ['새솔테크(주) following', '제조/화학', '3.5', '2,805']
# ['선바이오투(주) following', '제조/화학', '4.0', '2,295']
# ['세영테크(주) following', '제조/화학', '3.5', '2,883']
# ['신스타프리젠츠(주) following', '제조/화학', '2.5', '0']
# ['씨케이그루브(주) following', '제조/화학', '1.5', '2,340']
# ['에스케이티(주) following', '제조/화학', '2.0', '0']
# ['에어솔(주) following', '제조/화학', '3.5', '0']
# ['에이티(주) following', '제조/화학', '3.5', '5,450']
# ['에코인토트(주) following', '제조/화학', '2.0', '2,734']
# ['에프티에스코리아(주) following', '제조/화학', '2.0', '2,975']
# ['엘텍솔루션(주) following', '제조/화학', '2.0', '3,534']
# ['엠디메드 following', '제조/화학', '4.5', '0']
# ['유일테크 following', '제조/화학', '2.0', '2,340']
# ['이에스텍(주) following', '제조/화학', '1.0', '3,013']
# ['인우테크(주) following', '제조/화학', '2.5', '2,412']
# ['인폼(주) following', '제조/화학', '2.5', '4,207']
# ['제이에스프리시젼(주) following', '제조/화학', '4.0', '4,114']
# ['제이콥스(주) following', '제조/화학', '3.5', '3,527']
# ['지이씨(주) following', '제조/화학', '1.0', '0']
# ['진테크(주) following', '제조/화학', '3.0', '2,874']
# ['창안(주) following', '제조/화학', '2.5', '3,897']
# ['케이제이(주) following', '제조/화학', '1.0', '3,075']
# ['코디박(주) following', '제조/화학', '2.5', '3,745']
# ['태진다이텍(주) following', '제조/화학', '1.5', '3,160']
# ['티씨에스(주) following', '제조/화학', '1.0', '3,515']
# ['프로텍코리아(주) following', '제조/화학', '3.0', '3,350']
# ['하이원전자(주) following', '제조/화학', '3.0', '2,076']
# ['한국씨엘티(주) following', '제조/화학', '1.5', '3,925']
# ['한국포세이돈 following', '제조/화학', '1.0', '0']
# ['혜성(주) following', '제조/화학', '1.5', '3,691']
# ['호산테크(주) following', '제조/화학', '4.0', '4,727']
# ['효성산업 following', '제조/화학', '3.5', '0']
# ['휴비오(주) following', '제조/화학', '2.5', '3,062']
# ['(주)넥스트테크놀러지 following', '제조/화학', '1.0', '2,995']
# ['(주)뉴라텍 following', '제조/화학', '4.0', '0']
# ['(주)다이든 following', '제조/화학', '5.0', '0']
# ['(주)다프엔텍 following', '제조/화학', '4.0', '4,875']
# ['(주)대덕테크 following', '제조/화학', '1.0', '2,784']
# ['(주)대일엔지니어링 following', '제조/화학', '2.0', '3,121']
# ['(주)대한테크 following', '제조/화학', '3.0', '2,867']
# ['(주)드림로봇 following', '제조/화학', '1.0', '2,399']
# ['(주)베큐마이즈 following', '제조/화학', '4.0', '3,590']
# ['(주)스마일캐드 following', '제조/화학', '5.0', '4,062']
# ['(주)에스엘에스 following', '제조/화학', '2.0', '3,191']
# ['(주)에스이지 following', '제조/화학', '2.0', '0']
# ['(주)에쓰엔 following', '제조/화학', '1.0', '0']
# ['(주)우성에이스 following', '제조/화학', '5.0', '2,712']
# ['(주)원진테크 following', '제조/화학', '3.0', '3,832']
# ['(주)이래 following', '제조/화학', '5.0', '0']
# ['(주)인천폐차사업소 following', '제조/화학', '1.0', '3,718']
# ['(주)제니스코리아 following', '제조/화학', '3.0', '2,960']
# ['(주)제이앤엘 following', '제조/화학', '1.0', '0']
# ['(주)진용엔지니어링 following', '제조/화학', '1.0', '3,238']
# ['(주)케이스랩 following', '제조/화학', '4.0', '0']
# ['(주)케이엔에스컴퍼니 following', '제조/화학', '2.0', '3,625']
# ['(주)티스퀘어랩 following', '제조/화학', '1.0', '4,664']
# ['(주)하이보 following', '제조/화학', '5.0', '3,892']
# ['(주)한성환경기연 following', '제조/화학', '1.0', '2,876']
# ['GTM-KOREA following', '제조/화학', '1.0', '0']
# ['국일정공(주) following', '제조/화학', '3.0', '3,086']
# ['그루포안톨린코리아(유) following', '제조/화학', '2.0', '6,380']
# ['남일(주) following', '제조/화학', '1.0', '3,257']
# ['대륜기계(주) following', '제조/화학', '4.0', '3,466']
# ['대명지이엔티(주) following', '제조/화학', '4.0', '2,345']
# ['대주기공(주) following', '제조/화학', '3.0', '4,017']
# ['대한전장(주) following', '제조/화학', '3.0', '1,931']
# ['대흥산기 following', '제조/화학', '4.0', '2,925']
# ['데오테크(주) following', '제조/화학', '2.0', '2,458']
# ['동우브레이크 following', '제조/화학', '3.0', '0']
# ['두성밴드(주) following', '제조/화학', '4.0', '3,383']
# ['마사한덕(주) following', '제조/화학', '2.0', '2,145']
# ['백상엔지니어링(주) following', '제조/화학', '1.0', '3,448']
# ['벧엘기계(주) following', '제조/화학', '2.0', '2,269']
# ['보명산업 following', '제조/화학', '3.0', '2,865']
# ['브이엠티(주) following', '제조/화학', '4.0', '3,075']
# ['브이티에스(주) following', '제조/화학', '2.0', '3,440']
# ['삼영이엔지(주) following', '제조/화학', '4.0', '2,867']
# ['삼우기업(주) following', '제조/화학', '3.0', '3,387']
# ['삼우피티에스 following', '제조/화학', '3.0', '3,507']
# ['상희금속(주) following', '제조/화학', '4.0', '3,911']
# ['새한에어서스펜션 following', '제조/화학', '2.0', '2,870']
# ['서모테크 following', '제조/화학', '2.0', '2,050']
# ['성남전자(주) following', '제조/화학', '3.0', '5,522']
# ['성우엔지니어링(주) following', '제조/화학', '2.0', '3,901']
# ['수산에스텍코리아(주) following', '제조/화학', '3.0', '3,075']
# ['신동양엔지니어링(주) following', '제조/화학', '1.0', '2,925']
# ['신보기연(주) following', '제조/화학', '4.0', '4,047']
# ['아이디알시스템 following', '제조/화학', '2.0', '3,588']
# ['아쿠엑스코리아(주) following', '제조/화학', '4.0', '2,514']
# ['알이디커뮤니케이션(주) following', '제조/화학', '3.0', '9,481']
# ['에나지에스(주) following', '제조/화학', '4.0', '2,340']
# ['에스앤드더블유아이엔디(주) following', '제조/화학', '1.0', '2,749']
# ['에스에스앤아이(주) following', '제조/화학', '3.0', '2,243']
# ['에스에이치아이(주) following', '제조/화학', '3.0', '3,373']
# ['에스엔에스 following', '제조/화학', '3.0', '3,075']
# ['에스오피(주) following', '제조/화학', '5.0', '2,460']
# ['에스지티(주) following', '제조/화학', '5.0', '4,802']
# ['에스피아이아시아 following', '제조/화학', '4.0', '3,280']
# ['에이시스(주) following', '제조/화학', '5.0', '0']
# ['에이앤피기계공업(주) following', '제조/화학', '3.0', '0']
# ['에이치에스오션(주) following', '제조/화학', '4.0', '5,119']
# ['엘앤엘프로덕츠오브코리아(유) following', '제조/화학', '2.0', '9,752']
# ['엠솔루션(주) following', '제조/화학', '3.0', '3,850']
# ['열린아이엠씨(주) following', '제조/화학', '3.0', '1,473']
# ['위소엔지니어링(주) following', '제조/화학', '1.0', '2,600']
# ['윈프로 following', '제조/화학', '4.0', '5,850']
# ['이스턴에프티씨(주) following', '제조/화학', '3.0', '3,259']
# ['일진오토모티브(주) following', '제조/화학', '1.0', '0']
# ['제이비코리아(주) following', '제조/화학', '1.0', '3,383']
# ['제이에스메캐닉(주) following', '제조/화학', '1.0', '2,820']
# ['젯트기연(주) following', '제조/화학', '5.0', '4,325']
# ['지디아이솔루션(주) following', '제조/화학', '5.0', '0']
# ['지에스텍(주) following', '제조/화학', '1.0', '4,333']
# ['진원아이엔디(유) following', '제조/화학', '3.0', '2,438']
# ['차오름(주) following', '제조/화학', '2.0', '0']
# ['통일방폭전기(주) following', '제조/화학', '3.0', '2,731']
# ['티에스엠(주) following', '제조/화학', '3.0', '3,588']
# ['포레시아배기시스템코리아(주) following', '제조/화학', '3.0', '5,963']
# ['포엠 following', '제조/화학', '3.0', '3,678']
# ['한라정공(주) following', '제조/화학', '2.0', '3,138']
# ['한성기어(주) following', '제조/화학', '3.0', '3,614']
# ['현대텔레시스 following', '제조/화학', '3.0', '2,819']
# ['효성하나로(주) following', '제조/화학', '1.0', '3,514']
# ['휴먼브릿지코리아(주) following', '제조/화학', '3.0', '1,755']
# ['휴엘 following', '제조/화학', '3.0', '1,755']
# ['히트콤(주) following', '제조/화학', '5.0', '2,145']
# ['(주)가온텍 following', '제조/화학', '0.0', '0']
# ['(주)경대테크 following', '제조/화학', '0.0', '0']
# ['(주)글로벌하이세스 following', '제조/화학', '0.0', '0']
# ['(주)느루 following', '제조/화학', '0.0', '0']
# ['(주)동양환기 following', '제조/화학', '0.0', '0']
# ['(주)동일이엔티 following', '제조/화학', '0.0', '3,437']
# ['(주)드라스타 following', '제조/화학', '0.0', '0']
# ['(주)디에이치펌프서비스 following', '제조/화학', '0.0', '0']
# ['(주)디플러스 following', '제조/화학', '0.0', '0']
# ['(주)로앤에프 following', '제조/화학', '0.0', '0']
# ['(주)리만테크 following', '제조/화학', '0.0', '3,087']
# ['(주)마르스 following', '제조/화학', '0.0', '4,798']
# ['(주)바테크 following', '제조/화학', '0.0', '3,772']
# ['(주)부국하이테크 following', '제조/화학', '0.0', '3,547']
# ['(주)씨앤엘 following', '제조/화학', '0.0', '2,298']
# ['(주)아그네스메디컬 following', '제조/화학', '0.0', '0']
# ['(주)아이엠티 following', '제조/화학', '0.0', '5,718']
# ['(주)에스제이메카텍 following', '제조/화학', '0.0', '0']
# ['(주)엔비트코리아 following', '제조/화학', '0.0', '0']
# ['(주)엠에이티 following', '제조/화학', '0.0', '3,324']
# ['(주)와이텍 following', '제조/화학', '0.0', '3,819']
# ['(주)우리이엔지 following', '제조/화학', '0.0', '3,720']
# ['(주)위소 following', '제조/화학', '0.0', '7,190']
# ['(주)유니버셜코리아 following', '제조/화학', '0.0', '0']
# ['(주)이룸에이티 following', '제조/화학', '0.0', '0']
# ['(주)제이원티엔엠 following', '제조/화학', '0.0', '0']
# ['(주)지디텍 following', '제조/화학', '0.0', '0']
# ['(주)창일테크 following', '제조/화학', '0.0', '0']
# ['(주)청원기연 following', '제조/화학', '0.0', '4,181']
# ['(주)켐텍 following', '제조/화학', '0.0', '3,245']
# ['(주)코빗 following', '제조/화학', '0.0', '0']
# ['(주)테크엑스 following', '제조/화학', '0.0', '0']
# ['(주)티씨엠에스 following', '제조/화학', '0.0', '0']
# ['(주)퓨어스페이스 following', '제조/화학', '0.0', '0']
# ['(주)피앤티 following', '제조/화학', '0.0', '0']
# ['(주)하나건드릴 following', '제조/화학', '0.0', '0']
# ['(주)한국힌지테크 following', '제조/화학', '0.0', '4,647']
# ['(주)한도 following', '제조/화학', '0.0', '2,863']
# ['(주)화진 following', '제조/화학', '0.0', '2,599']
# ['(주)히타치오토메이션코리아 following', '제조/화학', '0.0', '0']
# ['강남메디패스(주) following', '제조/화학', '0.0', '3,007']
# ['기성이엔지 following', '제조/화학', '0.0', '3,607']
# ['나노볼(주) following', '제조/화학', '0.0', '0']
# ['나노엔씨 following', '제조/화학', '0.0', '0']
# ['남영라스텍(주) following', '제조/화학', '0.0', '4,100']
# ['대원특장 following', '제조/화학', '0.0', '0']
# ['대일상사 following', '제조/화학', '0.0', '2,309']
# ['대흥하이텍(주) following', '제조/화학', '0.0', '0']
# ['더플랫(주) following', '제조/화학', '0.0', '0']
# ['동국정밀(주) following', '제조/화학', '0.0', '2,145']
# ['모두텍 following', '제조/화학', '0.0', '0']
# ['법일정밀 following', '제조/화학', '0.0', '0']
# ['베스트일렉트로닉스(주) following', '제조/화학', '0.0', '4,086']
# ['브이아이(주) following', '제조/화학', '0.0', '5,843']
# ['삼원에프엠티(주) following', '제조/화학', '0.0', '4,290']
# ['삼진(주) following', '제조/화학', '0.0', '2,381']
# ['상지(주) following', '제조/화학', '0.0', '2,772']
# ['새한테크(주) following', '제조/화학', '0.0', '2,255']
# ['신아(주) following', '제조/화학', '0.0', '1,684']
# ['신일하이테크(주) following', '제조/화학', '0.0', '2,907']
# ['신한열기(주) following', '제조/화학', '0.0', '4,506']
# ['씨알엔지니어링(주) following', '제조/화학', '0.0', '4,388']
# ['아모(주) following', '제조/화학', '0.0', '4,401']
# ['아이웰니스(주) following', '제조/화학', '0.0', '2,050']
# ['에스티(주) following', '제조/화학', '0.0', '3,607']
# ['엔케이티(주) following', '제조/화학', '0.0', '8,775']
# ['와이비테크 following', '제조/화학', '0.0', '0']
# ['웅진테크(주) following', '제조/화학', '0.0', '2,140']
# ['유어스 following', '제조/화학', '0.0', '5,119']
# ['일동라이펠(주) following', '제조/화학', '0.0', '1,755']
# ['일동엔에스티(주) following', '제조/화학', '0.0', '3,878']
# ['재경엠티에스(주) following', '제조/화학', '0.0', '0']
# ['지비(주) following', '제조/화학', '0.0', '3,502']
# ['지에스엠(주) following', '제조/화학', '0.0', '1,613']
# ['지에프(주) following', '제조/화학', '0.0', '0']
# ['진양이피에스(주) following', '제조/화학', '0.0', '3,318']
# ['창해산업(주) following', '제조/화학', '0.0', '4,422']
# ['코리아엘리베이터(주) following', '제조/화학', '0.0', '2,145']
# ['타키언(주) following', '제조/화학', '0.0', '7,549']
# ['테라이엔이(주) following', '제조/화학', '0.0', '2,839']
# ['튜브캐스트(주) following', '제조/화학', '0.0', '2,597']
# ['티엠에스코리아(주) following', '제조/화학', '0.0', '3,366']
# ['파라기계(주) following', '제조/화학', '0.0', '3,277']
# ['효원전자(주) following', '제조/화학', '0.0', '2,460']
# ['지에프(주) following', '제조/화학', '0.0', '0']
# ['진양이피에스(주) following', '제조/화학', '0.0', '3,318']
# ['창해산업(주) following', '제조/화학', '0.0', '4,422']
# ['코리아엘리베이터(주) following', '제조/화학', '0.0', '2,145']
# ['타키언(주) following', '제조/화학', '0.0', '7,549']
# ['테라이엔이(주) following', '제조/화학', '0.0', '2,839']
# ['튜브캐스트(주) following', '제조/화학', '0.0', '2,597']
# ['티엠에스코리아(주) following', '제조/화학', '0.0', '3,366']
# ['파라기계(주) following', '제조/화학', '0.0', '3,277']
# ['효원전자(주) following', '제조/화학', '0.0', '2,460']
# ['지에프(주) following', '제조/화학', '0.0', '0']
# ['진양이피에스(주) following', '제조/화학', '0.0', '3,318']
# ['창해산업(주) following', '제조/화학', '0.0', '4,422']
# ['코리아엘리베이터(주) following', '제조/화학', '0.0', '2,145']
# ['타키언(주) following', '제조/화학', '0.0', '7,549']
# ['테라이엔이(주) following', '제조/화학', '0.0', '2,839']
# ['튜브캐스트(주) following', '제조/화학', '0.0', '2,597']
# ['티엠에스코리아(주) following', '제조/화학', '0.0', '3,366']
# ['파라기계(주) following', '제조/화학', '0.0', '3,277']
# ['효원전자(주) following', '제조/화학', '0.0', '2,460']
# ['지에프(주) following', '제조/화학', '0.0', '0']
# ['진양이피에스(주) following', '제조/화학', '0.0', '3,318']
# ['창해산업(주) following', '제조/화학', '0.0', '4,422']
# ['코리아엘리베이터(주) following', '제조/화학', '0.0', '2,145']
# ['타키언(주) following', '제조/화학', '0.0', '7,549']
# ['테라이엔이(주) following', '제조/화학', '0.0', '2,839']
# ['튜브캐스트(주) following', '제조/화학', '0.0', '2,597']
# ['티엠에스코리아(주) following', '제조/화학', '0.0', '3,366']
# ['파라기계(주) following', '제조/화학', '0.0', '3,277']
# ['효원전자(주) following', '제조/화학', '0.0', '2,460']
# ['지에프(주) following', '제조/화학', '0.0', '0']
# ['진양이피에스(주) following', '제조/화학', '0.0', '3,318']
# ['창해산업(주) following', '제조/화학', '0.0', '4,422']
# ['코리아엘리베이터(주) following', '제조/화학', '0.0', '2,145']
# ['타키언(주) following', '제조/화학', '0.0', '7,549']
# ['테라이엔이(주) following', '제조/화학', '0.0', '2,839']
# ['튜브캐스트(주) following', '제조/화학', '0.0', '2,597']
# ['티엠에스코리아(주) following', '제조/화학', '0.0', '3,366']
# ['파라기계(주) following', '제조/화학', '0.0', '3,277']
# ['효원전자(주) following', '제조/화학', '0.0', '2,460']
# ['지에프(주) following', '제조/화학', '0.0', '0']
# ['진양이피에스(주) following', '제조/화학', '0.0', '3,318']
# ['창해산업(주) following', '제조/화학', '0.0', '4,422']
# ['코리아엘리베이터(주) following', '제조/화학', '0.0', '2,145']
# ['타키언(주) following', '제조/화학', '0.0', '7,549']
# ['테라이엔이(주) following', '제조/화학', '0.0', '2,839']
# ['튜브캐스트(주) following', '제조/화학', '0.0', '2,597']
# ['티엠에스코리아(주) following', '제조/화학', '0.0', '3,366']
# ['파라기계(주) following', '제조/화학', '0.0', '3,277']
# ['효원전자(주) following', '제조/화학', '0.0', '2,460']
# ['지에프(주) following', '제조/화학', '0.0', '0']
# ['진양이피에스(주) following', '제조/화학', '0.0', '3,318']
# ['창해산업(주) following', '제조/화학', '0.0', '4,422']
# ['코리아엘리베이터(주) following', '제조/화학', '0.0', '2,145']
# ['타키언(주) following', '제조/화학', '0.0', '7,549']
# ['테라이엔이(주) following', '제조/화학', '0.0', '2,839']
# ['튜브캐스트(주) following', '제조/화학', '0.0', '2,597']
# ['티엠에스코리아(주) following', '제조/화학', '0.0', '3,366']
# ['파라기계(주) following', '제조/화학', '0.0', '3,277']
# ['효원전자(주) following', '제조/화학', '0.0', '2,460']
# ['지에프(주) following', '제조/화학', '0.0', '0']
# ['진양이피에스(주) following', '제조/화학', '0.0', '3,318']
# ['창해산업(주) following', '제조/화학', '0.0', '4,422']
# ['코리아엘리베이터(주) following', '제조/화학', '0.0', '2,145']
# ['타키언(주) following', '제조/화학', '0.0', '7,549']
# ['테라이엔이(주) following', '제조/화학', '0.0', '2,839']
# ['튜브캐스트(주) following', '제조/화학', '0.0', '2,597']
# ['티엠에스코리아(주) following', '제조/화학', '0.0', '3,366']
# ['파라기계(주) following', '제조/화학', '0.0', '3,277']
# ['효원전자(주) following', '제조/화학', '0.0', '2,460']
# ['지에프(주) following', '제조/화학', '0.0', '0']
# ['진양이피에스(주) following', '제조/화학', '0.0', '3,318']
# ['창해산업(주) following', '제조/화학', '0.0', '4,422']
# ['코리아엘리베이터(주) following', '제조/화학', '0.0', '2,145']
# ['타키언(주) following', '제조/화학', '0.0', '7,549']
# ['테라이엔이(주) following', '제조/화학', '0.0', '2,839']
# ['튜브캐스트(주) following', '제조/화학', '0.0', '2,597']
# ['티엠에스코리아(주) following', '제조/화학', '0.0', '3,366']
# ['파라기계(주) following', '제조/화학', '0.0', '3,277']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 15
#      13 name = elem.find_element(By.CLASS_NAME,'us_titb_l3').text
#      14 field = elem.find_element(By.CLASS_NAME, 'us_stxt_1').text
# ---> 15 point = elem.find_element(By.CLASS_NAME, 'gfvalue').text
#      16 money = elem.find_element(By.CLASS_NAME, 'notranslate').text
#      18 company.append(name)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:90, in WebElement.text(self)
#      87 @property
#      88 def text(self) -> str:
#      89     """The text of the element."""
# ---> 90     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     343     elif "sessionId" not in params:
#     344         params["sessionId"] = self.session_id
# --> 346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
#     348     self.error_handler.check_response(response)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:300, in RemoteConnection.execute(self, command, params)
#     298 data = utils.dump_json(params)
#     299 url = f"{self._url}{path}"
# --> 300 return self._request(command_info[0], url, body=data)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:321, in RemoteConnection._request(self, method, url, body)
#     318     body = None
#     320 if self.keep_alive:
# --> 321     response = self._conn.request(method, url, body=body, headers=headers)
#     322     statuscode = response.status
#     323 else:
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/_request_methods.py:110, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     107     urlopen_kw["body"] = body
#     109 if method in self._encode_url_methods:
# --> 110     return self.request_encode_url(
#     111         method,
#     112         url,
#     113         fields=fields,  # type: ignore[arg-type]
#     114         headers=headers,
#     115         **urlopen_kw,
#     116     )
#     117 else:
#     118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     140 if fields:
#     141     url += "?" + urlencode(fields)
# --> 143 return self.urlopen(method, url, **extra_kw)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/poolmanager.py:444, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     442     response = conn.urlopen(method, url, **kw)
#     443 else:
# --> 444     response = conn.urlopen(method, u.request_uri, **kw)
#     446 redirect_location = redirect and response.get_redirect_location()
#     447 if not redirect_location:
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import pandas as pd 
com1 = company_list
columns=['기업이름','분야','평점','연봉']
df1 = pd.DataFrame(com1, columns=columns)

# %%
df1['기업이름'] = df1['기업이름'].str.split('f').str[0]
df1['평점'] = df1['평점'].astype(float)
df1['연봉'] = df1['연봉'].replace({',': ''}, regex=True)
df1['연봉'] = df1['연봉'].astype(int)
df1['2차산업군'] = '기계/설비/자동차'

# %%
df1.to_csv('../../../data/eda_project_data/잡플래닛/기계설비.csv',index=False)

# %%
driver.quit()
