# %%
from tqdm.notebook import tqdm
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.request import Request
import urllib
from user_agent import generate_user_agent

# %%
driver = webdriver.Chrome(service=Service('../../../driver/chromedriver'))
driver.get('https://www.jobplanet.co.kr/companies?industry_id=202&page=1')

# %%
import time
from tqdm.notebook import tqdm

# company_list = []

for i in tqdm(range(1,50)):
    time.sleep(1)
    elements = driver.find_elements(By.CLASS_NAME, 'company.content_ty3')
    
    for elem in elements:
        company =[]

        name = elem.find_element(By.CLASS_NAME,'us_titb_l3').text
        field = elem.find_element(By.CLASS_NAME, 'us_stxt_1').text
        point = elem.find_element(By.CLASS_NAME, 'gfvalue').text
        money = elem.find_element(By.CLASS_NAME, 'notranslate').text
        
        company.append(name)
        company.append(field)
        company.append(point)
        company.append(money)
        company_list.append(company)
        print(company)

    driver.find_element(By.CLASS_NAME, 'btn_pgnext').click()
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]
# ['(주)올네이션 following', '제조/화학', '2.7', '3,302']
# ['(주)제이후렉스 following', '제조/화학', '3.8', '4,547']
# ['(주)하이딥 following', '제조/화학', '2.9', '4,034']
# ['대덕가스(주) following', '제조/화학', '2.4', '2,777']
# ['모멘티브퍼포먼스머티리얼스코리아(주) following', '제조/화학', '2.6', '4,826']
# ['승진기업 following', '제조/화학', '2.0', '2,200']
# ['씨에이치디(주) following', '제조/화학', '2.6', '2,789']
# ['애경특수도료(주) following', '제조/화학', '2.2', '4,201']
# ['엠엔비그린어스(주) following', '제조/화학', '2.0', '3,010']
# ['장암칼스(주) following', '제조/화학', '2.7', '3,461']
# ['지금강(주) following', '제조/화학', '2.9', '3,870']
# ['한국디비케이(주) following', '제조/화학', '2.0', '2,576']
# ['한국무사시도료(주) following', '제조/화학', '2.6', '3,205']
# ['(주)동성화학 following', '제조/화학', '3.0', '3,864']
# ['(주)씨엔텍코리아 following', '제조/화학', '3.2', '2,763']
# ['(주)아토세이프 following', '제조/화학', '3.9', '2,675']
# ['(주)유원플렛폼 following', '제조/화학', '2.4', '3,330']
# ['군장에너지 following', '제조/화학', '3.2', '4,474']
# ['백영전자(주) following', '제조/화학', '1.8', '3,265']
# ['중국검험인증그룹코리아컴퍼니(주) following', '제조/화학', '1.9', '2,896']
# ['테라이엔씨(주) following', '제조/화학', '2.1', '3,203']
# ['(주)비앤비 following', '제조/화학', '2.1', '2,684']
# ['(주)알킨스 following', '제조/화학', '2.6', '3,269']
# ['광동(주) following', '제조/화학', '2.1', '3,394']
# ['로이드선급협회아시아영업소 following', '제조/화학', '3.1', '4,612']
# ['삼의공영(주) following', '제조/화학', '2.5', '3,766']
# ['엠오에스강북(주) following', '제조/화학', '2.1', '2,753']
# ['이코넥스(주) following', '제조/화학', '2.2', '3,443']
# ['제이엘켐(주) following', '제조/화학', '2.8', '4,241']
# ['프라이메탈스테크놀리지스코리아(유) following', '제조/화학', '2.9', '4,800']
# ['한국다우케미칼실리콘(주) following', '제조/화학', '3.3', '5,158']
# ['한국섬유개발연구원 following', '제조/화학', '3.8', '3,807']
# ['(주)빅디테일 following', '제조/화학', '2.3', '2,835']
# ['(주)세원기술단 following', '제조/화학', '1.6', '2,617']
# ['(주)아스타 following', '제조/화학', '2.0', '3,757']
# ['그린텍이엔지(주) following', '제조/화학', '2.2', '2,733']
# ['더원코스메틱(주) following', '제조/화학', '3.2', '3,279']
# ['실리콘밸리(주) following', '제조/화학', '2.7', '2,638']
# ['일진 following', '제조/화학', '2.5', '3,685']
# ['(주)금정 following', '제조/화학', '2.3', '3,041']
# ['(주)정석케미칼 following', '제조/화학', '2.4', '3,486']
# ['금호덴탈제약(주) following', '제조/화학', '1.8', '2,671']
# ['동우기술단(주) following', '제조/화학', '2.3', '3,248']
# ['신광화학공업(주) following', '제조/화학', '2.2', '3,138']
# ['신성산업(주) following', '제조/화학', '1.9', '3,498']
# ['알파색채(주) following', '제조/화학', '2.1', '2,670']
# ['에스디(주) following', '제조/화학', '2.6', '4,261']
# ['이노레스(주) following', '제조/화학', '3.0', '3,247']
# ['인천도시가스(주) following', '제조/화학', '3.1', '4,058']
# ['티케이지애강(주) following', '제조/화학', '2.1', '3,578']
# ['한화폴리드리머(주) following', '제조/화학', '2.6', '3,575']
# ['(주)에프티씨코리아 following', '제조/화학', '3.2', '3,995']
# ['(주)엔티지코리아 following', '제조/화학', '2.2', '3,069']
# ['(주)트리즈엔지니어링 following', '제조/화학', '2.9', '4,034']
# ['(주)피앤피산업 following', '제조/화학', '3.2', '2,661']
# ['(주)해양도시가스 following', '제조/화학', '3.3', '3,989']
# ['(주)헬프트라이알 following', '제조/화학', '3.7', '0']
# ['동양잉크(주) following', '제조/화학', '3.1', '4,726']
# ['동양티피티(주) following', '제조/화학', '2.2', '2,743']
# ['에이치엔씨엔지니어링(주) following', '제조/화학', '2.8', '4,414']
# ['전영(주) following', '제조/화학', '2.0', '3,325']
# ['한국나노텍(주) following', '제조/화학', '1.8', '2,398']
# ['(주)나노 following', '제조/화학', '2.6', '3,070']
# ['(주)디어스엠 following', '제조/화학', '3.5', '2,771']
# ['(주)블루마운트테크놀러지 following', '제조/화학', '2.8', '2,842']
# ['(주)유엔아이 following', '제조/화학', '2.4', '3,303']
# ['(주)창강화학 following', '제조/화학', '3.3', '3,404']
# ['(주)펠릭스랩 following', '제조/화학', '4.3', '2,740']
# ['(주)풍농 following', '제조/화학', '1.9', '5,003']
# ['건일엔지니어링(주) following', '제조/화학', '2.1', '3,811']
# ['광진(주) following', '제조/화학', '3.1', '4,257']
# ['금호폴리켐(주) following', '제조/화학', '3.1', '5,485']
# ['대은산업(주) following', '제조/화학', '1.7', '2,598']
# ['모빌코리아윤활유(주) following', '제조/화학', '2.8', '6,075']
# ['삼공물산(주) following', '제조/화학', '2.3', '3,292']
# ['서안켐텍(주) following', '제조/화학', '2.3', '3,963']
# ['엔에스엠(주) following', '제조/화학', '2.4', '3,528']
# ['우창산업(주) following', '제조/화학', '2.4', '2,594']
# ['유니버셜오일(주) following', '제조/화학', '2.8', '2,808']
# ['일천산업 following', '제조/화학', '1.2', '2,909']
# ['케이디케이(주) following', '제조/화학', '2.1', '4,084']
# ['태진(주) following', '제조/화학', '2.2', '3,192']
# ['태형(주) following', '제조/화학', '2.3', '3,102']
# ['한국훅스윤활유(주) following', '제조/화학', '3.0', '4,072']
# ['(주)뷰케이코리아 following', '제조/화학', '2.8', '3,916']
# ['(주)씨텍 following', '제조/화학', '2.3', '5,033']
# ['(주)한화/화약 following', '제조/화학', '3.6', '5,089']
# ['기도스포츠(주) following', '제조/화학', '2.4', '5,314']
# ['더트루메틱(주) following', '제조/화학', '2.5', '3,450']
# ['덕성엠앤피(주) following', '제조/화학', '2.0', '3,688']
# ['신흥화학(주) following', '제조/화학', '3.2', '3,748']
# ['주영산업(주) following', '제조/화학', '1.4', '2,726']
# ['코스모필름스코리아(주) following', '제조/화학', '3.5', '3,101']
# ['포뉴텍(주) following', '제조/화학', '2.7', '4,302']
# ['피코바이오(주) following', '제조/화학', '2.2', '2,367']
# ['(주)동천 following', '제조/화학', '2.6', '3,661']
# ['(주)두코 following', '제조/화학', '2.2', '3,061']
# ['(주)아이씨티컴플라이언스 following', '제조/화학', '3.3', '3,074']
# ['(주)엘엑스엠엠에이 following', '제조/화학', '3.2', '4,894']
# ['(주)케이팩 following', '제조/화학', '2.6', '3,316']
# ['(주)코멕 following', '제조/화학', '1.6', '3,050']
# ['(주)파머스그레인코리아 following', '제조/화학', '1.2', '2,787']
# ['강원도시가스(주) following', '제조/화학', '3.3', '3,754']
# ['진양화학(주) following', '제조/화학', '2.4', '3,888']
# ['차후에스엔피(주) following', '제조/화학', '2.0', '3,454']
# ['한국호세코(주) following', '제조/화학', '1.4', '4,226']
# ['(주)리뉴시스템 following', '제조/화학', '2.7', '3,319']
# ['(주)아이씨티케이 following', '제조/화학', '2.1', '3,307']
# ['(주)퍼퓸홀릭 following', '제조/화학', '1.9', '0']
# ['(주)프로켐 following', '제조/화학', '1.9', '3,061']
# ['NR지엔씨 following', '제조/화학', '3.3', '3,894']
# ['로얄네이쳐(주) following', '제조/화학', '1.4', '2,517']
# ['룰런즈라버코리아(주) following', '제조/화학', '2.4', '4,380']
# ['범우(주) following', '제조/화학', '2.8', '3,936']
# ['세일하이텍(주) following', '제조/화학', '2.1', '3,302']
# ['씨앤앰(주) following', '제조/화학', '3.2', '4,871']
# ['엘지도요엔지니어링(주) following', '제조/화학', '2.2', '5,700']
# ['조성코퍼레이션(주) following', '제조/화학', '2.2', '2,962']
# ['한진피앤씨(주) following', '제조/화학', '2.1', '4,180']
# ['(주)고비 following', '제조/화학', '2.4', '3,229']
# ['(주)아이유닉 following', '제조/화학', '2.9', '2,796']
# ['(주)에이피텍 following', '제조/화학', '2.8', '3,056']
# ['(주)율산 following', '제조/화학', '1.8', '0']
# ['(주)중앙첨단소재 following', '제조/화학', '2.4', '4,474']
# ['(주)카파맥스 following', '제조/화학', '2.0', '2,484']
# ['(주)피엔에스 following', '제조/화학', '2.5', '3,656']
# ['(주)한신체인 following', '제조/화학', '3.9', '4,117']
# ['(주)해광요업 following', '제조/화학', '3.4', '4,598']
# ['그레이스콘티넨탈코리아(주) following', '제조/화학', '1.8', '2,853']
# ['금화소재(주) following', '제조/화학', '1.9', '3,266']
# ['대경엔지니어링(주) following', '제조/화학', '3.6', '2,768']
# ['로움하이텍(주) following', '제조/화학', '2.5', '3,656']
# ['비씨태창산업(유) following', '제조/화학', '2.5', '2,935']
# ['씰테크(주) following', '제조/화학', '1.8', '2,821']
# ['에스티엑스에너지(주) following', '제조/화학', '3.3', '3,360']
# ['에이피에스티(주) following', '제조/화학', '3.5', '3,151']
# ['엘베스트지에이티(주) following', '제조/화학', '3.1', '4,298']
# ['오리온이엔씨(주) following', '제조/화학', '1.9', '3,645']
# ['정도이앤피(주) following', '제조/화학', '2.4', '4,254']
# ['코스모아이앤디(주) following', '제조/화학', '2.5', '3,851']
# ['파낙스이엠(주) following', '제조/화학', '3.4', '3,381']
# ['한국에이에스케이케미칼즈(주) following', '제조/화학', '3.1', '4,474']
# ['(주)닥터글로덤 following', '제조/화학', '2.7', '2,822']
# ['(주)어벤션 following', '제조/화학', '3.9', '0']
# ['고려검사(주) following', '제조/화학', '2.4', '2,962']
# ['금성티에스씨(주) following', '제조/화학', '1.7', '2,599']
# ['신우산업(주) following', '제조/화학', '1.3', '2,705']
# ['씨에스엘쏠라(주) following', '제조/화학', '3.3', '3,497']
# ['어스그린코리아(주) following', '제조/화학', '3.3', '4,049']
# ['우피휠터스코리아(유) following', '제조/화학', '2.4', '3,451']
# ['이엠씨컴플라이언스(주) following', '제조/화학', '2.9', '4,120']
# ['인천종합에너지(주) following', '제조/화학', '4.4', '5,065']
# ['일신하이폴리(주) following', '제조/화학', '1.9', '4,100']
# ['전영화전(주) following', '제조/화학', '2.0', '2,910']
# ['제이더블유생활건강(주) following', '제조/화학', '1.7', '4,883']
# ['케이에스펄(주) following', '제조/화학', '3.0', '2,670']
# ['한국케미라화학(주) following', '제조/화학', '2.9', '3,709']
# ['한주케미칼(주) following', '제조/화학', '2.0', '4,126']
# ['(주)동일제약 following', '제조/화학', '2.7', '3,142']
# ['(주)석광테크 following', '제조/화학', '4.3', '3,952']
# ['(주)유알지 following', '제조/화학', '5.0', '2,919']
# ['(주)피유시스 following', '제조/화학', '4.3', '4,004']
# ['대원산업(주) following', '제조/화학', '2.2', '4,232']
# ['에어코리아(주) following', '제조/화학', '2.8', '5,512']
# ['위즈코즈(주) following', '제조/화학', '3.0', '2,656']
# ['윈드밀러앤홀셔아시아퍼시픽컴퍼니리미티드 following', '제조/화학', '4.2', '6,312']
# ['이에스코리아(주) following', '제조/화학', '3.7', '1,767']
# ['지에스이(주) following', '제조/화학', '3.5', '4,191']
# ['지엠큐(주) following', '제조/화학', '3.3', '2,249']
# ['한국나이스기술단(주) following', '제조/화학', '2.5', '2,295']
# ['한국사빅이노베이티브플라스틱(유) following', '제조/화학', '2.8', '3,777']
# ['한국카모플라스트(주) following', '제조/화학', '2.8', '2,778']
# ['(주)세모컴퍼니 following', '제조/화학', '2.8', '3,371']
# ['(주)케이디중앙연구소 following', '제조/화학', '2.8', '3,898']
# ['(주)파뮤 following', '제조/화학', '2.8', '2,642']
# ['고도텍(주) following', '제조/화학', '3.4', '3,042']
# ['그라프(주) following', '제조/화학', '2.8', '3,165']
# ['나노픽시스(주) following', '제조/화학', '3.0', '2,370']
# ['대림(주) following', '제조/화학', '3.0', '3,874']
# ['대진첨단소재(주) following', '제조/화학', '2.0', '2,966']
# ['동서산업(주) following', '제조/화학', '3.6', '4,050']
# ['동성하이켐(주) following', '제조/화학', '3.4', '4,587']
# ['삼성비피화학(주) following', '제조/화학', '3.4', '4,986']
# ['선익 following', '제조/화학', '4.0', '3,039']
# ['에스엠솔루션즈(주) following', '제조/화학', '1.8', '2,390']
# ['에이치더블유아이(주) following', '제조/화학', '2.0', '3,384']
# ['월드에어텍(주) following', '제조/화학', '3.0', '2,506']
# ['제누스(주) following', '제조/화학', '2.6', '4,931']
# ['케이에이치테크 following', '제조/화학', '1.4', '3,983']
# ['태성엔지니어링 following', '제조/화학', '2.6', '3,546']
# ['티티티(주) following', '제조/화학', '2.6', '3,131']
# ['플러벤스(주) following', '제조/화학', '2.6', '3,051']
# ['한진화학(주) following', '제조/화학', '1.4', '3,152']
# ['(주)건양 following', '제조/화학', '3.8', '3,219']
# ['(주)오리오 following', '제조/화학', '2.5', '0']
# ['(주)유니트레이드 following', '제조/화학', '3.3', '3,072']
# ['(주)코레트리 following', '제조/화학', '1.8', '3,133']
# ['경민엔지니어링(주) following', '제조/화학', '3.0', '2,174']
# ['그린텍컴(주) following', '제조/화학', '3.0', '2,911']
# ['동해가스산업(주) following', '제조/화학', '2.8', '3,017']
# ['디케이씨코포레이션(주) following', '제조/화학', '2.3', '1,845']
# ['라파월드(주) following', '제조/화학', '3.3', '3,218']
# ['마임 following', '제조/화학', '3.0', '2,614']
# ['명성세미트론(주) following', '제조/화학', '2.5', '2,846']
# ['부성폴리콤(주) following', '제조/화학', '2.5', '3,382']
# ['비엔케미칼(주) following', '제조/화학', '2.0', '3,112']
# ['세스트(주) following', '제조/화학', '2.8', '3,567']
# ['수완에너지(주) following', '제조/화학', '3.3', '5,010']
# ['싸이트로닉(주) following', '제조/화학', '1.8', '0']
# ['씨씨피컴포지트코리아(주) following', '제조/화학', '2.5', '3,316']
# ['에스케이어드밴스드(주) following', '제조/화학', '3.0', '5,109']
# ['제이엠넷(주) following', '제조/화학', '2.8', '3,002']
# ['태영티알티(주) following', '제조/화학', '2.3', '2,894']
# ['한국솔베이정밀화학(주) following', '제조/화학', '3.8', '3,167']
# ['화인코(주) following', '제조/화학', '2.8', '3,067']
# ['(주)네스트 following', '제조/화학', '3.0', '2,563']
# ['(주)에이에스피 following', '제조/화학', '4.0', '0']
# ['(주)엑소루브 following', '제조/화학', '2.3', '2,920']
# ['(주)이레에이티 following', '제조/화학', '1.0', '3,897']
# ['남양고진공 following', '제조/화학', '3.7', '0']
# ['대광화공(주) following', '제조/화학', '2.0', '5,701']
# ['대양플라텍(주) following', '제조/화학', '3.3', '3,364']
# ['디더블유아이(주) following', '제조/화학', '1.3', '2,974']
# ['범일전기(주) following', '제조/화학', '3.0', '2,988']
# ['블랙스미스(주) following', '제조/화학', '2.7', '2,220']
# ['삼성석유화학(주) following', '제조/화학', '3.0', '5,259']
# ['솔레니스코리아(유) following', '제조/화학', '2.0', '3,387']
# ['스톨베르그앤드삼일(주) following', '제조/화학', '3.0', '4,337']
# ['씨아이텔레콤 following', '제조/화학', '2.3', '3,844']
# ['씨알에스리프로세싱코리아리미티드(유) following', '제조/화학', '4.3', '3,667']
# ['씨에스텍(주) following', '제조/화학', '1.7', '0']
# ['에스지씨에너지(주) following', '제조/화학', '3.7', '4,893']
# ['에스케이피아이씨글로벌(주) following', '제조/화학', '4.3', '5,225']
# ['오아시스이엔에스(주) following', '제조/화학', '3.0', '2,967']
# ['우병엔지니어링(주) following', '제조/화학', '3.3', '3,847']
# ['이엘엠(주) following', '제조/화학', '3.3', '3,328']
# ['코네스코퍼레이션(주) following', '제조/화학', '3.7', '3,246']
# ['타코스(주) following', '제조/화학', '1.3', '0']
# ['태강(주) following', '제조/화학', '2.3', '2,407']
# ['현대전자 following', '제조/화학', '4.0', '5,333']
# ['(주)경원 following', '제조/화학', '1.5', '0']
# ['(주)미디온그룹 following', '제조/화학', '4.0', '3,818']
# ['(주)버즈업 following', '제조/화학', '5.0', '0']
# ['(주)부산아크릴 following', '제조/화학', '1.5', '2,906']
# ['(주)시코 following', '제조/화학', '3.5', '2,473']
# ['(주)엘케이랩스 following', '제조/화학', '5.0', '0']
# ['(주)영인플랜텍 following', '제조/화학', '3.0', '0']
# ['(주)퓨어스피어 following', '제조/화학', '3.5', '3,605']
# ['(주)하나이화 following', '제조/화학', '3.0', '4,484']
# ['(주)현텍엔바이오 following', '제조/화학', '5.0', '0']
# ['가온에이스(주) following', '제조/화학', '1.5', '1,755']
# ['고려도토(주) following', '제조/화학', '2.0', '2,412']
# ['굿스 following', '제조/화학', '4.5', '3,690']
# ['동양케미칼(주) following', '제조/화학', '3.0', '4,640']
# ['두루주 following', '제조/화학', '4.0', '0']
# ['라이프앤진(주) following', '제조/화학', '4.0', '0']
# ['로완컴퍼니스 following', '제조/화학', '4.5', '11,700']
# ['베이비원코리아(주) following', '제조/화학', '1.0', '2,298']
# ['보경전기 following', '제조/화학', '2.5', '2,633']
# ['부건종합건축사사무소(주) following', '제조/화학', '2.0', '5,119']
# ['비기(주) following', '제조/화학', '3.5', '3,475']
# ['비스알(주) following', '제조/화학', '2.5', '3,710']
# ['삼양화성(주) following', '제조/화학', '4.5', '5,220']
# ['선박설계폴라리스 following', '제조/화학', '2.0', '0']
# ['선텍옵트코리아(주) following', '제조/화학', '1.0', '3,767']
# ['세원산업(주) following', '제조/화학', '4.0', '3,628']
# ['실리콘모션코리아(유) following', '제조/화학', '3.5', '4,845']
# ['아시아소음진동연구소(주) following', '제조/화학', '2.5', '2,925']
# ['에스케이에스페인트(주) following', '제조/화학', '2.0', '3,100']
# ['에이와케이(주) following', '제조/화학', '1.0', '3,705']
# ['에이피엠(주) following', '제조/화학', '1.0', '3,472']
# ['와이씨켐(주) following', '제조/화학', '2.5', '3,738']
# ['인천연료전지(주) following', '제조/화학', '2.0', '0']
# ['일진레이텍(주) following', '제조/화학', '1.0', '4,313']
# ['자연과과학(주) following', '제조/화학', '3.5', '2,400']
# ['제일화성(주) following', '제조/화학', '3.0', '2,958']
# ['지코스(주) following', '제조/화학', '2.5', '4,110']
# ['창원테크(주) following', '제조/화학', '3.5', '6,150']
# ['코스팜(주) following', '제조/화학', '2.5', '2,072']
# ['코웨스코(주) following', '제조/화학', '1.5', '3,153']
# ['파낙코리아(주) following', '제조/화학', '4.0', '2,871']
# ['평화산업사 following', '제조/화학', '2.0', '0']
# ['한국스티롤루션(주) following', '제조/화학', '2.5', '3,365']
# ['한산(주) following', '제조/화학', '2.5', '3,075']
# ['(유)에코텍코리아 following', '제조/화학', '5.0', '0']
# ['(유)천향네이처 following', '제조/화학', '1.0', '0']
# ['(주)부농 following', '제조/화학', '4.0', '3,807']
# ['(주)비갠 following', '제조/화학', '4.0', '0']
# ['(주)비티에스이엔지 following', '제조/화학', '3.0', '3,953']
# ['(주)아이필로 following', '제조/화학', '1.0', '0']
# ['(주)에니켐텍 following', '제조/화학', '4.0', '3,764']
# ['(주)켐베이스 following', '제조/화학', '3.0', '2,559']
# ['(주)코팩시스템 following', '제조/화학', '4.0', '2,798']
# ['(주)프라코 following', '제조/화학', '2.0', '4,227']
# ['감성커뮤니케이션(주) following', '제조/화학', '3.0', '0']
# ['경북산업개발(주) following', '제조/화학', '4.0', '6,435']
# ['교연엔지니어링(주) following', '제조/화학', '4.0', '4,103']
# ['군산도시가스 following', '제조/화학', '1.0', '3,753']
# ['나노이닉스(주) following', '제조/화학', '3.0', '2,749']
# ['남양비엠씨(주) following', '제조/화학', '3.0', '1,755']
# ['누드코스메틱(주) following', '제조/화학', '3.0', '2,255']
# ['대헌(주) following', '제조/화학', '4.0', '4,827']
# ['대흥아이비엔(주) following', '제조/화학', '5.0', '3,984']
# ['드림라인테크(주) following', '제조/화학', '4.0', '2,723']
# ['레비브레코리아(주) following', '제조/화학', '1.0', '0']
# ['브라이트에너지파트너스(주) following', '제조/화학', '5.0', '0']
# ['삼우에프엔지(주) following', '제조/화학', '5.0', '2,702']
# ['삼정디씨피(주) following', '제조/화학', '1.0', '3,163']
# ['성도엔지니어링 following', '제조/화학', '2.0', '4,109']
# ['성진케미칼 following', '제조/화학', '4.0', '2,692']
# ['시프트테크놀로지스코리아(유) following', '제조/화학', '4.0', '0']
# ['신한테크(주) following', '제조/화학', '2.0', '2,650']
# ['씨에스아이(주) following', '제조/화학', '3.0', '2,453']
# ['아이비넷 following', '제조/화학', '2.0', '2,535']
# ['아이실리콘(주) following', '제조/화학', '2.0', '4,494']
# ['에버그린21 following', '제조/화학', '3.0', '3,075']
# ['에스제이(주) following', '제조/화학', '2.0', '1,755']
# ['에이스기술단(주) following', '제조/화학', '3.0', '1,875']
# ['엑스메텍(주) following', '제조/화학', '2.0', '3,867']
# ['엠피씨율촌전력(주) following', '제조/화학', '5.0', '6,287']
# ['영진공업(주) following', '제조/화학', '4.0', '3,511']
# ['올팩코리아 following', '제조/화학', '3.0', '4,205']
# ['유달산업 following', '제조/화학', '3.0', '1,845']
# ['이삭(주) following', '제조/화학', '2.0', '2,737']
# ['이월에스엔피(주) following', '제조/화학', '3.0', '0']
# ['케이알코폴리머(주) following', '제조/화학', '4.0', '0']
# ['켐텍(주) following', '제조/화학', '2.0', '2,623']
# ['크리룩스(주) following', '제조/화학', '3.0', '0']
# ['키솔(주) following', '제조/화학', '3.0', '0']
# ['티엔지(주) following', '제조/화학', '4.0', '3,599']
# ['피앤비(주) following', '제조/화학', '2.0', '2,426']
# ['필켐(주) following', '제조/화학', '3.0', '3,313']
# ['한국주택관리(주) following', '제조/화학', '3.0', '2,830']
# ['흥진테크 following', '제조/화학', '4.0', '4,100']
# ['(유)리퀴드매니아 following', '제조/화학', '0.0', '0']
# ['(유)와이엠리앤텍 following', '제조/화학', '0.0', '0']
# ['(주)노바머터리얼즈 following', '제조/화학', '0.0', '0']
# ['(주)대한링크 following', '제조/화학', '0.0', '0']
# ['(주)더데이원랩 following', '제조/화학', '0.0', '0']
# ['(주)리단데 following', '제조/화학', '0.0', '0']
# ['(주)비앤비컴퍼지트 following', '제조/화학', '0.0', '0']
# ['(주)서광산업 following', '제조/화학', '0.0', '4,119']
# ['(주)쉐어켐 following', '제조/화학', '0.0', '0']
# ['(주)씨앤엠 following', '제조/화학', '0.0', '0']
# ['(주)씨이텍 following', '제조/화학', '0.0', '0']
# ['(주)아이린코스메틱 following', '제조/화학', '0.0', '0']
# ['(주)아헤스 following', '제조/화학', '0.0', '0']
# ['(주)에이치에스이엔지 following', '제조/화학', '0.0', '0']
# ['(주)오버플러스파워 following', '제조/화학', '0.0', '0']
# ['(주)재우 following', '제조/화학', '0.0', '0']
# ['(주)제일하이텍 following', '제조/화학', '0.0', '3,456']
# ['(주)포레스트커머스 following', '제조/화학', '0.0', '0']
# ['(주)폴리코리아 following', '제조/화학', '0.0', '2,935']
# ['(주)화남인더스트리 following', '제조/화학', '0.0', '3,060']
# ['경기전기관리공사(주) following', '제조/화학', '0.0', '2,867']
# ['남경이엔지(주) following', '제조/화학', '0.0', '0']
# ['대한에프앤드에프(주) following', '제조/화학', '0.0', '0']
# ['더존(주) following', '제조/화학', '0.0', '4,476']
# ['덕산(주) following', '제조/화학', '0.0', '3,645']
# ['덕원엔지니어링(주) following', '제조/화학', '0.0', '0']
# ['띵크어바웃유(주) following', '제조/화학', '0.0', '0']
# ['마이크로켐(주) following', '제조/화학', '0.0', '5,855']
# ['만인산농업협동조합 following', '제조/화학', '0.0', '4,906']
# ['모소행(주) following', '제조/화학', '0.0', '0']
# ['무림교역(주) following', '제조/화학', '0.0', '0']
# ['미샤비씨에스(주) following', '제조/화학', '0.0', '2,930']
# ['비엔티 following', '제조/화학', '0.0', '3,033']
# ['삼광잉크제조(주) following', '제조/화학', '0.0', '3,180']
# ['성림영농조합법인 following', '제조/화학', '0.0', '0']
# ['신성프라스틱공업(주) following', '제조/화학', '0.0', '4,364']
# ['신영델텍(주) following', '제조/화학', '0.0', '1,921']
# ['신일 following', '제조/화학', '0.0', '3,666']
# ['에스에스에이디티(주) following', '제조/화학', '0.0', '0']
# ['에스이엘(주) following', '제조/화학', '0.0', '6,150']
# ['에스파워(주) following', '제조/화학', '0.0', '8,251']
# ['엠오아이(주) following', '제조/화학', '0.0', '1,755']
# ['연호코스텍(주) following', '제조/화학', '0.0', '0']
# ['와이투(주) following', '제조/화학', '0.0', '0']
# ['유나이티드퍼시픽피엘지(주) following', '제조/화학', '0.0', '3,767']
# ['유화산업(주) following', '제조/화학', '0.0', '3,304']
# ['인터플론 코리아 following', '제조/화학', '0.0', '0']
# ['케스코(주) following', '제조/화학', '0.0', '0']
# ['팔공산미나리능성영농조합법인 following', '제조/화학', '0.0', '0']
# ['팩토리풀 following', '제조/화학', '0.0', '0']
# ['플러버(주) following', '제조/화학', '0.0', '4,277']
# ['협동엔지니어링(주) following', '제조/화학', '0.0', '5,385']
# ['화성산업(주) following', '제조/화학', '0.0', '3,577']
# ['화승소재(주) 인도법인 following', '제조/화학', '0.0', '2,370']
# ['인터플론 코리아 following', '제조/화학', '0.0', '0']
# ['케스코(주) following', '제조/화학', '0.0', '0']
# ['팔공산미나리능성영농조합법인 following', '제조/화학', '0.0', '0']
# ['팩토리풀 following', '제조/화학', '0.0', '0']
# ['플러버(주) following', '제조/화학', '0.0', '4,277']
# ['협동엔지니어링(주) following', '제조/화학', '0.0', '5,385']
# ['화성산업(주) following', '제조/화학', '0.0', '3,577']
# ['화승소재(주) 인도법인 following', '제조/화학', '0.0', '2,370']
# ['인터플론 코리아 following', '제조/화학', '0.0', '0']
# ['케스코(주) following', '제조/화학', '0.0', '0']
# ['팔공산미나리능성영농조합법인 following', '제조/화학', '0.0', '0']
# ['팩토리풀 following', '제조/화학', '0.0', '0']
# ['플러버(주) following', '제조/화학', '0.0', '4,277']
# ['협동엔지니어링(주) following', '제조/화학', '0.0', '5,385']
# ['화성산업(주) following', '제조/화학', '0.0', '3,577']
# ['화승소재(주) 인도법인 following', '제조/화학', '0.0', '2,370']
# ['인터플론 코리아 following', '제조/화학', '0.0', '0']
# ['케스코(주) following', '제조/화학', '0.0', '0']
# ['팔공산미나리능성영농조합법인 following', '제조/화학', '0.0', '0']
# ['팩토리풀 following', '제조/화학', '0.0', '0']
# ['플러버(주) following', '제조/화학', '0.0', '4,277']
# ['협동엔지니어링(주) following', '제조/화학', '0.0', '5,385']
# ['화성산업(주) following', '제조/화학', '0.0', '3,577']
# ['화승소재(주) 인도법인 following', '제조/화학', '0.0', '2,370']
# ['인터플론 코리아 following', '제조/화학', '0.0', '0']
# ['케스코(주) following', '제조/화학', '0.0', '0']
# ['팔공산미나리능성영농조합법인 following', '제조/화학', '0.0', '0']
# ['팩토리풀 following', '제조/화학', '0.0', '0']
# ['플러버(주) following', '제조/화학', '0.0', '4,277']
# ['협동엔지니어링(주) following', '제조/화학', '0.0', '5,385']
# ['화성산업(주) following', '제조/화학', '0.0', '3,577']
# ['화승소재(주) 인도법인 following', '제조/화학', '0.0', '2,370']
# ['인터플론 코리아 following', '제조/화학', '0.0', '0']
# ['케스코(주) following', '제조/화학', '0.0', '0']
# ['팔공산미나리능성영농조합법인 following', '제조/화학', '0.0', '0']
# ['팩토리풀 following', '제조/화학', '0.0', '0']
# ['플러버(주) following', '제조/화학', '0.0', '4,277']
# ['협동엔지니어링(주) following', '제조/화학', '0.0', '5,385']
# ['화성산업(주) following', '제조/화학', '0.0', '3,577']
# ['화승소재(주) 인도법인 following', '제조/화학', '0.0', '2,370']
# ['인터플론 코리아 following', '제조/화학', '0.0', '0']
# ['케스코(주) following', '제조/화학', '0.0', '0']
# ['팔공산미나리능성영농조합법인 following', '제조/화학', '0.0', '0']
# ['팩토리풀 following', '제조/화학', '0.0', '0']
# ['플러버(주) following', '제조/화학', '0.0', '4,277']
# ['협동엔지니어링(주) following', '제조/화학', '0.0', '5,385']
# ['화성산업(주) following', '제조/화학', '0.0', '3,577']
# ['화승소재(주) 인도법인 following', '제조/화학', '0.0', '2,370']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       4 # company_list = []
#       6 for i in tqdm(range(1,50)):
# ----> 7     time.sleep(1)
#       8     elements = driver.find_elements(By.CLASS_NAME, 'company.content_ty3')
#      10     for elem in elements:
#
# KeyboardInterrupt:

# %%
import pandas as pd 
com1 = company_list
columns=['기업이름','분야','평점','연봉']
df1 = pd.DataFrame(com1, columns=columns)

# %%
df1['기업이름'] = df1['기업이름'].str.split('f').str[0]
df1['평점'] = df1['평점'].astype(float)
df1['연봉'] = df1['연봉'].replace({',': ''}, regex=True)
df1['연봉'] = df1['연봉'].astype(int)
df1['2차산업군'] = '석유/화학/에너지'

# %%
df1.to_csv('../../../data/eda_project_data/잡플래닛/석유화학에너지.csv',index=False)

# %%
driver.quit()
