# %% [markdown]
# ##### project_merge테이블 기업이름 중복 없이 몇 개 있나 계산 - 428개

# %%
import pandas as pd

df = pd.read_csv("project_merge.csv")
df.head()
# Out:
#       기업이름 고용형태        연봉                                        기업주소   키워드  \
# 0    컨트롤웍스   2년  연봉업계평균이상                    서울 강남구 언주로81길 13 진일빌딩 3층  자율주행
# 1  뷰런테크놀로지    -         -                           서초구 강남대로 311, 19층  자율주행
# 2     씨엔비스   4년         -  경기도 성남시 수정구 창업로 43, 판교 글로벌비즈센터 A동 907~910호  자율주행
# 3    컨트롤웍스   2년  연봉업계평균이상                    서울 강남구 언주로81길 13 진일빌딩 3층  자율주행
# 4    베스텔라랩   2년  연봉업계평균이상      안양시 동안구 엘에스로116번길 118 안양2차 SKV1 Center  자율주행
#
#                          담당업무  \
# 0  [2년 이상] 자율주행 Front-End 개발자
# 1                 자율주행 인지 개발자
# 2                 자율주행 인지 개발자
# 3                자율주행 SW 엔지니어
# 4   자율주행 연구원(경기/대구)(전문연구요원가능)
#
#                                                 필요역량  인덱스
# 0  [자격요건], 학사 이상 (컴퓨터 공학/감성 및 인간공학 등 전공), 프론트엔드 개...    1
# 1  , 전자전기/컴퓨터공학 학사 이상 또는 이와 비슷한 동종업계 경력, C/C++ 또는...    2
# 2  , 관련 분야 학사학위(4년제) 이상, 혹은 유관 분야 경력 2년 이상이신 분, C...    3
# 3  [자격요건],  학사학위 이상(자동차공학, 기계공학, 로보틱스, 컴퓨터 공학, 전기...    4
# ...

# %%
df.drop_duplicates(subset=['기업이름'], keep='first', inplace=True)

# %%
df
# Out:
#         기업이름      고용형태        연봉                                        기업주소  \
# 0      컨트롤웍스        2년  연봉업계평균이상                    서울 강남구 언주로81길 13 진일빌딩 3층
# 1    뷰런테크놀로지         -         -                           서초구 강남대로 311, 19층
# 2       씨엔비스        4년         -  경기도 성남시 수정구 창업로 43, 판교 글로벌비즈센터 A동 907~910호
# 4      베스텔라랩        2년  연봉업계평균이상      안양시 동안구 엘에스로116번길 118 안양2차 SKV1 Center
# 5      엑스와이지        2년         -                          서울시 성동구 아차산로17길 48
# ..       ...       ...       ...                                         ...
# 933   에스피에이치  경력 3~15년  회사내규에 따름             서울 마포구 마포대로 92,  효성해링턴스퀘어 A동 3층
# 938      포소드  경력신입~20년  회사내규에 따름              서울시 영등포구 영신로 220, KnK디지털타워 707
# 939      딥파인  경력 3~15년  회사내규에 따름                           서울 용산구 한강대로30길 25
# 941      피처링  경력 2~10년  회사내규에 따름            서울 강남구 테헤란로 419, 15층 (강남파이낸스플라자)
# 943   데이터메이커  경력 3~15년  회사내규에 따름                       대전 유성구 유성대로 871, 4-5층
#
#       키워드                           담당업무  \
# ...
